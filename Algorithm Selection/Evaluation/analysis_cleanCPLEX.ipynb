# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Confusion matrix of autofolio schedules

# %%
schedule1 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/1_schedule.npy', allow_pickle=True)
schedule2 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/2_schedule.npy', allow_pickle=True)
schedule3 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/3_schedule.npy', allow_pickle=True)
schedule4 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/4_schedule.npy', allow_pickle=True)
schedule5 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/5_schedule.npy', allow_pickle=True)
schedule6 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/6_schedule.npy', allow_pickle=True)
schedule7 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/7_schedule.npy', allow_pickle=True)
schedule8 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/8_schedule.npy', allow_pickle=True)
schedule9 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/9_schedule.npy', allow_pickle=True)
schedule10 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_cleanARPfeatures_48hs/10_schedule.npy', allow_pickle=True)

# %%
instance1 = list(schedule1.tolist().keys())
selection1 = list(schedule1.tolist().values())
instance2 = list(schedule2.tolist().keys())
selection2 = list(schedule2.tolist().values())
instance3 = list(schedule3.tolist().keys())
selection3 = list(schedule3.tolist().values())
instance4 = list(schedule4.tolist().keys())
selection4 = list(schedule4.tolist().values())
instance5 = list(schedule5.tolist().keys())
selection5 = list(schedule5.tolist().values())
instance6 = list(schedule6.tolist().keys())
selection6 = list(schedule6.tolist().values())
instance7 = list(schedule7.tolist().keys())
selection7 = list(schedule7.tolist().values())
instance8 = list(schedule8.tolist().keys())
selection8 = list(schedule8.tolist().values())
instance9 = list(schedule9.tolist().keys())
selection9 = list(schedule9.tolist().values())
instance10 = list(schedule10.tolist().keys())
selection10 = list(schedule10.tolist().values())

#pd.DataFrame({'instances': instance1, 'selection': selection1})

# %%
import itertools

merged_instances = itertools.chain(instance1, instance2, instance3, instance4, instance5, instance6, instance7, instance8, instance9, instance10)
merged_instances = list(merged_instances)

merged_selections = itertools.chain(selection1, selection2, selection3, selection4, selection5, selection6, selection7, selection8, selection9, selection10)
merged_selections = list(merged_selections)

# %%
for i in merged_selections:
    print(i)
# Out:
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config1', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config1', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('ConfigDefault', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# ...
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config1', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config2', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]
# [('Config3', 9601)]

# %%
new_merged_selections = []
for i in merged_selections:
    new_merged_selections.append(i[0][0])

# %%
import re
new_merged_instances = []
for i in merged_instances:
    new_merged_instances.append(int(re.findall(r'\d+', i)[0]))

# %%
runtimes = pd.read_excel('C:/Users/Jasmin/Documents/MSc-Thesis/Data/Runtime/Results-MIPVerify_SDPdMLPa.xlsx')
runtimes.head()
# Out:
#    SampleNumber  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
#
#        SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  SolveTime_conf3  \
# 0  InfeasibleOrUnbounded        44.068493        Infeasible        78.731996
# 1              UserLimit      9600.184597         UserLimit      9600.010288
# 2  InfeasibleOrUnbounded      3025.400426        Infeasible      2938.074613
# 3  InfeasibleOrUnbounded        54.733004        Infeasible        41.134581
# 4  InfeasibleOrUnbounded       538.053177        Infeasible       300.046997
#
#   SolveStatus_conf3  SolveTime_best      Config_best
# 0        Infeasible       44.068493  SolveTime_conf2
# 1         UserLimit     9600.010288          TIMEOUT
# 2        Infeasible     1258.149140  SolveTime_conf1
# 3        Infeasible       41.134581  SolveTime_conf3
# 4        Infeasible      220.795008  SolveTime_conf1

# %%
runtimes.rename(columns={'SampleNumber': 'instances'}, inplace=True)

# %%
runtimes
# Out:
#       instances  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
# ...         ...                ...                    ...              ...
# 9995       9996          12.674720  InfeasibleOrUnbounded     18608.097787
# 9996       9997          18.379950  InfeasibleOrUnbounded       110.131027
# 9997       9998          75.684641  InfeasibleOrUnbounded       105.670172
# 9998       9999        1669.967257  InfeasibleOrUnbounded       826.113838
# 9999      10000          22.112561  InfeasibleOrUnbounded       378.362607
#
#           SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  \
# 0     InfeasibleOrUnbounded        44.068493        Infeasible
# 1                 UserLimit      9600.184597         UserLimit
# 2     InfeasibleOrUnbounded      3025.400426        Infeasible
# 3     InfeasibleOrUnbounded        54.733004        Infeasible
# 4     InfeasibleOrUnbounded       538.053177        Infeasible
# ...                     ...              ...               ...
# 9995              UserLimit        25.863838        Infeasible
# 9996  InfeasibleOrUnbounded        50.209194        Infeasible
# 9997  InfeasibleOrUnbounded       106.346014        Infeasible
# 9998  InfeasibleOrUnbounded      1401.266455        Infeasible
# 9999  InfeasibleOrUnbounded        78.919991        Infeasible
#
#       SolveTime_conf3 SolveStatus_conf3  SolveTime_best        Config_best
# 0           78.731996        Infeasible       44.068493    SolveTime_conf2
# 1         9600.010288         UserLimit     9600.010288            TIMEOUT
# 2         2938.074613        Infeasible     1258.149140    SolveTime_conf1
# 3           41.134581        Infeasible       41.134581    SolveTime_conf3
# 4          300.046997        Infeasible      220.795008    SolveTime_conf1
# ...               ...               ...             ...                ...
# 9995       172.116870        Infeasible       12.674720  SolveTime_default
# 9996       110.876559        Infeasible       18.379950  SolveTime_default
# 9997       102.811690        Infeasible       75.684641  SolveTime_default
# 9998      1643.462584        Infeasible      826.113838    SolveTime_conf1
# 9999        18.838446        Infeasible       18.838446    SolveTime_conf3
#
# [10000 rows x 11 columns]

# %%
new_runtimes = runtimes[['instances', 'Config_best']]

# %%
afolio = pd.DataFrame({'instances': new_merged_instances, 'selection': new_merged_selections})

# %%
afolio = afolio.merge(new_runtimes, on='instances')

# %%
afolio
# Out:
#       instances selection        Config_best
# 0          1021   Config3    SolveTime_conf1
# 1          1022   Config3    SolveTime_conf1
# 2          1033   Config3  SolveTime_default
# 3          1048   Config3    SolveTime_conf2
# 4          1057   Config3    SolveTime_conf2
# ...         ...       ...                ...
# 9995       9949   Config3    SolveTime_conf1
# 9996       9968   Config2    SolveTime_conf3
# 9997       9970   Config3    SolveTime_conf1
# 9998       9973   Config3  SolveTime_default
# 9999       9995   Config3  SolveTime_default
#
# [10000 rows x 3 columns]

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf1", "Config_best"] = "Config1"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf2", "Config_best"] = "Config2"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf3", "Config_best"] = "Config3"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_default", "Config_best"] = "ConfigDefault"

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

print("accuracy:", accuracy_score(afolio['Config_best'], afolio['selection']))

plt.subplots(figsize=(11.5,7)) 
cm = confusion_matrix(afolio['Config_best'], afolio['selection'], labels=['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
#ax = plt.axes()
ax = sns.heatmap(cm, linewidth=0.5, annot=True, fmt='d')
ax.set_title("Confusion Matrix for Autofolio selectiion using cleaned ARP features")
ax.set_ylabel("Actual", fontsize=14, labelpad=20)
ax.set_xlabel("Prediction", fontsize=14, labelpad=20)
ax.xaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
ax.yaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
plt.show()
# Out:
# accuracy: 0.3245

# %%
#remove timeouts
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

afolio.drop(afolio[afolio['Config_best'] == 'TIMEOUT'].index, inplace = True)


print("accuracy:", accuracy_score(afolio['Config_best'], afolio['selection']))

plt.subplots(figsize=(11.5,7)) 
cm = confusion_matrix(afolio['Config_best'], afolio['selection'], labels=['ConfigDefault', 'Config1', 'Config2', 'Config3'])
#ax = plt.axes()
ax = sns.heatmap(cm, linewidth=0.5, annot=True, fmt='d')
ax.set_title("Autofolio selection using cleaned ARP MIP features")
ax.set_ylabel("Actual", fontsize=14, labelpad=20)
ax.set_xlabel("Prediction", fontsize=14, labelpad=20)
ax.xaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3'])
ax.yaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3'])
plt.show()
# Out:
# accuracy: 0.3816749000235239

# %% [markdown]
# ## Plot par10s

# %%
import pandas as pd
import numpy as np

# %%
id_order = pd.read_csv("output_cleanARPfeatures_48hs/id_order.csv",names=['id'], header=0)
id_order.head()
# Out:
#         id
# 0  mip1021
# 1  mip1022
# 2  mip1033
# 3  mip1048
# 4  mip1057

# %%
vbs = pd.read_csv("output_cleanARPfeatures_48hs/all_vbs.csv", names=['vbs'], header=0)
sbs = pd.read_csv("output_cleanARPfeatures_48hs/all_sbs.csv", names=['sbs'],header=0)
instances = pd.read_csv("output_cleanARPfeatures_48hs/all_instances.csv", names=['instances'], header=0)

df = [vbs,sbs,instances,id_order]
df = pd.concat(df, axis=1)
df.head()
# Out:
#           vbs          sbs    instances       id
# 0  237.739878   299.625810   300.009143  mip1021
# 1  181.373848   254.938741   255.372074  mip1022
# 2  809.615652  2575.033846  2575.400513  mip1033
# 3   28.995697    56.105023    56.438357  mip1048
# 4   76.865610    79.595654    79.962320  mip1057

# %%
# Before analyzing data check if timeouts are in PAR10, if not multiply all timeouts (9600) by 10
print(vbs.max())
print(sbs.max())
print(instances.max())
# Out:
# vbs    96000.0
# dtype: float64
# sbs    96000.0
# dtype: float64
# instances    96000.0
# dtype: float64

# %%
# Before analyzing data check if timeouts are in PAR10, if not multiply all timeouts (9600) by 10
def par10ify(x):
    if x >= 9600:
        return 96000
    else:
        return x
    

def par2ify(x):
    if x >= 9600:
        return 9600*2
    else:
        return x


def par1ify(x):
    if x >= 9600:
        return 9600
    else:
        return x

#df['vbs'] = df['vbs'].apply(par10ify)
#df['sbs'] = df['sbs'].apply(par10ify)
#df['instances'] = df['instances'].apply(par10ify)
#df.head()

# %%
# Closed gap --> (sum(sbs) - sum(instances))/(sum(sbs) - sum(vbs))
closed_gap = (df.sbs.sum() - df.instances.sum())/(df.sbs.sum() - df.vbs.sum())
print(closed_gap)
# Out:
# -0.01225005592026027

# %%
df.sbs.sum()/10000
# Out:
# 16482.56105497079

# %%
df.vbs.sum()/10000
# Out:
# 14830.814236654376

# %%
df.instances.sum()/10000
# Out:
# 16502.795045861276

# %% [markdown]
# ## CHECK WITH RAW DATA IF THIS MAKES SENSE

# %%
runtimes = pd.read_excel('C:/Users/Jasmin/Documents/MSc-Thesis/Data/Runtime/Results-MIPVerify_SDPdMLPa.xlsx')
runtimes.head()
# Out:
#    SampleNumber  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
#
#        SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  SolveTime_conf3  \
# 0  InfeasibleOrUnbounded        44.068493        Infeasible        78.731996
# 1              UserLimit      9600.184597         UserLimit      9600.010288
# 2  InfeasibleOrUnbounded      3025.400426        Infeasible      2938.074613
# 3  InfeasibleOrUnbounded        54.733004        Infeasible        41.134581
# 4  InfeasibleOrUnbounded       538.053177        Infeasible       300.046997
#
#   SolveStatus_conf3  SolveTime_best      Config_best
# 0        Infeasible       44.068493  SolveTime_conf2
# 1         UserLimit     9600.010288          TIMEOUT
# 2        Infeasible     1258.149140  SolveTime_conf1
# 3        Infeasible       41.134581  SolveTime_conf3
# 4        Infeasible      220.795008  SolveTime_conf1

# %%
runtimes[['SampleNumber', 'SolveTime_best', 'SolveTime_conf3']].iloc[[0, 9, 99]]
# Out:
#     SampleNumber  SolveTime_best  SolveTime_conf3
# 0              1       44.068493        78.731996
# 9             10     9600.019248      9600.171495
# 99           100       80.580781       215.399513

# %%
#runtimes['SolveTime_best'] = runtimes['SolveTime_best'].apply(par10ify)
#check_parallel = runtimes.SolveTime_best * 4
#print(check_parallel.sum()/10000)

# %%
new_runtimes = runtimes[['SampleNumber', 'SolveTime_conf1', 'SolveTime_conf2', 'SolveTime_conf3', 'SolveTime_default', 'SolveTime_best']]
new_runtimes.rename(columns={'SampleNumber':'id'}, inplace=True)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\520049881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes.rename(columns={'SampleNumber':'id'}, inplace=True)

# %%
new_runtimes
# Out:
#          id  SolveTime_conf1  SolveTime_conf2  SolveTime_conf3  \
# 0         1       152.683291        44.068493        78.731996
# 1         2      9600.080699      9600.184597      9600.010288
# 2         3      1258.149140      3025.400426      2938.074613
# 3         4       170.613330        54.733004        41.134581
# 4         5       220.795008       538.053177       300.046997
# ...     ...              ...              ...              ...
# 9995   9996     18608.097787        25.863838       172.116870
# 9996   9997       110.131027        50.209194       110.876559
# 9997   9998       105.670172       106.346014       102.811690
# 9998   9999       826.113838      1401.266455      1643.462584
# 9999  10000       378.362607        78.919991        18.838446
#
#       SolveTime_default  SolveTime_best
# 0            104.393417       44.068493
# 1           9600.323414     9600.010288
# 2           9600.157577     1258.149140
# 3             83.344657       41.134581
# 4           5567.992290      220.795008
# ...                 ...             ...
# 9995          12.674720       12.674720
# 9996          18.379950       18.379950
# 9997          75.684641       75.684641
# 9998        1669.967257      826.113838
# 9999          22.112561       18.838446
#
# [10000 rows x 6 columns]

# %%
def correctify(x):
    if x >= 9600:
        return 9600
    else:
        return x
    
new_runtimes['SolveTime_best'] = new_runtimes['SolveTime_best'].apply(correctify)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\3516999053.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_best'] = new_runtimes['SolveTime_best'].apply(correctify)

# %%
new_runtimes['SolveTime_conf1'] = new_runtimes['SolveTime_conf1'].apply(correctify)
new_runtimes['SolveTime_conf2'] = new_runtimes['SolveTime_conf2'].apply(correctify)
new_runtimes['SolveTime_conf3'] = new_runtimes['SolveTime_conf3'].apply(correctify)
new_runtimes['SolveTime_default'] = new_runtimes['SolveTime_default'].apply(correctify)
new_runtimes
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\411108732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf1'] = new_runtimes['SolveTime_conf1'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\411108732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf2'] = new_runtimes['SolveTime_conf2'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\411108732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf3'] = new_runtimes['SolveTime_conf3'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\411108732.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_default'] = new_runtimes['SolveTime_default'].apply(correctify)
#          id  SolveTime_conf1  SolveTime_conf2  SolveTime_conf3  \
# 0         1       152.683291        44.068493        78.731996
# 1         2      9600.000000      9600.000000      9600.000000
# 2         3      1258.149140      3025.400426      2938.074613
# 3         4       170.613330        54.733004        41.134581
# 4         5       220.795008       538.053177       300.046997
# ...     ...              ...              ...              ...
# 9995   9996      9600.000000        25.863838       172.116870
# 9996   9997       110.131027        50.209194       110.876559
# 9997   9998       105.670172       106.346014       102.811690
# 9998   9999       826.113838      1401.266455      1643.462584
# 9999  10000       378.362607        78.919991        18.838446
#
#       SolveTime_default  SolveTime_best
# 0            104.393417       44.068493
# 1           9600.000000     9600.000000
# 2           9600.000000     1258.149140
# 3             83.344657       41.134581
# 4           5567.992290      220.795008
# ...                 ...             ...
# 9995          12.674720       12.674720
# 9996          18.379950       18.379950
# 9997          75.684641       75.684641
# 9998        1669.967257      826.113838
# 9999          22.112561       18.838446
#
# [10000 rows x 6 columns]

# %%
df['id'] = df.id.str.extract('(\d+)')
df['id'] = pd.to_numeric(df['id'])
df.sort_values(by='id', inplace=True, ignore_index=True)
df
# Out:
#                vbs           sbs     instances     id
# 0        44.068493     78.731996     78.931996      1
# 1     96000.000000  96000.000000  96000.000000      2
# 2      1258.149140   2938.074613   3025.617093      3
# 3        41.134581     41.134581     41.317914      4
# 4       220.795008    300.046997    302.263667      5
# ...            ...           ...           ...    ...
# 9995     12.674720    172.116870    172.266870   9996
# 9996     18.379950    110.876559    111.226559   9997
# 9997     75.684641    102.811690    102.995023   9998
# 9998    826.113838   1643.462584   1645.512584   9999
# 9999     18.838446     18.838446     19.021779  10000
#
# [10000 rows x 4 columns]

# %%
df = df.merge(new_runtimes, on='id')
df
# Out:
#                vbs           sbs     instances     id  SolveTime_conf1  \
# 0        44.068493     78.731996     78.931996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.617093      3      1258.149140
# 3        41.134581     41.134581     41.317914      4       170.613330
# 4       220.795008    300.046997    302.263667      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    172.266870   9996      9600.000000
# 9996     18.379950    110.876559    111.226559   9997       110.131027
# 9997     75.684641    102.811690    102.995023   9998       105.670172
# 9998    826.113838   1643.462584   1645.512584   9999       826.113838
# 9999     18.838446     18.838446     19.021779  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Okay, now let's plot parallel against instances (and vbs and sbs)

# %%
df.rename(columns={'instances':'autofolio'}, inplace=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# data
N = 10000
y = df.autofolio
x = df.sbs
c = x**2 + y**2

fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = 10, 10
ax.scatter(x, y, s=3, c='tab:blue')
ax.set_yscale('log')
ax.set_xscale('log')

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
#ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_ylabel("CPU time [s], " + y.name, fontsize=20)
ax.set_xlabel("CPU time [s], " + x.name, fontsize=20)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\2369322554.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
# Text(0.5, 0, 'CPU time [s], sbs')

# %%
print("SBS:", df.sbs.sum()/10000)
print("VBS:", df.vbs.sum()/10000)
print("Autofolio:", df.autofolio.sum()/10000)
# Out:
# SBS: 16482.56105497079
# VBS: 14830.814236654376
# Autofolio: 16502.795045861276

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means
#

# Cutoff solvetime_best at 2400

def cuttoff2400(x):
    if x >= 2400:
        return 2400
    else:
        return x
    
df['parallel'] = df['SolveTime_best'].apply(cuttoff2400)
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     78.931996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.617093      3      1258.149140
# 3        41.134581     41.134581     41.317914      4       170.613330
# 4       220.795008    300.046997    302.263667      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    172.266870   9996      9600.000000
# 9996     18.379950    110.876559    111.226559   9997       110.131027
# 9997     75.684641    102.811690    102.995023   9998       105.670172
# 9998    826.113838   1643.462584   1645.512584   9999       826.113838
# 9999     18.838446     18.838446     19.021779  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#          parallel
# 0       44.068493
# 1     2400.000000
# 2     1258.149140
# 3       41.134581
# 4      220.795008
# ...           ...
# 9995    12.674720
# 9996    18.379950
# 9997    75.684641
# 9998   826.113838
# 9999    18.838446
#
# [10000 rows x 10 columns]

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means
#

# multiply all values by 4
df['parallel'] = df['parallel']*4
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     78.931996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.617093      3      1258.149140
# 3        41.134581     41.134581     41.317914      4       170.613330
# 4       220.795008    300.046997    302.263667      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    172.266870   9996      9600.000000
# 9996     18.379950    110.876559    111.226559   9997       110.131027
# 9997     75.684641    102.811690    102.995023   9998       105.670172
# 9998    826.113838   1643.462584   1645.512584   9999       826.113838
# 9999     18.838446     18.838446     19.021779  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#          parallel
# 0      176.273972
# 1     9600.000000
# 2     5032.596560
# 3      164.538324
# 4      883.180032
# ...           ...
# 9995    50.698880
# 9996    73.519800
# 9997   302.738564
# 9998  3304.455352
# 9999    75.353784
#
# [10000 rows x 10 columns]

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means


# penalize anything that times out
def par10ify(x):
    if x >= 2400:
        return 96000
    else:
        return x
    
df['parallel'] = df['parallel'].apply(par10ify)
#df['parallel'] = df['SolveTime_best'].apply(par10ify)
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     78.931996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.617093      3      1258.149140
# 3        41.134581     41.134581     41.317914      4       170.613330
# 4       220.795008    300.046997    302.263667      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    172.266870   9996      9600.000000
# 9996     18.379950    110.876559    111.226559   9997       110.131027
# 9997     75.684641    102.811690    102.995023   9998       105.670172
# 9998    826.113838   1643.462584   1645.512584   9999       826.113838
# 9999     18.838446     18.838446     19.021779  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#           parallel
# 0       176.273972
# 1     96000.000000
# 2     96000.000000
# 3       164.538324
# 4       883.180032
# ...            ...
# 9995     50.698880
# 9996     73.519800
# 9997    302.738564
# 9998  96000.000000
# 9999     75.353784
#
# [10000 rows x 10 columns]

# %%
df.parallel.mean()*4 # it does not make any sense to compare with the parallel portfolio
# Out:
# 120479.24625584297

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# data
N = 10000
y = df.autofolio
x = df.parallel
c = x**2 + y**2

fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = 10, 10
ax.scatter(x, y, s=3, c='tab:blue')
ax.set_yscale('log')
ax.set_xscale('log')

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
#ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_ylabel("CPU time [s], " + y.name, fontsize=20)
ax.set_xlabel("CPU time [s], " + x.name, fontsize=20)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_8604\16693665.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
# Text(0.5, 0, 'CPU time [s], parallel')

# %%
# Compare with parallel
print("SBS:", df.sbs.sum()/10000)
print("VBS:", df.vbs.sum()/10000)
print("parallel:", df.parallel.sum()/10000)
print("Autofolio:", df.autofolio.sum()/10000)
# Out:
# SBS: 16482.56105497079
# VBS: 14830.814236654376
# parallel: 30119.811563960742
# Autofolio: 16502.795045861276

# %%
#plt.hist(df.instances, bins=10000)
#plt.xscale('log')
#plt.axvline(x=9600, ymin=0, ymax=0.95, color='r', label='axvline - % of full height')

# %%
# solved by one and not the other

def compare_solved(A, B, n_instances, timeout):
    '''
    Input: 
        - A: represents one method
        - B: represents the other method
        - n_instances: number of instances
        - timeout: Value of timeout (note if timeout is par10ified then include this as timeout e.g. par10 of 9600 is 96000)
    
    Output:
        - countA: Number of instances solved by A but not B
        - countB: Number of instances solved by B but not A
        - count0: Number of instances solved by neither method

    Solved: Solving in this case is does it reach the timeout or not?

    '''
    solvedbya = []
    notsolvedbya = []
    solvedbyb = []
    notsolvedbyb = []

    for i in range(n_instances):
        # selector A
        if A[i] == timeout:
            notsolvedbya.append(i)
        else:
            solvedbya.append(i)
        # selector B
        if B[i] == timeout:
            notsolvedbyb.append(i)
        else:
            solvedbyb.append(i)

    A_solved = set(solvedbya).difference(set(solvedbyb))
    B_solved = set(solvedbyb).difference(set(solvedbya))
    neither = set(notsolvedbya).intersection(set(notsolvedbyb))
    countA = len(A_solved)
    countB = len(B_solved)
    count0 = len(neither)
    return countA, countB, count0


compare_solved(A=df.autofolio, B=df.sbs, n_instances=10000, timeout=96000)
# Out:
# (5, 8, 1645)

# %%
def compare_times(A, B, n_instances):
    '''
    Input: 
        - A: represents one method
        - B: represents the other method
        - n_instances: number of instances
    
    Output:
        - countA: Number of instances solved faster by A 
        - countB: Number of instances solved faster by B 
        - count0: Number of instances solved by both equally fast

    Solved: Solving in this case is which method took less time?

    '''
    solvedbya = []
    solvedbyb = []
    equal = []

    for i in range(n_instances):
        if A[i] > B[i]:
            solvedbyb.append(i)
        elif A[i] < B[i]:
            solvedbya.append(i)
        else:
            equal.append(i)

    countA = len(solvedbya)
    countB = len(solvedbyb)
    count0 = len(equal)
    return countA, countB, count0


compare_times(A=df.autofolio, B=df.sbs, n_instances=10000)
# Out:
# (324, 7623, 2053)

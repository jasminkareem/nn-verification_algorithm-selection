# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Confusion matrix of autofolio schedules

# %%
schedule1 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/1_schedule.npy', allow_pickle=True)
schedule2 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/2_schedule.npy', allow_pickle=True)
schedule3 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/3_schedule.npy', allow_pickle=True)
schedule4 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/4_schedule.npy', allow_pickle=True)
schedule5 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/5_schedule.npy', allow_pickle=True)
schedule6 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/6_schedule.npy', allow_pickle=True)
schedule7 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/7_schedule.npy', allow_pickle=True)
schedule8 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/8_schedule.npy', allow_pickle=True)
schedule9 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/9_schedule.npy', allow_pickle=True)
schedule10 = np.load('C:/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/output_hhfeatures_48hs_nocost/10_schedule.npy', allow_pickle=True)

# %%
instance1 = list(schedule1.tolist().keys())
selection1 = list(schedule1.tolist().values())
instance2 = list(schedule2.tolist().keys())
selection2 = list(schedule2.tolist().values())
instance3 = list(schedule3.tolist().keys())
selection3 = list(schedule3.tolist().values())
instance4 = list(schedule4.tolist().keys())
selection4 = list(schedule4.tolist().values())
instance5 = list(schedule5.tolist().keys())
selection5 = list(schedule5.tolist().values())
instance6 = list(schedule6.tolist().keys())
selection6 = list(schedule6.tolist().values())
instance7 = list(schedule7.tolist().keys())
selection7 = list(schedule7.tolist().values())
instance8 = list(schedule8.tolist().keys())
selection8 = list(schedule8.tolist().values())
instance9 = list(schedule9.tolist().keys())
selection9 = list(schedule9.tolist().values())
instance10 = list(schedule10.tolist().keys())
selection10 = list(schedule10.tolist().values())

#pd.DataFrame({'instances': instance1, 'selection': selection1})

# %%
import itertools

merged_instances = itertools.chain(instance1, instance2, instance3, instance4, instance5, instance6, instance7, instance8, instance9, instance10)
merged_instances = list(merged_instances)

merged_selections = itertools.chain(selection1, selection2, selection3, selection4, selection5, selection6, selection7, selection8, selection9, selection10)
merged_selections = list(merged_selections)

# %%
new_merged_selections = []
for i in merged_selections:
    new_merged_selections.append(i[0][0])

# %%
import re
new_merged_instances = []
for i in merged_instances:
    new_merged_instances.append(int(re.findall(r'\d+', i)[0]))

# %%
runtimes = pd.read_excel('C:/Users/Jasmin/Documents/MSc-Thesis/Data/Runtime/Results-MIPVerify_SDPdMLPa.xlsx')
runtimes.head()
# Out:
#    SampleNumber  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
#
#        SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  SolveTime_conf3  \
# 0  InfeasibleOrUnbounded        44.068493        Infeasible        78.731996
# 1              UserLimit      9600.184597         UserLimit      9600.010288
# 2  InfeasibleOrUnbounded      3025.400426        Infeasible      2938.074613
# 3  InfeasibleOrUnbounded        54.733004        Infeasible        41.134581
# 4  InfeasibleOrUnbounded       538.053177        Infeasible       300.046997
#
#   SolveStatus_conf3  SolveTime_best      Config_best
# 0        Infeasible       44.068493  SolveTime_conf2
# 1         UserLimit     9600.010288          TIMEOUT
# 2        Infeasible     1258.149140  SolveTime_conf1
# 3        Infeasible       41.134581  SolveTime_conf3
# 4        Infeasible      220.795008  SolveTime_conf1

# %%
runtimes.rename(columns={'SampleNumber': 'instances'}, inplace=True)

# %%
runtimes
# Out:
#       instances  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
# ...         ...                ...                    ...              ...
# 9995       9996          12.674720  InfeasibleOrUnbounded     18608.097787
# 9996       9997          18.379950  InfeasibleOrUnbounded       110.131027
# 9997       9998          75.684641  InfeasibleOrUnbounded       105.670172
# 9998       9999        1669.967257  InfeasibleOrUnbounded       826.113838
# 9999      10000          22.112561  InfeasibleOrUnbounded       378.362607
#
#           SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  \
# 0     InfeasibleOrUnbounded        44.068493        Infeasible
# 1                 UserLimit      9600.184597         UserLimit
# 2     InfeasibleOrUnbounded      3025.400426        Infeasible
# 3     InfeasibleOrUnbounded        54.733004        Infeasible
# 4     InfeasibleOrUnbounded       538.053177        Infeasible
# ...                     ...              ...               ...
# 9995              UserLimit        25.863838        Infeasible
# 9996  InfeasibleOrUnbounded        50.209194        Infeasible
# 9997  InfeasibleOrUnbounded       106.346014        Infeasible
# 9998  InfeasibleOrUnbounded      1401.266455        Infeasible
# 9999  InfeasibleOrUnbounded        78.919991        Infeasible
#
#       SolveTime_conf3 SolveStatus_conf3  SolveTime_best        Config_best
# 0           78.731996        Infeasible       44.068493    SolveTime_conf2
# 1         9600.010288         UserLimit     9600.010288            TIMEOUT
# 2         2938.074613        Infeasible     1258.149140    SolveTime_conf1
# 3           41.134581        Infeasible       41.134581    SolveTime_conf3
# 4          300.046997        Infeasible      220.795008    SolveTime_conf1
# ...               ...               ...             ...                ...
# 9995       172.116870        Infeasible       12.674720  SolveTime_default
# 9996       110.876559        Infeasible       18.379950  SolveTime_default
# 9997       102.811690        Infeasible       75.684641  SolveTime_default
# 9998      1643.462584        Infeasible      826.113838    SolveTime_conf1
# 9999        18.838446        Infeasible       18.838446    SolveTime_conf3
#
# [10000 rows x 11 columns]

# %%
new_runtimes = runtimes[['instances', 'Config_best']]

# %%
afolio = pd.DataFrame({'instances': new_merged_instances, 'selection': new_merged_selections})

# %%
afolio = afolio.merge(new_runtimes, on='instances')

# %%
afolio
# Out:
#       instances selection        Config_best
# 0          1021   Config2    SolveTime_conf1
# 1          1022   Config2    SolveTime_conf1
# 2          1033   Config2  SolveTime_default
# 3          1048   Config2    SolveTime_conf2
# 4          1057   Config2    SolveTime_conf2
# ...         ...       ...                ...
# 9995       9949   Config3    SolveTime_conf1
# 9996       9968   Config3    SolveTime_conf3
# 9997       9970   Config3    SolveTime_conf1
# 9998       9973   Config3  SolveTime_default
# 9999       9995   Config3  SolveTime_default
#
# [10000 rows x 3 columns]

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf1", "Config_best"] = "Config1"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf2", "Config_best"] = "Config2"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_conf3", "Config_best"] = "Config3"

# %%
afolio.loc[afolio["Config_best"] == "SolveTime_default", "Config_best"] = "ConfigDefault"

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

print("accuracy:", accuracy_score(afolio['Config_best'], afolio['selection']))
#print("f1 score:", f1_score(y_true=afolio['Config_best'], y_pred=afolio['selection']))

plt.subplots(figsize=(11.5,7)) 
cm = confusion_matrix(afolio['Config_best'], afolio['selection'], labels=['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
#ax = plt.axes()
ax = sns.heatmap(cm, linewidth=0.5, annot=True, fmt='d')
ax.set_title("Confusion Matrix for Autofolio output using ARP features without feature costs")
ax.set_ylabel("Actual", fontsize=14, labelpad=20)
ax.set_xlabel("Prediction", fontsize=14, labelpad=20)
ax.xaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
ax.yaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3', 'TIMEOUT'])
plt.show()
# Out:
# accuracy: 0.3064

# %%
#remove timeouts
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

afolio.drop(afolio[afolio['Config_best'] == 'TIMEOUT'].index, inplace = True)


print("accuracy:", accuracy_score(afolio['Config_best'], afolio['selection']))

plt.subplots(figsize=(11.5,7)) 
cm = confusion_matrix(afolio['Config_best'], afolio['selection'], labels=['ConfigDefault', 'Config1', 'Config2', 'Config3'])
#ax = plt.axes()
ax = sns.heatmap(cm, linewidth=0.5, annot=True, fmt='d')
ax.set_title("Confusion Matrix for Autofolio output using ARP features without feature costs")
ax.set_ylabel("Actual", fontsize=14, labelpad=20)
ax.set_xlabel("Prediction", fontsize=14, labelpad=20)
ax.xaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3'])
ax.yaxis.set_ticklabels(['ConfigDefault', 'Config1', 'Config2', 'Config3'])
plt.show()
# Out:
# accuracy: 0.36038579157845213

# %% [markdown]
# ## Plot par10s

# %%
import pandas as pd
import numpy as np

# %%
id_order = pd.read_csv("output_hhfeatures_48hs/id_order.csv",names=['id'], header=0)
id_order.head()
# Out:
#         id
# 0  mip1021
# 1  mip1022
# 2  mip1033
# 3  mip1048
# 4  mip1057

# %%
vbs = pd.read_csv("output_hhfeatures_48hs_nocost/all_vbs.csv", names=['vbs'], header=0)
sbs = pd.read_csv("output_hhfeatures_48hs_nocost/all_sbs.csv", names=['sbs'],header=0)
instances = pd.read_csv("output_hhfeatures_48hs_nocost/all_instances.csv", names=['instances'], header=0)

df = [vbs,sbs,instances,id_order]
df = pd.concat(df, axis=1)
df.head()
# Out:
#           vbs          sbs    instances       id
# 0  237.739878   299.625810   305.625810  mip1021
# 1  181.373848   254.938741   260.938741  mip1022
# 2  809.615652  2575.033846  2581.033846  mip1033
# 3   28.995697    56.105023    62.105023  mip1048
# 4   76.865610    79.595654    85.595654  mip1057

# %%
# Before analyzing data check if timeouts are in PAR10, if not multiply all timeouts (9600) by 10
print(vbs.max())
print(sbs.max())
print(instances.max())
# Out:
# vbs    96000.0
# dtype: float64
# sbs    96000.0
# dtype: float64
# instances    96000.0
# dtype: float64

# %%
# Before analyzing data check if timeouts are in PAR10, if not multiply all timeouts (9600) by 10
def par10ify(x):
    if x >= 9600:
        return 96000
    else:
        return x
    

def par2ify(x):
    if x >= 9600:
        return 9600*2
    else:
        return x

#df['vbs'] = df['vbs'].apply(par10ify)
#df['sbs'] = df['sbs'].apply(par10ify)
#df['instances'] = df['instances'].apply(par10ify)
#df.head()

# %%
# Closed gap --> (sum(sbs) - sum(instances))/(sum(sbs) - sum(vbs))
closed_gap = (df.sbs.sum() - df.instances.sum())/(df.sbs.sum() - df.vbs.sum())
print(closed_gap)
# Out:
# -0.06963436797778923

# %%
df.sbs.sum()/10000
# Out:
# 16482.56105497079

# %%
df.vbs.sum()/10000
# Out:
# 14830.814236654376

# %%
df.instances.sum()/10000
# Out:
# 16597.579400723578

# %% [markdown]
# ## CHECK WITH RAW DATA IF THIS MAKES SENSE

# %%
runtimes = pd.read_excel('C:/Users/Jasmin/Documents/MSc-Thesis/Data/Runtime/Results-MIPVerify_SDPdMLPa.xlsx')
runtimes.head()
# Out:
#    SampleNumber  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0             1         104.393417  InfeasibleOrUnbounded       152.683291
# 1             2        9600.323414              UserLimit      9600.080699
# 2             3        9600.157577              UserLimit      1258.149140
# 3             4          83.344657  InfeasibleOrUnbounded       170.613330
# 4             5        5567.992290  InfeasibleOrUnbounded       220.795008
#
#        SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  SolveTime_conf3  \
# 0  InfeasibleOrUnbounded        44.068493        Infeasible        78.731996
# 1              UserLimit      9600.184597         UserLimit      9600.010288
# 2  InfeasibleOrUnbounded      3025.400426        Infeasible      2938.074613
# 3  InfeasibleOrUnbounded        54.733004        Infeasible        41.134581
# 4  InfeasibleOrUnbounded       538.053177        Infeasible       300.046997
#
#   SolveStatus_conf3  SolveTime_best      Config_best
# 0        Infeasible       44.068493  SolveTime_conf2
# 1         UserLimit     9600.010288          TIMEOUT
# 2        Infeasible     1258.149140  SolveTime_conf1
# 3        Infeasible       41.134581  SolveTime_conf3
# 4        Infeasible      220.795008  SolveTime_conf1

# %%
runtimes[['SampleNumber', 'SolveTime_best', 'SolveTime_conf3']].iloc[[0, 9, 99]]
# Out:
#     SampleNumber  SolveTime_best  SolveTime_conf3
# 0              1       44.068493        78.731996
# 9             10     9600.019248      9600.171495
# 99           100       80.580781       215.399513

# %%
list(runtimes[runtimes['SolveTime_best'] <= 237.739878]['SolveTime_best'])
# Out:
# [44.0684928894043,
#  41.1345810890197,
#  220.795007944107,
#  34.4942691326141,
#  48.7599289417266,
#  29.0571610927581,
#  58.4233419895172,
#  36.9728968143463,
#  160.456463813781,
#  178.678840875625,
#  69.7900259494781,
#  25.4225029945373,
#  40.51633810997,
#  57.7239501476287,
#  51.880163192749,
#  33.9573729038238,
#  92.8867070674896,
#  61.0818779468536,
#  66.5422399044036,
#  175.042777061462,
#  127.948179006576,
#  36.559473991394,
#  47.0929069519043,
#  89.4485659599304,
#  48.9369349479675,
#  186.844413042068,
#  120.579977989196,
#  26.7099730968475,
#  30.0771958827972,
#  211.685604810714,
#  35.6478881835937,
#  151.981482028961,
#  30.243446111679,
#  60.1966631412506,
#  32.6921069622039,
#  14.0914101600646,
#  1.55690383911132,
#  125.808505058288,
#  1.28328299522399,
#  27.6860258579254,
#  49.1663990020752,
#  29.0297229290008,
#  58.4375319480896,
#  50.6973598003387,
#  84.1579401493072,
#  57.0314531326294,
#  78.3019790649414,
#  67.9998760223388,
#  62.2631690502166,
#  140.996971845626,
#  52.0836851596832,
#  80.5807809829711,
#  56.9387710094451,
#  82.2296659946441,
#  62.6224579811096,
#  115.12180685997,
#  113.274147987365,
#  64.6409981250763,
#  1.8853600025177,
#  23.0886061191558,
#  63.6401920318603,
#  48.8819270133972,
#  1.0384669303894,
#  29.5620999336242,
#  43.9490699768066,
#  57.4050030708313,
#  38.1483879089355,
#  38.5806829929351,
#  24.2276229858398,
#  51.9538509845733,
#  49.20805311203,
#  11.7760949134826,
#  58.7999420166015,
#  40.3063721656799,
#  96.8775820732116,
#  203.173063039779,
#  41.0663559436798,
#  13.0527379512786,
#  42.4532849788665,
#  1.18768119812011,
#  230.182141065597,
#  48.2621059417724,
#  138.562971115112,
#  46.0044808387756,
#  71.3115720748901,
#  52.7682271003723,
#  53.6981999874115,
#  84.7409780025482,
#  68.2200670242309,
#  144.520895957946,
#  60.7354559898376,
#  65.0066411495208,
#  48.23872590065,
#  86.5869398117065,
#  208.244381904602,
#  157.738800048828,
#  15.135663986206,
#  57.3505420684814,
#  19.0329699516296,
#  31.3622021675109,
#  43.762332201004,
#  53.9335529804229,
#  139.810032844543,
#  17.7861821651458,
#  173.840636968612,
#  24.0537688732147,
#  213.227085828781,
#  65.6943190097808,
#  19.226516008377,
#  56.1520140171051,
#  95.811173915863,
#  47.6743810176849,
#  200.968932151794,
#  64.6704130172729,
#  159.967297077178,
#  10.2222199440002,
#  58.7138128280639,
#  39.224828004837,
#  56.8337299823761,
#  132.153182029724,
#  62.9503910541534,
#  31.66841506958,
#  1.78925108909606,
#  76.0072040557861,
#  94.1645579338073,
#  146.069154977798,
#  30.9422781467437,
#  12.1908609867095,
#  1.32232594490051,
#  29.3629269599914,
#  62.6543691158294,
#  49.5913889408111,
#  57.334625005722,
#  138.481973886489,
#  77.751195192337,
#  168.065828084945,
#  89.4304659366607,
#  70.8014059066772,
#  45.7263770103454,
#  45.857398033142,
#  47.001434803009,
#  102.070481061935,
#  43.9700999259948,
#  76.5771849155426,
#  25.7255809307098,
#  1.2263069152832,
#  41.1757328510284,
#  58.3078861236572,
#  60.9167439937591,
#  57.7624831199646,
#  28.3056421279907,
#  23.953565120697,
#  104.78858590126,
#  31.8528289794921,
#  57.4397511482238,
#  211.500416994094,
#  52.4801800251007,
#  21.8182981014251,
#  24.1333680152893,
#  1.21219396591186,
#  66.5209121704101,
#  44.0475339889526,
#  64.8584048748016,
#  200.231289863586,
#  1.31573915481567,
#  1.56723308563232,
#  58.6320312023162,
#  53.2433719635009,
#  65.6119570732116,
#  60.1796751022338,
#  189.548682928085,
#  1.04873418807983,
#  57.4291429519653,
#  69.976623058319,
#  48.1580238342285,
#  23.9253439903259,
#  43.5885729789733,
#  25.6636731624603,
#  0.92000412940979,
#  21.3616800308227,
#  192.472189188003,
#  16.4017820358276,
#  140.511029958724,
#  28.2703070640564,
#  1.10789489746093,
#  57.3782889842987,
#  60.1580162048339,
#  196.531347036361,
#  45.588168144226,
#  43.9004609584808,
#  223.662548065185,
#  57.9404709339141,
#  30.4161708354949,
#  139.09770488739,
#  107.162809133529,
#  56.6367161273956,
#  1.57679200172424,
#  33.3452432155609,
#  58.6942799091339,
#  22.5029640197753,
#  81.8747851848602,
#  52.476301908493,
#  127.15182518959,
#  171.667081832885,
#  37.0030179023742,
#  25.2529940605163,
#  82.2452929019928,
#  106.008154869079,
#  1.64320397377014,
#  106.228421926498,
#  20.2041699886322,
#  61.4662051200866,
#  78.6869530677795,
#  60.4563028812408,
#  26.4156241416931,
#  60.0614371299743,
#  90.9725968837738,
#  53.6909041404724,
#  144.732380867004,
#  170.750916957855,
#  190.722858905792,
#  99.4597768783569,
#  151.512444019317,
#  138.719219923019,
#  15.3782520294189,
#  27.8678770065307,
#  31.3026230335235,
#  92.5685601234436,
#  1.22401905059814,
#  84.1967558860778,
#  68.7064690589904,
#  0.9303879737854,
#  20.5846707820892,
#  80.045429944992,
#  192.944421052932,
#  53.9397900104522,
#  47.2434420585632,
#  125.028323888778,
#  16.1652719974517,
#  55.0638530254364,
#  19.6631331443786,
#  122.119511127471,
#  96.4916150569915,
#  213.766214132308,
#  219.178165912628,
#  107.739377975463,
#  33.0086131095886,
#  55.5902340412139,
#  59.9218070507049,
#  59.6914091110229,
#  1.27123498916625,
#  227.662833213806,
#  118.649693012237,
#  125.157105922698,
#  142.518267869949,
#  150.71578001976,
#  18.1973078250885,
#  42.0620040893554,
#  0.768026113510131,
#  152.26914691925,
#  37.8346529006958,
#  235.961787939071,
#  23.2638552188873,
#  205.358188152313,
#  196.953617811203,
#  25.3984339237213,
#  19.8294491767883,
#  186.07605600357,
#  51.4713888168334,
#  132.547671794891,
#  54.8919038772583,
#  58.2969381809234,
#  60.163712978363,
#  50.3371119499206,
#  53.6841828823089,
#  55.2405941486358,
#  157.790983200073,
#  123.083251953125,
#  23.9993059635162,
#  62.3565030097961,
#  1.74575209617614,
#  51.4379870891571,
#  59.1430070400238,
#  14.5640308856964,
#  2.08198308944702,
#  106.947963953018,
#  103.309659957885,
#  49.1977770328521,
#  196.560700178146,
#  22.3567378520965,
#  122.237200975418,
#  68.2342231273651,
#  1.39363884925842,
#  62.8512058258056,
#  55.3836648464202,
#  54.6308131217956,
#  166.59447813034,
#  59.9068579673767,
#  1.29030799865722,
#  28.6652910709381,
#  21.0665030479431,
#  1.43228411674499,
#  211.86436009407,
#  87.0659070014953,
#  151.249339103698,
#  52.9038050174713,
#  78.2055420875549,
#  51.5207359790802,
#  1.13115000724792,
#  26.1096458435058,
#  31.7931540012359,
#  178.053833007812,
#  111.590166091918,
#  82.3724811077117,
#  34.3005521297454,
#  29.0739910602569,
#  60.5228040218353,
#  40.6244800090789,
#  17.4226992130279,
#  1.06737399101257,
#  60.4611089229583,
#  13.0461409091949,
#  132.626091003417,
#  38.6924638748168,
#  93.5103831291198,
#  22.2693960666656,
#  84.5531370639801,
#  63.7620069980621,
#  27.651692867279,
#  61.5540609359741,
#  30.277153968811,
#  48.1095440387725,
#  49.8277559280395,
#  60.9316239356994,
#  70.6410620212555,
#  59.2427568435668,
#  31.1582019329071,
#  1.27922010421752,
#  106.495724916458,
#  49.5672771930694,
#  36.2328259944915,
#  53.1539430618286,
#  50.7211778163909,
#  30.0542449951171,
#  37.9280459880828,
#  1.30396890640258,
#  154.531421899795,
#  43.0910320281982,
#  38.1600968837738,
#  9.67333483695984,
#  41.4351501464843,
#  160.556365013122,
#  57.035943031311,
#  60.790323972702,
#  61.4232819080352,
#  21.8885848522186,
#  191.141948938369,
#  29.4838750362396,
#  188.285678148269,
#  1.23537611961364,
#  39.1275980472564,
#  28.5656769275665,
#  0.992204904556274,
#  52.0302739143371,
#  49.5064141750335,
#  117.929044961929,
#  148.420786142349,
#  32.4050340652465,
#  118.282612085342,
#  50.8032200336456,
#  118.656131982803,
#  1.26251292228698,
#  95.4633090496063,
#  62.4968290328979,
#  24.9896731376647,
#  52.749310016632,
#  220.84176492691,
#  77.3547809123992,
#  1.27126908302307,
#  34.4765148162841,
#  56.3452351093292,
#  1.20383095741271,
#  109.875840902328,
#  229.259752988815,
#  198.625273942947,
#  67.9978730678558,
#  53.3062679767608,
#  49.4657270908355,
#  118.980818986892,
#  18.3726089000701,
#  227.441428899765,
#  1.45835995674133,
#  119.675942897796,
#  57.9517259597778,
#  131.357944965362,
#  91.8356900215148,
#  153.678984880447,
#  88.1943681240081,
#  64.4898240566253,
#  62.0556819438934,
#  44.3819890022277,
#  94.370579957962,
#  72.5317738056182,
#  90.912052154541,
#  111.156290054321,
#  53.3422949314117,
#  145.489194154739,
#  129.401996850967,
#  74.8691890239715,
#  102.895769834518,
#  58.8697688579559,
#  57.5714311599731,
#  50.2298882007598,
#  132.629800081253,
#  57.3304049968719,
#  45.6457331180572,
#  130.378127098083,
#  60.9263770580291,
#  51.9873220920562,
#  210.571322917938,
#  75.3044040203094,
#  173.846713066101,
#  105.352187156677,
#  40.7691431045532,
#  26.0675599575042,
#  23.3691399097442,
#  18.0861909389495,
#  67.7987949848175,
#  18.7576959133148,
#  133.435503005981,
#  46.8120191097259,
#  132.366901874542,
#  19.6283180713653,
#  46.2651391029357,
#  25.0789079666137,
#  7.65700197219848,
#  61.8198969364166,
#  61.1187698841095,
#  53.0900380611419,
#  102.303458929061,
#  23.759967803955,
#  53.0931730270385,
#  56.2887330055236,
#  36.4034600257873,
#  208.351505041122,
#  97.0159680843353,
#  33.5799269676208,
#  36.0752379894256,
#  55.5152540206909,
#  10.7732458114624,
#  61.8391950130462,
#  157.192665100097,
#  141.963616132736,
#  33.5457069873809,
#  1.25774693489074,
#  127.253851890563,
#  27.6826679706573,
#  1.70222496986389,
#  19.3154509067535,
#  35.9792580604553,
#  93.0337209701538,
#  82.9885320663452,
#  52.142851114273,
#  42.6346909999847,
#  71.2885739803314,
#  31.3843719959259,
#  51.9645600318908,
#  36.8416278362274,
#  154.690410852432,
#  51.2503521442413,
#  87.2312769889831,
#  60.5516300201416,
#  26.5115201473236,
#  50.740942955017,
#  22.8645780086517,
#  37.7552640438079,
#  132.264946937561,
#  44.1748058795928,
#  161.539710998535,
#  149.639333009719,
#  1.19975590705871,
#  1.47162508964538,
#  75.9334640502929,
#  48.9299569129943,
#  110.86761689186,
#  45.8585970401763,
#  106.956907987594,
#  56.9727411270141,
#  29.7977750301361,
#  169.917777061462,
#  55.9274668693542,
#  125.504518985748,
#  215.637361049652,
#  58.6122651100158,
#  121.995558977127,
#  51.6049818992614,
#  34.3209869861602,
#  24.6790089607238,
#  44.4409871101379,
#  33.2830998897552,
#  52.0912528038024,
#  55.0065109729766,
#  58.3174798488616,
#  143.66209411621,
#  70.4175200462341,
#  40.9635860919952,
#  38.0579459667205,
#  2.04989981651306,
#  49.9550681114196,
#  47.9621589183807,
#  150.419178009033,
#  90.6122789382934,
#  112.727712154388,
#  164.827778816223,
#  145.93668603897,
#  59.4477710723876,
#  1.26276993751525,
#  2.77982091903686,
#  66.8852379322052,
#  40.6406300067901,
#  22.7170848846435,
#  0.99932312965393,
#  178.760981082916,
#  1.18634605407714,
#  46.4674861431121,
#  1.43128299713134,
#  53.4589290618896,
#  1.45744204521179,
#  141.814720153808,
#  81.3173398971557,
#  81.271152973175,
#  26.2937638759613,
#  18.1943039894104,
#  39.3063731193542,
#  66.6119589805603,
#  29.4584109783172,
#  51.2809150218963,
#  18.6835660934448,
#  53.797523021698,
#  32.9463970661163,
#  100.339653968811,
#  71.4652259349823,
#  71.2755749225616,
#  230.053086996078,
#  59.0241630077362,
#  69.1748988628387,
#  28.0835189819335,
#  27.5658061504364,
#  52.0837748050689,
#  75.3951029777526,
#  67.7905218601226,
#  62.4112071990966,
#  23.0151998996734,
#  53.4462161064148,
#  55.5502598285675,
#  5.12095785140991,
#  1.37371921539306,
#  60.3204169273376,
#  237.739877939224,
#  181.373847961425,
#  53.8132979869842,
#  58.6358478069305,
#  86.8344709873199,
#  135.601101875305,
#  39.0256700515747,
#  85.6456251144409,
#  22.3991451263427,
#  119.975617885589,
#  73.1507239341735,
#  109.712433099746,
#  17.7048850059509,
#  193.026839017868,
#  2.48674321174621,
#  51.1424279212951,
#  53.3502080440521,
#  159.284811973571,
#  28.9956970214843,
#  16.5407409667968,
#  3.18193101882934,
#  126.639019966125,
#  46.9188101291656,
#  76.8656101226806,
#  193.925990819931,
#  32.6157159805297,
#  43.033143043518,
#  14.1999127864837,
#  1.78687191009521,
#  59.6349589824676,
#  37.3678860664367,
#  78.6371490955352,
#  66.66424202919,
#  20.705705165863,
#  23.9453561305999,
#  123.604236125946,
#  30.8477439880371,
#  69.1238029003143,
#  1.02583813667297,
#  63.304307937622,
#  77.8203771114349,
#  150.41296505928,
#  81.6251780986785,
#  1.32338690757751,
#  131.288563013076,
#  67.894248008728,
#  30.772782087326,
#  1.15339112281799,
#  54.7248690128326,
#  0.914527893066406,
#  87.4159648418426,
#  1.02922010421752,
#  70.6262490749359,
#  38.3515148162841,
#  48.8288090229034,
#  49.0576288700103,
#  47.9250330924987,
#  48.9459300041198,
#  56.6851060390472,
#  59.8936359882354,
#  55.8210859298706,
#  89.5233461856842,
#  25.0190980434417,
#  146.191797971725,
#  49.921805858612,
#  50.5610101222992,
#  56.0414519309997,
#  52.6464538574218,
#  32.6189761161804,
#  128.801043987274,
#  29.6899700164794,
#  30.5682270526886,
#  104.708482980728,
#  54.8283059597015,
#  115.167351961135,
#  69.6740419864654,
#  67.2298109531402,
#  13.7848398685455,
#  66.8162009716034,
#  58.5034508705139,
#  45.67791390419,
#  44.4990298748016,
#  23.3723499774932,
#  1.12130403518676,
#  191.512253046035,
#  84.0200281143188,
#  27.4245729446411,
#  54.1590588092804,
#  1.14805483818054,
#  1.29661893844604,
#  115.898217916488,
#  1.3652319908142,
#  66.3166091442108,
#  48.262923002243,
#  138.146667003631,
#  1.16720390319824,
#  64.9991729259491,
#  1.58033895492553,
#  103.686694860458,
#  1.13938283920288,
#  39.8014740943908,
#  0.956226110458374,
#  70.8282809257507,
#  0.911809921264648,
#  42.1724181175231,
#  20.4180219173431,
#  96.8898158073425,
#  76.9678950309753,
#  47.8658850193023,
#  55.4454820156097,
#  29.4565069675445,
#  78.8129320144653,
#  14.6694581508636,
#  1.09806203842163,
#  65.4475018978118,
#  1.24561595916748,
#  72.1120190620422,
#  30.385085105896,
#  28.8545172214508,
#  1.39301419258117,
#  34.2115528583526,
#  112.208168029785,
#  82.4656620025634,
#  55.2763249874115,
#  40.243763923645,
#  27.9048371315002,
#  1.51316404342651,
#  1.84388995170593,
#  133.013876914978,
#  0.952370882034301,
#  1.43426489830017,
#  32.0200769901275,
#  21.1626460552215,
#  127.774790048599,
#  56.0665009021759,
#  99.2649109363556,
#  61.4767041206359,
#  1.30561399459838,
#  120.55922293663,
#  197.631180047988,
#  54.4437170028686,
#  137.516480922698,
#  97.9769630432128,
#  28.4770700931549,
#  151.497428178787,
#  35.1692860126495,
#  1.89126896858215,
#  148.829607963562,
#  194.003399133682,
#  59.007364988327,
#  59.9244430065155,
#  97.3450951576232,
#  118.788699150085,
#  49.7620449066162,
#  1.35982680320739,
#  123.986238956451,
#  32.3296389579772,
#  100.062922000885,
#  14.765625,
#  1.80540704727172,
#  99.1422901153564,
#  22.0912690162658,
#  1.88190793991088,
#  1.29314994812011,
#  1.55446910858154,
#  193.31335401535,
#  31.9213140010833,
#  56.322641134262,
#  22.2334871292114,
#  50.7789070606231,
#  33.423691034317,
#  0.929999113082885,
#  151.067687988281,
#  207.061920881271,
#  25.4604058265686,
#  57.3679900169372,
#  203.373199939727,
#  72.9086830615997,
#  16.7578690052032,
#  163.150228023529,
#  110.200889110565,
#  101.632198095321,
#  94.6060750484466,
#  146.343863010406,
#  91.460214138031,
#  181.229912996292,
#  86.6451768875122,
#  117.451148033142,
#  119.904247045516,
#  26.2498898506164,
#  70.0737829208374,
#  57.3794689178466,
#  28.2772450447082,
#  61.9130690097808,
#  29.3308918476104,
#  46.8123149871826,
#  94.307853937149,
#  66.901859998703,
#  30.3849129676818,
#  34.8017261028289,
#  45.0755100250244,
#  51.0708780288696,
#  26.1670229434967,
#  26.1623439788818,
#  20.015487909317,
#  35.2923181056976,
#  179.811319112777,
#  46.0400710105896,
#  36.2721271514892,
#  14.8455650806427,
#  122.200653076171,
#  85.0228691101074,
#  15.4059867858886,
#  110.060256958007,
#  1.58442306518554,
#  1.14029884338378,
#  19.4873650074005,
#  22.0295388698577,
#  49.5757431983947,
#  146.937590122222,
#  59.9932358264923,
#  1.13775897026062,
#  35.2255239486694,
#  225.630917072296,
#  1.14319205284118,
#  63.406128168106,
#  56.7760870456695,
#  63.8131549358367,
#  50.1376299858093,
#  70.3958859443664,
#  1.27224016189575,
#  23.4063651561737,
#  17.2874228954315,
#  115.440865993499,
#  102.47059392929,
#  23.8066670894622,
#  13.664764881134,
#  149.380191087722,
#  34.7855129241943,
#  13.428472995758,
#  29.6819200515747,
#  105.867459058761,
#  1.07232403755188,
#  1.45076394081115,
#  52.3798711299896,
#  81.9314348697662,
#  84.5044479370117,
#  47.7603900432586,
#  210.851545095443,
#  23.8936760425567,
#  28.7305850982666,
#  44.0585460662841,
#  30.0924890041351,
#  80.7495229244232,
#  72.1237609386444,
#  31.1289780139923,
#  171.199959039688,
#  1.51787400245666,
#  38.2136070728302,
#  24.0384860038757,
#  1.91479396820068,
#  69.6887638568878,
#  51.7216579914093,
#  92.1376559734344,
#  88.181261062622,
#  116.67131614685,
#  23.0010070800781,
#  56.1354930400848,
#  52.1828589439392,
#  60.7366349697113,
#  49.6439168453216,
#  0.98632788658142,
#  28.8429079055786,
#  1.45926809310913,
#  114.159580945968,
#  48.95183801651,
#  1.02654099464416,
#  103.9951338768,
#  29.3760509490966,
#  20.8550748825073,
#  59.9467940330505,
#  113.254565954208,
#  55.5286040306091,
#  60.9273800849914,
#  78.3734230995178,
#  88.4002780914306,
#  213.465574026107,
#  0.981348037719726,
#  132.569324970245,
#  1.95526695251464,
#  117.981842994689,
#  1.94264698028564,
#  50.4156339168548,
#  43.4476838111877,
#  52.4767470359802,
#  18.5213189125061,
#  84.1852240562439,
#  12.4871270656585,
#  1.13436484336853,
#  66.0838470458984,
#  24.375282049179,
#  50.272145986557,
#  186.863147974014,
#  1.74519777297973,
#  154.549944877624,
#  26.6300511360168,
#  96.8708310127258,
#  58.388580083847,
#  20.6209180355072,
#  34.3305461406707,
#  59.7146270275116,
#  30.3652131557464,
#  59.9795467853546,
#  33.6541118621826,
#  66.1699209213256,
#  51.4051361083984,
#  25.3954219818115,
#  41.7888040542602,
#  1.08271098136901,
#  22.8154509067535,
#  88.4256560802459,
#  51.1635730266571,
#  31.4324848651886,
#  30.1824519634246,
#  1.33440399169921,
#  217.119104146957,
#  52.2973818778991,
#  62.5411269664764,
#  171.494017839431,
#  28.0340640544891,
#  148.058295965194,
#  29.9359469413757,
#  59.1799759864807,
#  179.963067054748,
#  55.1519088745117,
#  40.0048449039459,
#  74.9760661125183,
#  58.7264211177825,
#  226.360706090927,
#  152.627534866333,
#  60.2620999813079,
#  79.1920440196991,
#  89.9024648666381,
#  58.764760017395,
#  19.3801538944244,
#  218.827057123184,
#  193.509994029998,
#  45.3757619857788,
#  27.075294971466,
#  55.8004601001739,
#  64.796450138092,
#  142.317212104797,
#  41.1488089561462,
#  53.6636400222778,
#  173.524410963058,
#  1.66436600685119,
#  55.9087669849395,
#  34.8820278644561,
#  1.62340879440307,
#  145.747239828109,
#  42.1619639396667,
#  37.4735691547393,
#  50.6542670726776,
#  48.2632639408111,
#  35.4388420581817,
#  43.9987790584564,
#  46.2230720520019,
#  96.7946741580963,
#  41.315689086914,
#  1.5338180065155,
#  48.3841078281402,
#  75.0541980266571,
#  47.8563799858093,
#  202.941551923751,
#  0.858901977539062,
#  4.67845392227172,
#  45.1317720413208,
#  61.9582970142364,
#  1.31192016601562,
#  21.9222381114959,
#  124.525882959365,
#  39.5588989257812,
#  127.562391042709,
#  76.9244601726532,
#  1.37225079536438,
#  64.9438199996948,
#  27.0056228637695,
#  1.47922492027282,
#  52.503347158432,
#  121.511835098266,
#  79.3957409858703,
#  132.748879194259,
#  174.715381145477,
#  1.25607085227966,
#  72.4033818244934,
#  134.381942033767,
#  78.2874419689178,
#  103.404415130615,
#  30.4840710163116,
#  180.482752799987,
#  54.0111949443817,
#  98.4154090881347,
#  22.965833902359,
#  1.62167692184448,
#  188.946712970733,
#  233.227854013443,
#  1.95174598693847,
#  80.0528039932251,
#  59.6485500335693,
#  105.979728937149,
#  1.825856924057,
#  64.1976089477539,
#  30.6811869144439,
#  34.5013101100921,
#  49.3479731082916,
#  48.2509450912475,
#  36.7364881038665,
#  35.9614799022674,
#  109.039040803909,
#  74.5466699600219,
#  153.376022100448,
#  136.886209964752,
#  1.2118170261383,
#  39.5730810165405,
#  49.7656898498535,
#  22.690335035324,
#  21.3402771949768,
#  48.785521030426,
#  61.2950961589813,
#  1.02372908592224,
#  111.457609891891,
#  111.462203025817,
#  130.040166139602,
#  49.5170221328735,
#  57.8319590091705,
#  174.110554218292,
#  46.5155069828033,
#  25.9402158260345,
#  192.867338895797,
#  44.0635800361633,
#  60.3445649147033,
#  1.49069809913635,
#  ...]

# %%
#runtimes['SolveTime_best'] = runtimes['SolveTime_best'].apply(par10ify)
#check_parallel = runtimes.SolveTime_best * 4

# %%
#print(check_parallel.sum()/10000)

# %%
new_runtimes = runtimes[['SampleNumber', 'SolveTime_conf1', 'SolveTime_conf2', 'SolveTime_conf3', 'SolveTime_default', 'SolveTime_best']]
new_runtimes.rename(columns={'SampleNumber':'id'}, inplace=True)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\520049881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes.rename(columns={'SampleNumber':'id'}, inplace=True)

# %%
new_runtimes
# Out:
#          id  SolveTime_conf1  SolveTime_conf2  SolveTime_conf3  \
# 0         1       152.683291        44.068493        78.731996
# 1         2      9600.080699      9600.184597      9600.010288
# 2         3      1258.149140      3025.400426      2938.074613
# 3         4       170.613330        54.733004        41.134581
# 4         5       220.795008       538.053177       300.046997
# ...     ...              ...              ...              ...
# 9995   9996     18608.097787        25.863838       172.116870
# 9996   9997       110.131027        50.209194       110.876559
# 9997   9998       105.670172       106.346014       102.811690
# 9998   9999       826.113838      1401.266455      1643.462584
# 9999  10000       378.362607        78.919991        18.838446
#
#       SolveTime_default  SolveTime_best
# 0            104.393417       44.068493
# 1           9600.323414     9600.010288
# 2           9600.157577     1258.149140
# 3             83.344657       41.134581
# 4           5567.992290      220.795008
# ...                 ...             ...
# 9995          12.674720       12.674720
# 9996          18.379950       18.379950
# 9997          75.684641       75.684641
# 9998        1669.967257      826.113838
# 9999          22.112561       18.838446
#
# [10000 rows x 6 columns]

# %%
def correctify(x):
    if x >= 9600:
        return 9600
    else:
        return x
    
new_runtimes['SolveTime_best'] = new_runtimes['SolveTime_best'].apply(correctify)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\3516999053.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_best'] = new_runtimes['SolveTime_best'].apply(correctify)

# %%
new_runtimes['SolveTime_conf1'] = new_runtimes['SolveTime_conf1'].apply(correctify)
new_runtimes['SolveTime_conf2'] = new_runtimes['SolveTime_conf2'].apply(correctify)
new_runtimes['SolveTime_conf3'] = new_runtimes['SolveTime_conf3'].apply(correctify)
new_runtimes['SolveTime_default'] = new_runtimes['SolveTime_default'].apply(correctify)
new_runtimes
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\411108732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf1'] = new_runtimes['SolveTime_conf1'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\411108732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf2'] = new_runtimes['SolveTime_conf2'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\411108732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_conf3'] = new_runtimes['SolveTime_conf3'].apply(correctify)
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\411108732.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_runtimes['SolveTime_default'] = new_runtimes['SolveTime_default'].apply(correctify)
#          id  SolveTime_conf1  SolveTime_conf2  SolveTime_conf3  \
# 0         1       152.683291        44.068493        78.731996
# 1         2      9600.000000      9600.000000      9600.000000
# 2         3      1258.149140      3025.400426      2938.074613
# 3         4       170.613330        54.733004        41.134581
# 4         5       220.795008       538.053177       300.046997
# ...     ...              ...              ...              ...
# 9995   9996      9600.000000        25.863838       172.116870
# 9996   9997       110.131027        50.209194       110.876559
# 9997   9998       105.670172       106.346014       102.811690
# 9998   9999       826.113838      1401.266455      1643.462584
# 9999  10000       378.362607        78.919991        18.838446
#
#       SolveTime_default  SolveTime_best
# 0            104.393417       44.068493
# 1           9600.000000     9600.000000
# 2           9600.000000     1258.149140
# 3             83.344657       41.134581
# 4           5567.992290      220.795008
# ...                 ...             ...
# 9995          12.674720       12.674720
# 9996          18.379950       18.379950
# 9997          75.684641       75.684641
# 9998        1669.967257      826.113838
# 9999          22.112561       18.838446
#
# [10000 rows x 6 columns]

# %%
df['id'] = df.id.str.extract('(\d+)')
df['id'] = pd.to_numeric(df['id'])
df.sort_values(by='id', inplace=True, ignore_index=True)
df
# Out:
#                vbs           sbs     instances     id
# 0        44.068493     78.731996     80.731996      1
# 1     96000.000000  96000.000000  96000.000000      2
# 2      1258.149140   2938.074613   3025.400426      3
# 3        41.134581     41.134581     43.134581      4
# 4       220.795008    300.046997    538.053177      5
# ...            ...           ...           ...    ...
# 9995     12.674720    172.116870    174.116870   9996
# 9996     18.379950    110.876559    116.876559   9997
# 9997     75.684641    102.811690    104.811690   9998
# 9998    826.113838   1643.462584   1643.462584   9999
# 9999     18.838446     18.838446     18.838446  10000
#
# [10000 rows x 4 columns]

# %%
df = df.merge(new_runtimes, on='id')
df
# Out:
#                vbs           sbs     instances     id  SolveTime_conf1  \
# 0        44.068493     78.731996     80.731996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.400426      3      1258.149140
# 3        41.134581     41.134581     43.134581      4       170.613330
# 4       220.795008    300.046997    538.053177      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    174.116870   9996      9600.000000
# 9996     18.379950    110.876559    116.876559   9997       110.131027
# 9997     75.684641    102.811690    104.811690   9998       105.670172
# 9998    826.113838   1643.462584   1643.462584   9999       826.113838
# 9999     18.838446     18.838446     18.838446  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
# [10000 rows x 9 columns]

# %%
df.rename(columns={'instances': 'autofolio'}, inplace=True)

# %% [markdown]
# ## Okay, now let's plot parallel against instances (and vbs and sbs)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# data
N = 10000
y = df.autofolio
x = df.sbs
c = x**2 + y**2

fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = 10, 10
ax.scatter(x, y, s=3, c='tab:blue')
ax.set_yscale('log')
ax.set_xscale('log')

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
#ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_ylabel("CPU time [s], " + y.name, fontsize=20)
ax.set_xlabel("CPU time [s], " + x.name, fontsize=20)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\2369322554.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
# Text(0.5, 0, 'CPU time [s], sbs')

# %%
print("SBS:", df.sbs.sum()/10000)
print("VBS:", df.vbs.sum()/10000)
print("Autofolio:", df.autofolio.sum()/10000)
# Out:
# SBS: 16482.56105497079
# VBS: 14830.814236654376
# Autofolio: 16597.579400723578

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means
#

# Cutoff solvetime_best at 2400

def cuttoff2400(x):
    if x >= 2400:
        return 2400
    else:
        return x
    
df['parallel'] = df['SolveTime_best'].apply(cuttoff2400)
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     80.731996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.400426      3      1258.149140
# 3        41.134581     41.134581     43.134581      4       170.613330
# 4       220.795008    300.046997    538.053177      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    174.116870   9996      9600.000000
# 9996     18.379950    110.876559    116.876559   9997       110.131027
# 9997     75.684641    102.811690    104.811690   9998       105.670172
# 9998    826.113838   1643.462584   1643.462584   9999       826.113838
# 9999     18.838446     18.838446     18.838446  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#          parallel
# 0       44.068493
# 1     2400.000000
# 2     1258.149140
# 3       41.134581
# 4      220.795008
# ...           ...
# 9995    12.674720
# 9996    18.379950
# 9997    75.684641
# 9998   826.113838
# 9999    18.838446
#
# [10000 rows x 10 columns]

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means
#

# multiply all values by 4
df['parallel'] = df['parallel']*4
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     80.731996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.400426      3      1258.149140
# 3        41.134581     41.134581     43.134581      4       170.613330
# 4       220.795008    300.046997    538.053177      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    174.116870   9996      9600.000000
# 9996     18.379950    110.876559    116.876559   9997       110.131027
# 9997     75.684641    102.811690    104.811690   9998       105.670172
# 9998    826.113838   1643.462584   1643.462584   9999       826.113838
# 9999     18.838446     18.838446     18.838446  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#          parallel
# 0      176.273972
# 1     9600.000000
# 2     5032.596560
# 3      164.538324
# 4      883.180032
# ...           ...
# 9995    50.698880
# 9996    73.519800
# 9997   302.738564
# 9998  3304.455352
# 9999    75.353784
#
# [10000 rows x 10 columns]

# %%
# solvetime_best -> cutoff at 2400 (9600/4)
# multiply all values by 4
# calculate par10s (penalize)
# Compare the means


# penalize anything that times out
def par10ify(x):
    if x >= 2400:
        return 96000
    else:
        return x
    
df['parallel'] = df['parallel'].apply(par10ify)
#df['parallel'] = df['SolveTime_best'].apply(par10ify)
df
# Out:
#                vbs           sbs     autofolio     id  SolveTime_conf1  \
# 0        44.068493     78.731996     80.731996      1       152.683291
# 1     96000.000000  96000.000000  96000.000000      2      9600.000000
# 2      1258.149140   2938.074613   3025.400426      3      1258.149140
# 3        41.134581     41.134581     43.134581      4       170.613330
# 4       220.795008    300.046997    538.053177      5       220.795008
# ...            ...           ...           ...    ...              ...
# 9995     12.674720    172.116870    174.116870   9996      9600.000000
# 9996     18.379950    110.876559    116.876559   9997       110.131027
# 9997     75.684641    102.811690    104.811690   9998       105.670172
# 9998    826.113838   1643.462584   1643.462584   9999       826.113838
# 9999     18.838446     18.838446     18.838446  10000       378.362607
#
#       SolveTime_conf2  SolveTime_conf3  SolveTime_default  SolveTime_best  \
# 0           44.068493        78.731996         104.393417       44.068493
# 1         9600.000000      9600.000000        9600.000000     9600.000000
# 2         3025.400426      2938.074613        9600.000000     1258.149140
# 3           54.733004        41.134581          83.344657       41.134581
# 4          538.053177       300.046997        5567.992290      220.795008
# ...               ...              ...                ...             ...
# 9995        25.863838       172.116870          12.674720       12.674720
# 9996        50.209194       110.876559          18.379950       18.379950
# 9997       106.346014       102.811690          75.684641       75.684641
# 9998      1401.266455      1643.462584        1669.967257      826.113838
# 9999        78.919991        18.838446          22.112561       18.838446
#
#           parallel
# 0       176.273972
# 1     96000.000000
# 2     96000.000000
# 3       164.538324
# 4       883.180032
# ...            ...
# 9995     50.698880
# 9996     73.519800
# 9997    302.738564
# 9998  96000.000000
# 9999     75.353784
#
# [10000 rows x 10 columns]

# %%
df.parallel.mean()*4
# Out:
# 120479.24625584297

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set()

# data
N = 10000
y = df.autofolio
x = df.parallel
c = x**2 + y**2

fig, ax = plt.subplots()
plt.rcParams['figure.figsize'] = 10, 10
ax.scatter(x, y, s=3, c='tab:blue')
ax.set_yscale('log')
ax.set_xscale('log')

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
#ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
ax.set_ylabel("CPU time [s], " + y.name, fontsize=20)
ax.set_xlabel("CPU time [s], " + x.name, fontsize=20)
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_15344\16693665.py:24: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(lims, lims, 'k-', alpha=0.75, c='tab:blue')
# Text(0.5, 0, 'CPU time [s], parallel')

# %%
# Compare with parallel
print("SBS:", df.sbs.sum()/10000)
print("VBS:", df.vbs.sum()/10000)
print("parallel:", df.parallel.sum()/10000)
print("Autofolio:", df.autofolio.sum()/10000)
# Out:
# SBS: 16482.56105497079
# VBS: 14830.814236654376
# parallel: 30119.811563960742
# Autofolio: 16597.579400723578

# %%
#plt.hist(df.instances, bins=10000)
#plt.xscale('log')
#plt.axvline(x=9600, ymin=0, ymax=0.95, color='r', label='axvline - % of full height')

# %%
# solved by one and not the other

def compare_solved(A, B, n_instances, timeout):
    solvedbya = []
    notsolvedbya = []
    solvedbyb = []
    notsolvedbyb = []

    for i in range(n_instances):
        # selector A
        if A[i] == timeout:
            notsolvedbya.append(i)
        else:
            solvedbya.append(i)
        # selector B
        if B[i] == timeout:
            notsolvedbyb.append(i)
        else:
            solvedbyb.append(i)

    A_solved = set(solvedbya).difference(set(solvedbyb))
    B_solved = set(solvedbyb).difference(set(solvedbya))
    neither = set(notsolvedbya).intersection(set(notsolvedbyb))
    countA = len(A_solved)
    countB = len(B_solved)
    count0 = len(neither)
    return countA, countB, count0


compare_solved(A=df.autofolio, B=df.sbs, n_instances=10000, timeout=96000)
# Out:
# (8, 22, 1642)

# %%
def compare_times(A, B, n_instances):
    '''
    Input: 
        - A: represents one method
        - B: represents the other method
        - n_instances: number of instances
    
    Output:
        - countA: Number of instances solved faster by A 
        - countB: Number of instances solved faster by B 
        - count0: Number of instances solved by both equally fast

    Solved: Solving in this case is which method took less time?

    '''
    solvedbya = []
    solvedbyb = []
    equal = []

    for i in range(n_instances):
        if A[i] > B[i]:
            solvedbyb.append(i)
        elif A[i] < B[i]:
            solvedbya.append(i)
        else:
            equal.append(i)

    countA = len(solvedbya)
    countB = len(solvedbyb)
    count0 = len(equal)
    return countA, countB, count0


compare_times(A=df.autofolio, B=df.sbs, n_instances=10000)
# Out:
# (504, 1999, 7497)

# %% [markdown]
# ## Process CSV file into a CSV file that can be turned into an ASlib scenario: SCIP Features

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Jasmin/Documents/MSc-Thesis/Feature_Extraction/feature_data_rp/RP_scip_dataclean_12.csv')
df.drop(columns='Unnamed: 0',inplace=True)
df.head()
# Out:
#    INSTANCE_NAME  VARS_presolve_default  BIN_VARS_presolve_default  \
# 0              1                 1437.0                      330.0
# 1             10                 1403.0                      313.0
# 2            100                 1399.0                      311.0
# 3           1000                 1443.0                      333.0
# 4          10000                 1329.0                      276.0
#
#    CONT_VARS_presolve_default  UPPERBOUNDS_MEAN_presolve_default  \
# 0                      1107.0                           0.452455
# 1                      1090.0                           0.459198
# 2                      1088.0                           0.432643
# 3                      1110.0                           0.466921
# 4                      1053.0                           0.423002
#
#    UPPERBOUNDS_MIN_presolve_default  UPPERBOUNDS_MAX_presolve_default  \
# 0                      8.326673e-17                          4.014668
# 1                      8.326673e-17                          4.514678
# 2                      8.326673e-17                          4.140987
# 3                      8.326673e-17                          4.464831
# 4                      3.921569e-03                          3.856785
#
#    UPPERBOUNDS_STD_presolve_default  UPPERBOUNDS_MEDIAN_presolve_default  \
# 0                          0.208556                                  0.1
# 1                          0.241107                                  0.1
# 2                          0.204747                                  0.1
# 3                          0.221774                                  0.1
# 4                          0.220129                                  0.1
#
#    UPPERBOUNDS_DENSITY_presolve_default  ...  LP_strongbranching_2_Iterations  \
# 0                              0.999304  ...                           9068.0
# 1                              0.996436  ...                          34576.0
# 2                              0.998570  ...                          15531.0
# 3                              0.999307  ...                           7733.0
# 4                              1.000000  ...                          18120.0
#
#    LP_strongbranching_2_Iter/call  LP_strongbranching_2_Iter/sec  \
# 0                          503.78                        3943.55
# 1                          501.10                        3416.29
# 2                          501.00                        3656.85
# 3                          483.31                        3250.74
# 4                          503.33                        3253.58
#
#    LP_strongbranching_2_ItLimit  LP_conflictanalysis_Time  \
# 0                          18.0                       0.0
# 1                          69.0                       0.0
# 2                          31.0                       0.0
# 3                          14.0                       0.0
# 4                          36.0                       0.0
#
#    LP_conflictanalysis_Calls  LP_conflictanalysis_Iter/call  \
# 0                        1.0                            0.0
# 1                        0.0                            0.0
# 2                        0.0                            0.0
# 3                        1.0                            0.0
# 4                        0.0                            0.0
#
#    FirstLPIters_persecond  Integrals_primal-dual_Total  \
# 0                10024.94                      2257.16
# 1                 6630.76                      1954.25
# 2                 6675.08                      3152.15
# 3                 6334.76                      3848.17
# 4                 5678.14                      1671.32
#
#    Integrals_primal-dual_Avg%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
#
# [5 rows x 364 columns]

# %%
df['INSTANCE_NAME'] = 'mip' + df['INSTANCE_NAME'].astype('str')
df.head()
# Out:
#   INSTANCE_NAME  VARS_presolve_default  BIN_VARS_presolve_default  \
# 0          mip1                 1437.0                      330.0
# 1         mip10                 1403.0                      313.0
# 2        mip100                 1399.0                      311.0
# 3       mip1000                 1443.0                      333.0
# 4      mip10000                 1329.0                      276.0
#
#    CONT_VARS_presolve_default  UPPERBOUNDS_MEAN_presolve_default  \
# 0                      1107.0                           0.452455
# 1                      1090.0                           0.459198
# 2                      1088.0                           0.432643
# 3                      1110.0                           0.466921
# 4                      1053.0                           0.423002
#
#    UPPERBOUNDS_MIN_presolve_default  UPPERBOUNDS_MAX_presolve_default  \
# 0                      8.326673e-17                          4.014668
# 1                      8.326673e-17                          4.514678
# 2                      8.326673e-17                          4.140987
# 3                      8.326673e-17                          4.464831
# 4                      3.921569e-03                          3.856785
#
#    UPPERBOUNDS_STD_presolve_default  UPPERBOUNDS_MEDIAN_presolve_default  \
# 0                          0.208556                                  0.1
# 1                          0.241107                                  0.1
# 2                          0.204747                                  0.1
# 3                          0.221774                                  0.1
# 4                          0.220129                                  0.1
#
#    UPPERBOUNDS_DENSITY_presolve_default  ...  LP_strongbranching_2_Iterations  \
# 0                              0.999304  ...                           9068.0
# 1                              0.996436  ...                          34576.0
# 2                              0.998570  ...                          15531.0
# 3                              0.999307  ...                           7733.0
# 4                              1.000000  ...                          18120.0
#
#    LP_strongbranching_2_Iter/call  LP_strongbranching_2_Iter/sec  \
# 0                          503.78                        3943.55
# 1                          501.10                        3416.29
# 2                          501.00                        3656.85
# 3                          483.31                        3250.74
# 4                          503.33                        3253.58
#
#    LP_strongbranching_2_ItLimit  LP_conflictanalysis_Time  \
# 0                          18.0                       0.0
# 1                          69.0                       0.0
# 2                          31.0                       0.0
# 3                          14.0                       0.0
# 4                          36.0                       0.0
#
#    LP_conflictanalysis_Calls  LP_conflictanalysis_Iter/call  \
# 0                        1.0                            0.0
# 1                        0.0                            0.0
# 2                        0.0                            0.0
# 3                        1.0                            0.0
# 4                        0.0                            0.0
#
#    FirstLPIters_persecond  Integrals_primal-dual_Total  \
# 0                10024.94                      2257.16
# 1                 6630.76                      1954.25
# 2                 6675.08                      3152.15
# 3                 6334.76                      3848.17
# 4                 5678.14                      1671.32
#
#    Integrals_primal-dual_Avg%
# 0                       100.0
# 1                       100.0
# 2                       100.0
# 3                       100.0
# 4                       100.0
#
# [5 rows x 364 columns]

# %% [markdown]
# ## What timing features shall we use?
#
# - Dynamic feature group: df['TotalTime'] - df['presolvingtime'] (presolving group is a requirement)
# - Static presolve on (default) feature group: df['presolvingtime']
# - Static presolve off feature group: assume they are free because they are simply statistics like 'number of X' or 'mean of X'.

# %% [markdown]
# ### Add rows as comma seperated data to feature_values.arff file

# %%
# first make sure all column names are correct and isolate timing features
timing_df = df[['presolvingtime', 'TotalTime']]
timing_df
# Out:
#       presolvingtime  TotalTime
# 0               1.47      22.74
# 1               1.31      19.67
# 2               1.40      31.65
# 3               2.53      38.64
# 4               1.94      16.86
# ...              ...        ...
# 9995            1.18      11.67
# 9996            1.08      10.84
# 9997            1.27      12.71
# 9998            1.44      19.74
# 9999            1.19      17.86
#
# [10000 rows x 2 columns]

# %%
# first make sure all column names are correct and isolate timing features
features_df = df.drop(columns=timing_df.columns)
features_df
# Out:
#      INSTANCE_NAME  VARS_presolve_default  BIN_VARS_presolve_default  \
# 0             mip1                 1437.0                      330.0
# 1            mip10                 1403.0                      313.0
# 2           mip100                 1399.0                      311.0
# 3          mip1000                 1443.0                      333.0
# 4         mip10000                 1329.0                      276.0
# ...            ...                    ...                        ...
# 9995       mip9995                 1375.0                      299.0
# 9996       mip9996                 1275.0                      249.0
# 9997       mip9997                 1379.0                      301.0
# 9998       mip9998                 1365.0                      294.0
# 9999       mip9999                 1375.0                      299.0
#
#       CONT_VARS_presolve_default  UPPERBOUNDS_MEAN_presolve_default  \
# 0                         1107.0                           0.452455
# 1                         1090.0                           0.459198
# 2                         1088.0                           0.432643
# 3                         1110.0                           0.466921
# 4                         1053.0                           0.423002
# ...                          ...                                ...
# 9995                      1076.0                           0.441397
# 9996                      1026.0                           0.380774
# 9997                      1078.0                           0.418347
# 9998                      1071.0                           0.430596
# 9999                      1076.0                           0.446893
#
#       UPPERBOUNDS_MIN_presolve_default  UPPERBOUNDS_MAX_presolve_default  \
# 0                         8.326673e-17                          4.014668
# 1                         8.326673e-17                          4.514678
# 2                         8.326673e-17                          4.140987
# 3                         8.326673e-17                          4.464831
# 4                         3.921569e-03                          3.856785
# ...                                ...                               ...
# 9995                      8.326673e-17                          3.593675
# 9996                      8.326673e-17                          3.215775
# 9997                      1.347221e-04                          3.886279
# 9998                      8.326673e-17                          4.260940
# 9999                      8.326673e-17                          4.353233
#
#       UPPERBOUNDS_STD_presolve_default  UPPERBOUNDS_MEDIAN_presolve_default  \
# 0                             0.208556                                  0.1
# 1                             0.241107                                  0.1
# 2                             0.204747                                  0.1
# 3                             0.221774                                  0.1
# 4                             0.220129                                  0.1
# ...                                ...                                  ...
# 9995                          0.207536                                  0.1
# 9996                          0.189279                                  0.1
# 9997                          0.207325                                  0.1
# 9998                          0.212202                                  0.1
# 9999                          0.230003                                  0.1
#
#       UPPERBOUNDS_DENSITY_presolve_default  ...  \
# 0                                 0.999304  ...
# 1                                 0.996436  ...
# 2                                 0.998570  ...
# 3                                 0.999307  ...
# 4                                 1.000000  ...
# ...                                    ...  ...
# 9995                              0.999273  ...
# 9996                              0.904314  ...
# 9997                              1.000000  ...
# 9998                              0.999267  ...
# 9999                              0.999273  ...
#
#       LP_strongbranching_2_Iterations  LP_strongbranching_2_Iter/call  \
# 0                              9068.0                          503.78
# 1                             34576.0                          501.10
# 2                             15531.0                          501.00
# 3                              7733.0                          483.31
# 4                             18120.0                          503.33
# ...                               ...                             ...
# 9995                          11526.0                          501.13
# 9996                           9689.0                          509.95
# 9997                          10107.0                          505.35
# 9998                          11689.0                          508.22
# 9999                           6108.0                          509.00
#
#       LP_strongbranching_2_Iter/sec  LP_strongbranching_2_ItLimit  \
# 0                           3943.55                          18.0
# 1                           3416.29                          69.0
# 2                           3656.85                          31.0
# 3                           3250.74                          14.0
# 4                           3253.58                          36.0
# ...                             ...                           ...
# 9995                        4042.59                          23.0
# 9996                        3498.07                          19.0
# 9997                        2445.63                          20.0
# 9998                        4380.38                          22.0
# 9999                        4165.02                          12.0
#
#       LP_conflictanalysis_Time  LP_conflictanalysis_Calls  \
# 0                          0.0                        1.0
# 1                          0.0                        0.0
# 2                          0.0                        0.0
# 3                          0.0                        1.0
# 4                          0.0                        0.0
# ...                        ...                        ...
# 9995                       0.0                        0.0
# 9996                       0.0                        0.0
# 9997                       0.0                        0.0
# 9998                       0.0                        0.0
# 9999                       0.0                        0.0
#
#       LP_conflictanalysis_Iter/call  FirstLPIters_persecond  \
# 0                               0.0                10024.94
# 1                               0.0                 6630.76
# 2                               0.0                 6675.08
# 3                               0.0                 6334.76
# 4                               0.0                 5678.14
# ...                             ...                     ...
# 9995                            0.0                 7945.45
# 9996                            0.0                12400.55
# 9997                            0.0                 7913.33
# 9998                            0.0                 6605.43
# 9999                            0.0                 9894.03
#
#       Integrals_primal-dual_Total  Integrals_primal-dual_Avg%
# 0                         2257.16                       100.0
# 1                         1954.25                       100.0
# 2                         3152.15                       100.0
# 3                         3848.17                       100.0
# 4                         1671.32                       100.0
# ...                           ...                         ...
# 9995                      1155.12                       100.0
# 9996                      1059.17                       100.0
# 9997                      1258.05                       100.0
# 9998                      1954.18                       100.0
# 9999                      1774.44                       100.0
#
# [10000 rows x 362 columns]

# %%
# first make sure all column names are correct --> instance id and repetitions
features_df.rename(columns={"INSTANCE_NAME":"instance_id"}, inplace=True)
features_df["repetition"] = 1
features_df
# Out:
#      instance_id  VARS_presolve_default  BIN_VARS_presolve_default  \
# 0           mip1                 1437.0                      330.0
# 1          mip10                 1403.0                      313.0
# 2         mip100                 1399.0                      311.0
# 3        mip1000                 1443.0                      333.0
# 4       mip10000                 1329.0                      276.0
# ...          ...                    ...                        ...
# 9995     mip9995                 1375.0                      299.0
# 9996     mip9996                 1275.0                      249.0
# 9997     mip9997                 1379.0                      301.0
# 9998     mip9998                 1365.0                      294.0
# 9999     mip9999                 1375.0                      299.0
#
#       CONT_VARS_presolve_default  UPPERBOUNDS_MEAN_presolve_default  \
# 0                         1107.0                           0.452455
# 1                         1090.0                           0.459198
# 2                         1088.0                           0.432643
# 3                         1110.0                           0.466921
# 4                         1053.0                           0.423002
# ...                          ...                                ...
# 9995                      1076.0                           0.441397
# 9996                      1026.0                           0.380774
# 9997                      1078.0                           0.418347
# 9998                      1071.0                           0.430596
# 9999                      1076.0                           0.446893
#
#       UPPERBOUNDS_MIN_presolve_default  UPPERBOUNDS_MAX_presolve_default  \
# 0                         8.326673e-17                          4.014668
# 1                         8.326673e-17                          4.514678
# 2                         8.326673e-17                          4.140987
# 3                         8.326673e-17                          4.464831
# 4                         3.921569e-03                          3.856785
# ...                                ...                               ...
# 9995                      8.326673e-17                          3.593675
# 9996                      8.326673e-17                          3.215775
# 9997                      1.347221e-04                          3.886279
# 9998                      8.326673e-17                          4.260940
# 9999                      8.326673e-17                          4.353233
#
#       UPPERBOUNDS_STD_presolve_default  UPPERBOUNDS_MEDIAN_presolve_default  \
# 0                             0.208556                                  0.1
# 1                             0.241107                                  0.1
# 2                             0.204747                                  0.1
# 3                             0.221774                                  0.1
# 4                             0.220129                                  0.1
# ...                                ...                                  ...
# 9995                          0.207536                                  0.1
# 9996                          0.189279                                  0.1
# 9997                          0.207325                                  0.1
# 9998                          0.212202                                  0.1
# 9999                          0.230003                                  0.1
#
#       UPPERBOUNDS_DENSITY_presolve_default  ...  \
# 0                                 0.999304  ...
# 1                                 0.996436  ...
# 2                                 0.998570  ...
# 3                                 0.999307  ...
# 4                                 1.000000  ...
# ...                                    ...  ...
# 9995                              0.999273  ...
# 9996                              0.904314  ...
# 9997                              1.000000  ...
# 9998                              0.999267  ...
# 9999                              0.999273  ...
#
#       LP_strongbranching_2_Iter/call  LP_strongbranching_2_Iter/sec  \
# 0                             503.78                        3943.55
# 1                             501.10                        3416.29
# 2                             501.00                        3656.85
# 3                             483.31                        3250.74
# 4                             503.33                        3253.58
# ...                              ...                            ...
# 9995                          501.13                        4042.59
# 9996                          509.95                        3498.07
# 9997                          505.35                        2445.63
# 9998                          508.22                        4380.38
# 9999                          509.00                        4165.02
#
#       LP_strongbranching_2_ItLimit  LP_conflictanalysis_Time  \
# 0                             18.0                       0.0
# 1                             69.0                       0.0
# 2                             31.0                       0.0
# 3                             14.0                       0.0
# 4                             36.0                       0.0
# ...                            ...                       ...
# 9995                          23.0                       0.0
# 9996                          19.0                       0.0
# 9997                          20.0                       0.0
# 9998                          22.0                       0.0
# 9999                          12.0                       0.0
#
#       LP_conflictanalysis_Calls  LP_conflictanalysis_Iter/call  \
# 0                           1.0                            0.0
# 1                           0.0                            0.0
# 2                           0.0                            0.0
# 3                           1.0                            0.0
# 4                           0.0                            0.0
# ...                         ...                            ...
# 9995                        0.0                            0.0
# 9996                        0.0                            0.0
# 9997                        0.0                            0.0
# 9998                        0.0                            0.0
# 9999                        0.0                            0.0
#
#       FirstLPIters_persecond  Integrals_primal-dual_Total  \
# 0                   10024.94                      2257.16
# 1                    6630.76                      1954.25
# 2                    6675.08                      3152.15
# 3                    6334.76                      3848.17
# 4                    5678.14                      1671.32
# ...                      ...                          ...
# 9995                 7945.45                      1155.12
# 9996                12400.55                      1059.17
# 9997                 7913.33                      1258.05
# 9998                 6605.43                      1954.18
# 9999                 9894.03                      1774.44
#
#       Integrals_primal-dual_Avg%  repetition
# 0                          100.0           1
# 1                          100.0           1
# 2                          100.0           1
# 3                          100.0           1
# 4                          100.0           1
# ...                          ...         ...
# 9995                       100.0           1
# 9996                       100.0           1
# 9997                       100.0           1
# 9998                       100.0           1
# 9999                       100.0           1
#
# [10000 rows x 363 columns]

# %%
# Change position of columns --> instance_id and repetition go first
cols = features_df.columns.tolist()
cols
# Out:
# ['instance_id',
#  'VARS_presolve_default',
#  'BIN_VARS_presolve_default',
#  'CONT_VARS_presolve_default',
#  'UPPERBOUNDS_MEAN_presolve_default',
#  'UPPERBOUNDS_MIN_presolve_default',
#  'UPPERBOUNDS_MAX_presolve_default',
#  'UPPERBOUNDS_STD_presolve_default',
#  'UPPERBOUNDS_MEDIAN_presolve_default',
#  'UPPERBOUNDS_DENSITY_presolve_default',
#  'LOWERBOUNDS_MEAN_presolve_default',
#  'LOWERBOUNDS_MIN_presolve_default',
#  'LOWERBOUNDS_MAX_presolve_default',
#  'LOWERBOUNDS_STD_presolve_default',
#  'LOWERBOUNDS_DENSITY_presolve_default',
#  'BOUNDRANGE_MEAN_presolve_default',
#  'BOUNDRANGE_MIN_presolve_default',
#  'BOUNDRANGE_MAX_presolve_default',
#  'BOUNDRANGE_STD_presolve_default',
#  'BOUNDRANGE_MEDIAN_presolve_default',
#  'OBJCOEFF_ALL_MEAN_presolve_default',
#  'OBJCOEFF_ALL_STD_presolve_default',
#  'OBJCOEFF_CONT_MEAN_presolve_default',
#  'OBJCOEFF_CONT_STD_presolve_default',
#  'CONSTR_presolve_default',
#  'LINSING_CONSTR_presolve_default',
#  'LINPREC_CONSTR_presolve_default',
#  'LINVARBD_CONSTR_presolve_default',
#  'LINMIXBIN_CONSTR_presolve_default',
#  'CONSTR_MEAN_presolve_default',
#  'CONSTR_MAX_presolve_default',
#  'CONSTR_STD_presolve_default',
#  'RH_CONSTR_MEAN_presolve_default',
#  'RH_CONSTR_MAX_presolve_default',
#  'RH_CONSTR_STD_presolve_default',
#  'RH_CONSTR_DENSITY_presolve_default',
#  'LH_CONSTR_MEAN_presolve_default',
#  'LH_CONSTR_MIN_presolve_default',
#  'LH_CONSTR_MAX_presolve_default',
#  'LH_CONSTR_STD_presolve_default',
#  'LH_CONSTR_MEDIAN_presolve_default',
#  'RH_CONSTR_RATIO_presolve_default',
#  'LH_CONSTR_RATIO_presolve_default',
#  'NVAR_ALL_MEAN_presolve_default',
#  'NVAR_ALL_MIN_presolve_default',
#  'NVAR_ALL_STD_presolve_default',
#  'CONSTR_COEFF_MEAN_MEAN_presolve_default',
#  'CONSTR_COEFF_MEAN_STD_presolve_default',
#  'CONSTR_COEFF_MIN_MEAN_presolve_default',
#  'CONSTR_COEFF_MIN_STD_presolve_default',
#  'CONSTR_COEFF_MAX_MEAN_presolve_default',
#  'CONSTR_COEFF_MAX_STD_presolve_default',
#  'CONSTR_COEFF_STD_MEAN_presolve_default',
#  'CONSTR_COEFF_STD_STD_presolve_default',
#  'CONSTR_COEFF_STD_MEDIAN_presolve_default',
#  'CONSTR_MATRIX_DENSITY_presolve_default',
#  'NONZEROES_presolve_default',
#  'CLIQUE_MEAN_presolve_default',
#  'CLIQUE_MIN_presolve_default',
#  'CLIQUE_MAX_presolve_default',
#  'CLIQUE_STD_presolve_default',
#  'DYNAMISM_MEAN_presolve_default',
#  'DYNAMISM_MAX_presolve_default',
#  'DYNAMISM_STD_presolve_default',
#  'DYNAMISM_MEDIAN_presolve_default',
#  'VARS_presolve_off',
#  'BIN_VARS_presolve_off',
#  'CONT_VARS_presolve_off',
#  'PER_FINITE_UB_presolve_off',
#  'UPPERBOUNDS_MEAN_presolve_off',
#  'UPPERBOUNDS_MIN_presolve_off',
#  'UPPERBOUNDS_STD_presolve_off',
#  'LOWERBOUNDS_MEAN_presolve_off',
#  'LOWERBOUNDS_MIN_presolve_off',
#  'LOWERBOUNDS_MAX_presolve_off',
#  'LOWERBOUNDS_STD_presolve_off',
#  'LOWERBOUNDS_DENSITY_presolve_off',
#  'BOUNDRANGE_MEAN_presolve_off',
#  'BOUNDRANGE_MAX_presolve_off',
#  'BOUNDRANGE_STD_presolve_off',
#  'BOUNDRANGE_MEDIAN_presolve_off',
#  'OBJCOEFF_ALL_MEAN_presolve_off',
#  'OBJCOEFF_ALL_STD_presolve_off',
#  'OBJCOEFF_CONT_MEAN_presolve_off',
#  'CONSTR_presolve_off',
#  'LINSING_CONSTR_presolve_off',
#  'LINVARBD_CONSTR_presolve_off',
#  'LINMIXBIN_CONSTR_presolve_off',
#  'CONSTR_MEAN_presolve_off',
#  'CONSTR_MAX_presolve_off',
#  'CONSTR_STD_presolve_off',
#  'RH_CONSTR_MEAN_presolve_off',
#  'RH_CONSTR_MIN_presolve_off',
#  'RH_CONSTR_MAX_presolve_off',
#  'RH_CONSTR_STD_presolve_off',
#  'RH_CONSTR_DENSITY_presolve_off',
#  'LH_CONSTR_MEAN_presolve_off',
#  'LH_CONSTR_MIN_presolve_off',
#  'LH_CONSTR_STD_presolve_off',
#  'LH_CONSTR_DENSITY_presolve_off',
#  'RH_CONSTR_RATIO_presolve_off',
#  'LH_CONSTR_RATIO_presolve_off',
#  'NVAR_ALL_MEAN_presolve_off',
#  'NVAR_ALL_MAX_presolve_off',
#  'NVAR_ALL_STD_presolve_off',
#  'CONSTR_COEFF_MEAN_MEAN_presolve_off',
#  'CONSTR_COEFF_MEAN_MIN_presolve_off',
#  'CONSTR_COEFF_MEAN_STD_presolve_off',
#  'CONSTR_COEFF_MIN_MEAN_presolve_off',
#  'CONSTR_COEFF_MIN_STD_presolve_off',
#  'CONSTR_COEFF_MAX_MEAN_presolve_off',
#  'CONSTR_COEFF_MAX_MIN_presolve_off',
#  'CONSTR_COEFF_MAX_STD_presolve_off',
#  'CONSTR_COEFF_STD_MEAN_presolve_off',
#  'CONSTR_COEFF_STD_STD_presolve_off',
#  'CONSTR_COEFF_STD_MEDIAN_presolve_off',
#  'CONSTR_MATRIX_DENSITY_presolve_off',
#  'NONZEROES_presolve_off',
#  'CLIQUE_MEAN_presolve_off',
#  'CLIQUE_MIN_presolve_off',
#  'CLIQUE_MAX_presolve_off',
#  'CLIQUE_STD_presolve_off',
#  'DYNAMISM_MEAN_presolve_off',
#  'DYNAMISM_STD_presolve_off',
#  'solvingtime',
#  'readingtime',
#  'copyingtime',
#  'PresolvedProblem_Variables',
#  'feasibleleaves',
#  'objectiveleaves',
#  'nodesleft',
#  'avgswitchlength',
#  'FirstLPIters',
#  'FirstLPTime',
#  'FinalDualBound',
#  'FinalRootIters',
#  'RootLPEstimate',
#  'Solutionsfound',
#  'PrimalBound',
#  'Gap',
#  'FirstSolution',
#  'GapFirstSol.',
#  'GapLastSol.',
#  'PresolvedProblem_Variables_Binary',
#  'PresolvedProblem_Variables_Continuous',
#  'PresolvedProblem_Constraints_initial',
#  'PresolvedProblem_Constraints_maximal',
#  'PresolvedProblem_Nonzeros_constraint',
#  'PresolvedProblem_Nonzeros_clique',
#  'Presolvers_domcol_ExecTime',
#  'Presolvers_domcol_Calls',
#  'Presolvers_dualcomp_ExecTime',
#  'Presolvers_dualsparsify_ExecTime',
#  'Presolvers_dualsparsify_DelCons',
#  'Presolvers_implics_Calls',
#  'Presolvers_milp_ExecTime',
#  'Presolvers_milp_Calls',
#  'Presolvers_milp_FixedVars',
#  'Presolvers_milp_ChgBounds',
#  'Presolvers_sparsify_ExecTime',
#  'Presolvers_trivial_Calls',
#  'Presolvers_probing_ExecTime',
#  'Presolvers_probing_FixedVars',
#  'Presolvers_symmetry_ExecTime',
#  'Presolvers_vbounds_Calls',
#  'Presolvers_varbound_Calls',
#  'Presolvers_varbound_DelCons',
#  'Presolvers_setppc_Calls',
#  'Presolvers_linear_ExecTime',
#  'Presolvers_linear_SetupTime',
#  'Presolvers_linear_Calls',
#  'Presolvers_linear_ChgBounds',
#  'Presolvers_linear_DelCons',
#  'Presolvers_linear_ChgSides',
#  'Presolvers_components_ExecTime',
#  'Presolvers_rootnode_FixedVars',
#  'Presolvers_rootnode_ChgBounds',
#  'Constraints_benderslp_#EnfoLP',
#  'Constraints_benderslp_#Check',
#  'Constraints_integral_DomReds',
#  'Constraints_integral_Conss',
#  'Constraints_varbound_1_Number',
#  'Constraints_varbound_1_MaxNumber',
#  'Constraints_varbound_1_#Separate',
#  'Constraints_varbound_1_#Propagate',
#  'Constraints_varbound_1_#Check',
#  'Constraints_varbound_1_#ResProp',
#  'Constraints_varbound_1_Cutoffs',
#  'Constraints_varbound_1_DomReds',
#  'Constraints_setppc_1_MaxNumber',
#  'Constraints_setppc_1_#Separate',
#  'Constraints_setppc_1_#Propagate',
#  'Constraints_setppc_1_#Check',
#  'Constraints_setppc_1_#ResProp',
#  'Constraints_setppc_1_Cutoffs',
#  'Constraints_setppc_1_DomReds',
#  'Constraints_setppc_1_Cuts',
#  'Constraints_setppc_1_Applied',
#  'Constraints_linear_1_Number',
#  'Constraints_linear_1_MaxNumber',
#  'Constraints_linear_1_#Propagate',
#  'Constraints_linear_1_#Check',
#  'Constraints_linear_1_#ResProp',
#  'Constraints_linear_1_Cutoffs',
#  'Constraints_linear_1_DomReds',
#  'Constraints_logicor_1_MaxNumber',
#  'Constraints_logicor_1_#Separate',
#  'Constraints_logicor_1_#Propagate',
#  'Constraints_logicor_1_#ResProp',
#  'Constraints_logicor_1_Cutoffs',
#  'Constraints_logicor_1_Cuts',
#  'Constraints_logicor_1_Applied',
#  'Constraints_benders_1_#Check',
#  'ConstraintTimings_integral_1_TotalTime',
#  'ConstraintTimings_integral_1_EnfoLP',
#  'ConstraintTimings_varbound_2_TotalTime',
#  'ConstraintTimings_varbound_2_Separate',
#  'ConstraintTimings_varbound_2_Propagate',
#  'ConstraintTimings_varbound_2_ResProp',
#  'ConstraintTimings_setppc_2_TotalTime',
#  'ConstraintTimings_setppc_2_Propagate',
#  'ConstraintTimings_linear_2_TotalTime',
#  'ConstraintTimings_linear_2_Separate',
#  'ConstraintTimings_linear_2_Propagate',
#  'ConstraintTimings_linear_2_Check',
#  'ConstraintTimings_linear_2_ResProp',
#  'ConstraintTimings_linear_2_SB-Prop',
#  'Propagators_dualfix_1_#Propagate',
#  'Propagators_pseudoobj_1_#Propagate',
#  'Propagators_pseudoobj_1_DomReds',
#  'Propagators_redcost_#Propagate',
#  'Propagators_vbounds_1_#Propagate',
#  'PropagatorTimings_probing_2_TotalTime',
#  'PropagatorTimings_symmetry_2_TotalTime',
#  'ConflictAnalysis_propagation_Time',
#  'ConflictAnalysis_propagation_Calls',
#  'ConflictAnalysis_propagation_Success',
#  'ConflictAnalysis_propagation_Conflicts',
#  'ConflictAnalysis_propagation_Literals',
#  'ConflictAnalysis_propagation_Reconvs',
#  'ConflictAnalysis_propagation_ReconvLits',
#  'ConflictAnalysis_infeasibleLP_Time',
#  'ConflictAnalysis_infeasibleLP_Calls',
#  'ConflictAnalysis_infeasibleLP_Success',
#  'ConflictAnalysis_infeasibleLP_Conflicts',
#  'ConflictAnalysis_infeasibleLP_Literals',
#  'ConflictAnalysis_infeasibleLP_Reconvs',
#  'ConflictAnalysis_infeasibleLP_ReconvLits',
#  'ConflictAnalysis_infeasibleLP_Dualrays',
#  'ConflictAnalysis_infeasibleLP_Nonzeros',
#  'ConflictAnalysis_boundexceed.LP_Time',
#  'ConflictAnalysis_boundexceed.LP_Calls',
#  'ConflictAnalysis_boundexceed.LP_Success',
#  'ConflictAnalysis_boundexceed.LP_Conflicts',
#  'ConflictAnalysis_boundexceed.LP_Literals',
#  'ConflictAnalysis_boundexceed.LP_Reconvs',
#  'ConflictAnalysis_boundexceed.LP_ReconvLits',
#  'ConflictAnalysis_boundexceed.LP_Dualrays',
#  'ConflictAnalysis_boundexceed.LP_LP',
#  'ConflictAnalysis_pseudosolution_Calls',
#  'ConflictAnalysis_appliedglobally_DomReds',
#  'ConflictAnalysis_appliedglobally_Conflicts',
#  'ConflictAnalysis_appliedglobally_Literals',
#  'ConflictAnalysis_appliedglobally_Dualrays',
#  'ConflictAnalysis_appliedlocally_Conflicts',
#  'ConflictAnalysis_appliedlocally_Literals',
#  'Separators_cutpool_ExecTime',
#  'Separators_cutpool_Calls',
#  'Separators_cutpool_FoundCuts',
#  'Separators_cutpool_ViaPoolAdd',
#  'Separators_aggregation_ExecTime',
#  'Separators_aggregation_FoundCuts',
#  'Separators_aggregation_ViaPoolAdd',
#  'Separators_aggregation_Applied',
#  'Separators_>cmir_ViaPoolAdd',
#  'Separators_>cmir_Applied',
#  'Separators_>flowcover_ViaPoolAdd',
#  'Separators_>flowcover_Applied',
#  'Separators_>knapsackcover_ViaPoolAdd',
#  'Separators_>knapsackcover_Applied',
#  'Separators_clique_FoundCuts',
#  'Separators_clique_ViaPoolAdd',
#  'Separators_clique_Applied',
#  'Separators_gomory_ExecTime',
#  'Separators_gomory_FoundCuts',
#  'Separators_gomory_ViaPoolAdd',
#  'Separators_gomory_Applied',
#  'Separators_impliedbounds_FoundCuts',
#  'Separators_impliedbounds_ViaPoolAdd',
#  'Separators_impliedbounds_Applied',
#  'Separators_mcf_ExecTime',
#  'Separators_mixing_FoundCuts',
#  'Separators_mixing_ViaPoolAdd',
#  'Separators_mixing_Applied',
#  'Separators_zerohalf_Calls',
#  'Separators_zerohalf_FoundCuts',
#  'Separators_zerohalf_ViaPoolAdd',
#  'Cutselectors_hybrid_ExecTime',
#  'Cutselectors_hybrid_Calls',
#  'Cutselectors_hybrid_Selected',
#  'Cutselectors_hybrid_Forced',
#  'Cutselectors_hybrid_Filtered',
#  'BranchingRules_relpscost_ExecTime',
#  'BranchingRules_relpscost_BranchLP',
#  'PrimalHeuristics_alns_ExecTime',
#  'PrimalHeuristics_alns_Calls',
#  'PrimalHeuristics_clique_1_ExecTime',
#  'PrimalHeuristics_conflictdiving_ExecTime',
#  'PrimalHeuristics_conflictdiving_Calls',
#  'PrimalHeuristics_feaspump_ExecTime',
#  'PrimalHeuristics_feaspump_Found',
#  'PrimalHeuristics_intshifting_ExecTime',
#  'PrimalHeuristics_intshifting_Calls',
#  'PrimalHeuristics_locks_ExecTime',
#  'PrimalHeuristics_oneopt_ExecTime',
#  'PrimalHeuristics_oneopt_Calls',
#  'PrimalHeuristics_randrounding_ExecTime',
#  'PrimalHeuristics_randrounding_Calls',
#  'PrimalHeuristics_rens_ExecTime',
#  'PrimalHeuristics_rens_Calls',
#  'PrimalHeuristics_rens_Found',
#  'PrimalHeuristics_rounding_Calls',
#  'PrimalHeuristics_shiftandpropagate_ExecTime',
#  'PrimalHeuristics_shifting_ExecTime',
#  'PrimalHeuristics_zirounding_Calls',
#  'PrimalHeuristics_zirounding_Found',
#  'LP_primalLP_Time',
#  'LP_primalLP_Calls',
#  'LP_primalLP_Iterations',
#  'LP_primalLP_Iter/call',
#  'LP_primalLP_Iter/sec',
#  'LP_primalLP_Time-0-It',
#  'LP_primalLP_Calls-0-It',
#  'LP_dualLP_Time',
#  'LP_dualLP_Calls',
#  'LP_dualLP_Iterations',
#  'LP_dualLP_Iter/call',
#  'LP_dualLP_Iter/sec',
#  'LP_dualLP_Time-0-It',
#  'LP_dualLP_Calls-0-It',
#  'LP_resolveinstable_Time',
#  'LP_resolveinstable_Calls',
#  'LP_resolveinstable_Iterations',
#  'LP_resolveinstable_Iter/call',
#  'LP_resolveinstable_Iter/sec',
#  'LP_diving/probingLP_Time',
#  'LP_diving/probingLP_Calls',
#  'LP_diving/probingLP_Iterations',
#  'LP_diving/probingLP_Iter/call',
#  'LP_diving/probingLP_Iter/sec',
#  'LP_strongbranching_2_Time',
#  'LP_strongbranching_2_Calls',
#  'LP_strongbranching_2_Iterations',
#  'LP_strongbranching_2_Iter/call',
#  'LP_strongbranching_2_Iter/sec',
#  'LP_strongbranching_2_ItLimit',
#  'LP_conflictanalysis_Time',
#  'LP_conflictanalysis_Calls',
#  'LP_conflictanalysis_Iter/call',
#  'FirstLPIters_persecond',
#  'Integrals_primal-dual_Total',
#  'Integrals_primal-dual_Avg%',
#  'repetition']

# %%
# Change position of columns --> instance_id and repetition go first
cols = cols[-1:] + cols[1:-1]
new_cols = ['instance_id']
new_cols = new_cols + cols
new_cols
# Out:
# ['instance_id',
#  'repetition',
#  'VARS_presolve_default',
#  'BIN_VARS_presolve_default',
#  'CONT_VARS_presolve_default',
#  'UPPERBOUNDS_MEAN_presolve_default',
#  'UPPERBOUNDS_MIN_presolve_default',
#  'UPPERBOUNDS_MAX_presolve_default',
#  'UPPERBOUNDS_STD_presolve_default',
#  'UPPERBOUNDS_MEDIAN_presolve_default',
#  'UPPERBOUNDS_DENSITY_presolve_default',
#  'LOWERBOUNDS_MEAN_presolve_default',
#  'LOWERBOUNDS_MIN_presolve_default',
#  'LOWERBOUNDS_MAX_presolve_default',
#  'LOWERBOUNDS_STD_presolve_default',
#  'LOWERBOUNDS_DENSITY_presolve_default',
#  'BOUNDRANGE_MEAN_presolve_default',
#  'BOUNDRANGE_MIN_presolve_default',
#  'BOUNDRANGE_MAX_presolve_default',
#  'BOUNDRANGE_STD_presolve_default',
#  'BOUNDRANGE_MEDIAN_presolve_default',
#  'OBJCOEFF_ALL_MEAN_presolve_default',
#  'OBJCOEFF_ALL_STD_presolve_default',
#  'OBJCOEFF_CONT_MEAN_presolve_default',
#  'OBJCOEFF_CONT_STD_presolve_default',
#  'CONSTR_presolve_default',
#  'LINSING_CONSTR_presolve_default',
#  'LINPREC_CONSTR_presolve_default',
#  'LINVARBD_CONSTR_presolve_default',
#  'LINMIXBIN_CONSTR_presolve_default',
#  'CONSTR_MEAN_presolve_default',
#  'CONSTR_MAX_presolve_default',
#  'CONSTR_STD_presolve_default',
#  'RH_CONSTR_MEAN_presolve_default',
#  'RH_CONSTR_MAX_presolve_default',
#  'RH_CONSTR_STD_presolve_default',
#  'RH_CONSTR_DENSITY_presolve_default',
#  'LH_CONSTR_MEAN_presolve_default',
#  'LH_CONSTR_MIN_presolve_default',
#  'LH_CONSTR_MAX_presolve_default',
#  'LH_CONSTR_STD_presolve_default',
#  'LH_CONSTR_MEDIAN_presolve_default',
#  'RH_CONSTR_RATIO_presolve_default',
#  'LH_CONSTR_RATIO_presolve_default',
#  'NVAR_ALL_MEAN_presolve_default',
#  'NVAR_ALL_MIN_presolve_default',
#  'NVAR_ALL_STD_presolve_default',
#  'CONSTR_COEFF_MEAN_MEAN_presolve_default',
#  'CONSTR_COEFF_MEAN_STD_presolve_default',
#  'CONSTR_COEFF_MIN_MEAN_presolve_default',
#  'CONSTR_COEFF_MIN_STD_presolve_default',
#  'CONSTR_COEFF_MAX_MEAN_presolve_default',
#  'CONSTR_COEFF_MAX_STD_presolve_default',
#  'CONSTR_COEFF_STD_MEAN_presolve_default',
#  'CONSTR_COEFF_STD_STD_presolve_default',
#  'CONSTR_COEFF_STD_MEDIAN_presolve_default',
#  'CONSTR_MATRIX_DENSITY_presolve_default',
#  'NONZEROES_presolve_default',
#  'CLIQUE_MEAN_presolve_default',
#  'CLIQUE_MIN_presolve_default',
#  'CLIQUE_MAX_presolve_default',
#  'CLIQUE_STD_presolve_default',
#  'DYNAMISM_MEAN_presolve_default',
#  'DYNAMISM_MAX_presolve_default',
#  'DYNAMISM_STD_presolve_default',
#  'DYNAMISM_MEDIAN_presolve_default',
#  'VARS_presolve_off',
#  'BIN_VARS_presolve_off',
#  'CONT_VARS_presolve_off',
#  'PER_FINITE_UB_presolve_off',
#  'UPPERBOUNDS_MEAN_presolve_off',
#  'UPPERBOUNDS_MIN_presolve_off',
#  'UPPERBOUNDS_STD_presolve_off',
#  'LOWERBOUNDS_MEAN_presolve_off',
#  'LOWERBOUNDS_MIN_presolve_off',
#  'LOWERBOUNDS_MAX_presolve_off',
#  'LOWERBOUNDS_STD_presolve_off',
#  'LOWERBOUNDS_DENSITY_presolve_off',
#  'BOUNDRANGE_MEAN_presolve_off',
#  'BOUNDRANGE_MAX_presolve_off',
#  'BOUNDRANGE_STD_presolve_off',
#  'BOUNDRANGE_MEDIAN_presolve_off',
#  'OBJCOEFF_ALL_MEAN_presolve_off',
#  'OBJCOEFF_ALL_STD_presolve_off',
#  'OBJCOEFF_CONT_MEAN_presolve_off',
#  'CONSTR_presolve_off',
#  'LINSING_CONSTR_presolve_off',
#  'LINVARBD_CONSTR_presolve_off',
#  'LINMIXBIN_CONSTR_presolve_off',
#  'CONSTR_MEAN_presolve_off',
#  'CONSTR_MAX_presolve_off',
#  'CONSTR_STD_presolve_off',
#  'RH_CONSTR_MEAN_presolve_off',
#  'RH_CONSTR_MIN_presolve_off',
#  'RH_CONSTR_MAX_presolve_off',
#  'RH_CONSTR_STD_presolve_off',
#  'RH_CONSTR_DENSITY_presolve_off',
#  'LH_CONSTR_MEAN_presolve_off',
#  'LH_CONSTR_MIN_presolve_off',
#  'LH_CONSTR_STD_presolve_off',
#  'LH_CONSTR_DENSITY_presolve_off',
#  'RH_CONSTR_RATIO_presolve_off',
#  'LH_CONSTR_RATIO_presolve_off',
#  'NVAR_ALL_MEAN_presolve_off',
#  'NVAR_ALL_MAX_presolve_off',
#  'NVAR_ALL_STD_presolve_off',
#  'CONSTR_COEFF_MEAN_MEAN_presolve_off',
#  'CONSTR_COEFF_MEAN_MIN_presolve_off',
#  'CONSTR_COEFF_MEAN_STD_presolve_off',
#  'CONSTR_COEFF_MIN_MEAN_presolve_off',
#  'CONSTR_COEFF_MIN_STD_presolve_off',
#  'CONSTR_COEFF_MAX_MEAN_presolve_off',
#  'CONSTR_COEFF_MAX_MIN_presolve_off',
#  'CONSTR_COEFF_MAX_STD_presolve_off',
#  'CONSTR_COEFF_STD_MEAN_presolve_off',
#  'CONSTR_COEFF_STD_STD_presolve_off',
#  'CONSTR_COEFF_STD_MEDIAN_presolve_off',
#  'CONSTR_MATRIX_DENSITY_presolve_off',
#  'NONZEROES_presolve_off',
#  'CLIQUE_MEAN_presolve_off',
#  'CLIQUE_MIN_presolve_off',
#  'CLIQUE_MAX_presolve_off',
#  'CLIQUE_STD_presolve_off',
#  'DYNAMISM_MEAN_presolve_off',
#  'DYNAMISM_STD_presolve_off',
#  'solvingtime',
#  'readingtime',
#  'copyingtime',
#  'PresolvedProblem_Variables',
#  'feasibleleaves',
#  'objectiveleaves',
#  'nodesleft',
#  'avgswitchlength',
#  'FirstLPIters',
#  'FirstLPTime',
#  'FinalDualBound',
#  'FinalRootIters',
#  'RootLPEstimate',
#  'Solutionsfound',
#  'PrimalBound',
#  'Gap',
#  'FirstSolution',
#  'GapFirstSol.',
#  'GapLastSol.',
#  'PresolvedProblem_Variables_Binary',
#  'PresolvedProblem_Variables_Continuous',
#  'PresolvedProblem_Constraints_initial',
#  'PresolvedProblem_Constraints_maximal',
#  'PresolvedProblem_Nonzeros_constraint',
#  'PresolvedProblem_Nonzeros_clique',
#  'Presolvers_domcol_ExecTime',
#  'Presolvers_domcol_Calls',
#  'Presolvers_dualcomp_ExecTime',
#  'Presolvers_dualsparsify_ExecTime',
#  'Presolvers_dualsparsify_DelCons',
#  'Presolvers_implics_Calls',
#  'Presolvers_milp_ExecTime',
#  'Presolvers_milp_Calls',
#  'Presolvers_milp_FixedVars',
#  'Presolvers_milp_ChgBounds',
#  'Presolvers_sparsify_ExecTime',
#  'Presolvers_trivial_Calls',
#  'Presolvers_probing_ExecTime',
#  'Presolvers_probing_FixedVars',
#  'Presolvers_symmetry_ExecTime',
#  'Presolvers_vbounds_Calls',
#  'Presolvers_varbound_Calls',
#  'Presolvers_varbound_DelCons',
#  'Presolvers_setppc_Calls',
#  'Presolvers_linear_ExecTime',
#  'Presolvers_linear_SetupTime',
#  'Presolvers_linear_Calls',
#  'Presolvers_linear_ChgBounds',
#  'Presolvers_linear_DelCons',
#  'Presolvers_linear_ChgSides',
#  'Presolvers_components_ExecTime',
#  'Presolvers_rootnode_FixedVars',
#  'Presolvers_rootnode_ChgBounds',
#  'Constraints_benderslp_#EnfoLP',
#  'Constraints_benderslp_#Check',
#  'Constraints_integral_DomReds',
#  'Constraints_integral_Conss',
#  'Constraints_varbound_1_Number',
#  'Constraints_varbound_1_MaxNumber',
#  'Constraints_varbound_1_#Separate',
#  'Constraints_varbound_1_#Propagate',
#  'Constraints_varbound_1_#Check',
#  'Constraints_varbound_1_#ResProp',
#  'Constraints_varbound_1_Cutoffs',
#  'Constraints_varbound_1_DomReds',
#  'Constraints_setppc_1_MaxNumber',
#  'Constraints_setppc_1_#Separate',
#  'Constraints_setppc_1_#Propagate',
#  'Constraints_setppc_1_#Check',
#  'Constraints_setppc_1_#ResProp',
#  'Constraints_setppc_1_Cutoffs',
#  'Constraints_setppc_1_DomReds',
#  'Constraints_setppc_1_Cuts',
#  'Constraints_setppc_1_Applied',
#  'Constraints_linear_1_Number',
#  'Constraints_linear_1_MaxNumber',
#  'Constraints_linear_1_#Propagate',
#  'Constraints_linear_1_#Check',
#  'Constraints_linear_1_#ResProp',
#  'Constraints_linear_1_Cutoffs',
#  'Constraints_linear_1_DomReds',
#  'Constraints_logicor_1_MaxNumber',
#  'Constraints_logicor_1_#Separate',
#  'Constraints_logicor_1_#Propagate',
#  'Constraints_logicor_1_#ResProp',
#  'Constraints_logicor_1_Cutoffs',
#  'Constraints_logicor_1_Cuts',
#  'Constraints_logicor_1_Applied',
#  'Constraints_benders_1_#Check',
#  'ConstraintTimings_integral_1_TotalTime',
#  'ConstraintTimings_integral_1_EnfoLP',
#  'ConstraintTimings_varbound_2_TotalTime',
#  'ConstraintTimings_varbound_2_Separate',
#  'ConstraintTimings_varbound_2_Propagate',
#  'ConstraintTimings_varbound_2_ResProp',
#  'ConstraintTimings_setppc_2_TotalTime',
#  'ConstraintTimings_setppc_2_Propagate',
#  'ConstraintTimings_linear_2_TotalTime',
#  'ConstraintTimings_linear_2_Separate',
#  'ConstraintTimings_linear_2_Propagate',
#  'ConstraintTimings_linear_2_Check',
#  'ConstraintTimings_linear_2_ResProp',
#  'ConstraintTimings_linear_2_SB-Prop',
#  'Propagators_dualfix_1_#Propagate',
#  'Propagators_pseudoobj_1_#Propagate',
#  'Propagators_pseudoobj_1_DomReds',
#  'Propagators_redcost_#Propagate',
#  'Propagators_vbounds_1_#Propagate',
#  'PropagatorTimings_probing_2_TotalTime',
#  'PropagatorTimings_symmetry_2_TotalTime',
#  'ConflictAnalysis_propagation_Time',
#  'ConflictAnalysis_propagation_Calls',
#  'ConflictAnalysis_propagation_Success',
#  'ConflictAnalysis_propagation_Conflicts',
#  'ConflictAnalysis_propagation_Literals',
#  'ConflictAnalysis_propagation_Reconvs',
#  'ConflictAnalysis_propagation_ReconvLits',
#  'ConflictAnalysis_infeasibleLP_Time',
#  'ConflictAnalysis_infeasibleLP_Calls',
#  'ConflictAnalysis_infeasibleLP_Success',
#  'ConflictAnalysis_infeasibleLP_Conflicts',
#  'ConflictAnalysis_infeasibleLP_Literals',
#  'ConflictAnalysis_infeasibleLP_Reconvs',
#  'ConflictAnalysis_infeasibleLP_ReconvLits',
#  'ConflictAnalysis_infeasibleLP_Dualrays',
#  'ConflictAnalysis_infeasibleLP_Nonzeros',
#  'ConflictAnalysis_boundexceed.LP_Time',
#  'ConflictAnalysis_boundexceed.LP_Calls',
#  'ConflictAnalysis_boundexceed.LP_Success',
#  'ConflictAnalysis_boundexceed.LP_Conflicts',
#  'ConflictAnalysis_boundexceed.LP_Literals',
#  'ConflictAnalysis_boundexceed.LP_Reconvs',
#  'ConflictAnalysis_boundexceed.LP_ReconvLits',
#  'ConflictAnalysis_boundexceed.LP_Dualrays',
#  'ConflictAnalysis_boundexceed.LP_LP',
#  'ConflictAnalysis_pseudosolution_Calls',
#  'ConflictAnalysis_appliedglobally_DomReds',
#  'ConflictAnalysis_appliedglobally_Conflicts',
#  'ConflictAnalysis_appliedglobally_Literals',
#  'ConflictAnalysis_appliedglobally_Dualrays',
#  'ConflictAnalysis_appliedlocally_Conflicts',
#  'ConflictAnalysis_appliedlocally_Literals',
#  'Separators_cutpool_ExecTime',
#  'Separators_cutpool_Calls',
#  'Separators_cutpool_FoundCuts',
#  'Separators_cutpool_ViaPoolAdd',
#  'Separators_aggregation_ExecTime',
#  'Separators_aggregation_FoundCuts',
#  'Separators_aggregation_ViaPoolAdd',
#  'Separators_aggregation_Applied',
#  'Separators_>cmir_ViaPoolAdd',
#  'Separators_>cmir_Applied',
#  'Separators_>flowcover_ViaPoolAdd',
#  'Separators_>flowcover_Applied',
#  'Separators_>knapsackcover_ViaPoolAdd',
#  'Separators_>knapsackcover_Applied',
#  'Separators_clique_FoundCuts',
#  'Separators_clique_ViaPoolAdd',
#  'Separators_clique_Applied',
#  'Separators_gomory_ExecTime',
#  'Separators_gomory_FoundCuts',
#  'Separators_gomory_ViaPoolAdd',
#  'Separators_gomory_Applied',
#  'Separators_impliedbounds_FoundCuts',
#  'Separators_impliedbounds_ViaPoolAdd',
#  'Separators_impliedbounds_Applied',
#  'Separators_mcf_ExecTime',
#  'Separators_mixing_FoundCuts',
#  'Separators_mixing_ViaPoolAdd',
#  'Separators_mixing_Applied',
#  'Separators_zerohalf_Calls',
#  'Separators_zerohalf_FoundCuts',
#  'Separators_zerohalf_ViaPoolAdd',
#  'Cutselectors_hybrid_ExecTime',
#  'Cutselectors_hybrid_Calls',
#  'Cutselectors_hybrid_Selected',
#  'Cutselectors_hybrid_Forced',
#  'Cutselectors_hybrid_Filtered',
#  'BranchingRules_relpscost_ExecTime',
#  'BranchingRules_relpscost_BranchLP',
#  'PrimalHeuristics_alns_ExecTime',
#  'PrimalHeuristics_alns_Calls',
#  'PrimalHeuristics_clique_1_ExecTime',
#  'PrimalHeuristics_conflictdiving_ExecTime',
#  'PrimalHeuristics_conflictdiving_Calls',
#  'PrimalHeuristics_feaspump_ExecTime',
#  'PrimalHeuristics_feaspump_Found',
#  'PrimalHeuristics_intshifting_ExecTime',
#  'PrimalHeuristics_intshifting_Calls',
#  'PrimalHeuristics_locks_ExecTime',
#  'PrimalHeuristics_oneopt_ExecTime',
#  'PrimalHeuristics_oneopt_Calls',
#  'PrimalHeuristics_randrounding_ExecTime',
#  'PrimalHeuristics_randrounding_Calls',
#  'PrimalHeuristics_rens_ExecTime',
#  'PrimalHeuristics_rens_Calls',
#  'PrimalHeuristics_rens_Found',
#  'PrimalHeuristics_rounding_Calls',
#  'PrimalHeuristics_shiftandpropagate_ExecTime',
#  'PrimalHeuristics_shifting_ExecTime',
#  'PrimalHeuristics_zirounding_Calls',
#  'PrimalHeuristics_zirounding_Found',
#  'LP_primalLP_Time',
#  'LP_primalLP_Calls',
#  'LP_primalLP_Iterations',
#  'LP_primalLP_Iter/call',
#  'LP_primalLP_Iter/sec',
#  'LP_primalLP_Time-0-It',
#  'LP_primalLP_Calls-0-It',
#  'LP_dualLP_Time',
#  'LP_dualLP_Calls',
#  'LP_dualLP_Iterations',
#  'LP_dualLP_Iter/call',
#  'LP_dualLP_Iter/sec',
#  'LP_dualLP_Time-0-It',
#  'LP_dualLP_Calls-0-It',
#  'LP_resolveinstable_Time',
#  'LP_resolveinstable_Calls',
#  'LP_resolveinstable_Iterations',
#  'LP_resolveinstable_Iter/call',
#  'LP_resolveinstable_Iter/sec',
#  'LP_diving/probingLP_Time',
#  'LP_diving/probingLP_Calls',
#  'LP_diving/probingLP_Iterations',
#  'LP_diving/probingLP_Iter/call',
#  'LP_diving/probingLP_Iter/sec',
#  'LP_strongbranching_2_Time',
#  'LP_strongbranching_2_Calls',
#  'LP_strongbranching_2_Iterations',
#  'LP_strongbranching_2_Iter/call',
#  'LP_strongbranching_2_Iter/sec',
#  'LP_strongbranching_2_ItLimit',
#  'LP_conflictanalysis_Time',
#  'LP_conflictanalysis_Calls',
#  'LP_conflictanalysis_Iter/call',
#  'FirstLPIters_persecond',
#  'Integrals_primal-dual_Total',
#  'Integrals_primal-dual_Avg%']

# %%
features_df = features_df[new_cols]
features_df
# Out:
#      instance_id  repetition  VARS_presolve_default  \
# 0           mip1           1                 1437.0
# 1          mip10           1                 1403.0
# 2         mip100           1                 1399.0
# 3        mip1000           1                 1443.0
# 4       mip10000           1                 1329.0
# ...          ...         ...                    ...
# 9995     mip9995           1                 1375.0
# 9996     mip9996           1                 1275.0
# 9997     mip9997           1                 1379.0
# 9998     mip9998           1                 1365.0
# 9999     mip9999           1                 1375.0
#
#       BIN_VARS_presolve_default  CONT_VARS_presolve_default  \
# 0                         330.0                      1107.0
# 1                         313.0                      1090.0
# 2                         311.0                      1088.0
# 3                         333.0                      1110.0
# 4                         276.0                      1053.0
# ...                         ...                         ...
# 9995                      299.0                      1076.0
# 9996                      249.0                      1026.0
# 9997                      301.0                      1078.0
# 9998                      294.0                      1071.0
# 9999                      299.0                      1076.0
#
#       UPPERBOUNDS_MEAN_presolve_default  UPPERBOUNDS_MIN_presolve_default  \
# 0                              0.452455                      8.326673e-17
# 1                              0.459198                      8.326673e-17
# 2                              0.432643                      8.326673e-17
# 3                              0.466921                      8.326673e-17
# 4                              0.423002                      3.921569e-03
# ...                                 ...                               ...
# 9995                           0.441397                      8.326673e-17
# 9996                           0.380774                      8.326673e-17
# 9997                           0.418347                      1.347221e-04
# 9998                           0.430596                      8.326673e-17
# 9999                           0.446893                      8.326673e-17
#
#       UPPERBOUNDS_MAX_presolve_default  UPPERBOUNDS_STD_presolve_default  \
# 0                             4.014668                          0.208556
# 1                             4.514678                          0.241107
# 2                             4.140987                          0.204747
# 3                             4.464831                          0.221774
# 4                             3.856785                          0.220129
# ...                                ...                               ...
# 9995                          3.593675                          0.207536
# 9996                          3.215775                          0.189279
# 9997                          3.886279                          0.207325
# 9998                          4.260940                          0.212202
# 9999                          4.353233                          0.230003
#
#       UPPERBOUNDS_MEDIAN_presolve_default  ...  \
# 0                                     0.1  ...
# 1                                     0.1  ...
# 2                                     0.1  ...
# 3                                     0.1  ...
# 4                                     0.1  ...
# ...                                   ...  ...
# 9995                                  0.1  ...
# 9996                                  0.1  ...
# 9997                                  0.1  ...
# 9998                                  0.1  ...
# 9999                                  0.1  ...
#
#       LP_strongbranching_2_Iterations  LP_strongbranching_2_Iter/call  \
# 0                              9068.0                          503.78
# 1                             34576.0                          501.10
# 2                             15531.0                          501.00
# 3                              7733.0                          483.31
# 4                             18120.0                          503.33
# ...                               ...                             ...
# 9995                          11526.0                          501.13
# 9996                           9689.0                          509.95
# 9997                          10107.0                          505.35
# 9998                          11689.0                          508.22
# 9999                           6108.0                          509.00
#
#       LP_strongbranching_2_Iter/sec  LP_strongbranching_2_ItLimit  \
# 0                           3943.55                          18.0
# 1                           3416.29                          69.0
# 2                           3656.85                          31.0
# 3                           3250.74                          14.0
# 4                           3253.58                          36.0
# ...                             ...                           ...
# 9995                        4042.59                          23.0
# 9996                        3498.07                          19.0
# 9997                        2445.63                          20.0
# 9998                        4380.38                          22.0
# 9999                        4165.02                          12.0
#
#       LP_conflictanalysis_Time  LP_conflictanalysis_Calls  \
# 0                          0.0                        1.0
# 1                          0.0                        0.0
# 2                          0.0                        0.0
# 3                          0.0                        1.0
# 4                          0.0                        0.0
# ...                        ...                        ...
# 9995                       0.0                        0.0
# 9996                       0.0                        0.0
# 9997                       0.0                        0.0
# 9998                       0.0                        0.0
# 9999                       0.0                        0.0
#
#       LP_conflictanalysis_Iter/call  FirstLPIters_persecond  \
# 0                               0.0                10024.94
# 1                               0.0                 6630.76
# 2                               0.0                 6675.08
# 3                               0.0                 6334.76
# 4                               0.0                 5678.14
# ...                             ...                     ...
# 9995                            0.0                 7945.45
# 9996                            0.0                12400.55
# 9997                            0.0                 7913.33
# 9998                            0.0                 6605.43
# 9999                            0.0                 9894.03
#
#       Integrals_primal-dual_Total  Integrals_primal-dual_Avg%
# 0                         2257.16                       100.0
# 1                         1954.25                       100.0
# 2                         3152.15                       100.0
# 3                         3848.17                       100.0
# 4                         1671.32                       100.0
# ...                           ...                         ...
# 9995                      1155.12                       100.0
# 9996                      1059.17                       100.0
# 9997                      1258.05                       100.0
# 9998                      1954.18                       100.0
# 9999                      1774.44                       100.0
#
# [10000 rows x 363 columns]

# %%
id_order = list(features_df.instance_id)

# %%
test_data = {'test1':[1,2,3],'test2':[4,5,6],'test3':['a','b','c']}
example_test_df = pd.DataFrame(test_data)
example_test_df
# Out:
#    test1  test2 test3
# 0      1      4     a
# 1      2      5     b
# 2      3      6     c

# %%
for index,row in example_test_df.iterrows():
    print(str(list(row)).strip("[]").replace("'", ""))
# Out:
# 1, 4, a
# 2, 5, b
# 3, 6, c

# %%
# @ATTRIBUTE instance_id STRING
# Add all attributes in correct order

with open("feature_values.arff","a") as file:
    for col in features_df.columns:
        file.write("\n")
        if col == 'instance_id':
            newrow = '@ATTRIBUTE ' + col + ' STRING'
        else:
            newrow = '@ATTRIBUTE ' + col + ' NUMERIC'
        file.write(newrow)

    file.close()

# %%
# Get comma seperated rows and iteratively add to feature_values.arff
with open("MIPVerifySDP_SCIPfeatureset/feature_values.arff","a") as file:
    for index,row in features_df.iterrows():
        file.write("\n")
        newrow = str(list(row)).strip("[]").replace("'", "")
        file.write(newrow)

    file.close()

# %%
# double check the column order
for i in features_df.columns:
    print(i)
# Out:
# instance_id
# repetition
# VARS_presolve_default
# BIN_VARS_presolve_default
# CONT_VARS_presolve_default
# UPPERBOUNDS_MEAN_presolve_default
# UPPERBOUNDS_MIN_presolve_default
# UPPERBOUNDS_MAX_presolve_default
# UPPERBOUNDS_STD_presolve_default
# UPPERBOUNDS_MEDIAN_presolve_default
# UPPERBOUNDS_DENSITY_presolve_default
# LOWERBOUNDS_MEAN_presolve_default
# LOWERBOUNDS_MIN_presolve_default
# LOWERBOUNDS_MAX_presolve_default
# LOWERBOUNDS_STD_presolve_default
# LOWERBOUNDS_DENSITY_presolve_default
# BOUNDRANGE_MEAN_presolve_default
# BOUNDRANGE_MIN_presolve_default
# BOUNDRANGE_MAX_presolve_default
# BOUNDRANGE_STD_presolve_default
# BOUNDRANGE_MEDIAN_presolve_default
# OBJCOEFF_ALL_MEAN_presolve_default
# OBJCOEFF_ALL_STD_presolve_default
# OBJCOEFF_CONT_MEAN_presolve_default
# OBJCOEFF_CONT_STD_presolve_default
# CONSTR_presolve_default
# LINSING_CONSTR_presolve_default
# LINPREC_CONSTR_presolve_default
# LINVARBD_CONSTR_presolve_default
# LINMIXBIN_CONSTR_presolve_default
# CONSTR_MEAN_presolve_default
# CONSTR_MAX_presolve_default
# CONSTR_STD_presolve_default
# RH_CONSTR_MEAN_presolve_default
# RH_CONSTR_MAX_presolve_default
# RH_CONSTR_STD_presolve_default
# RH_CONSTR_DENSITY_presolve_default
# LH_CONSTR_MEAN_presolve_default
# LH_CONSTR_MIN_presolve_default
# LH_CONSTR_MAX_presolve_default
# LH_CONSTR_STD_presolve_default
# LH_CONSTR_MEDIAN_presolve_default
# RH_CONSTR_RATIO_presolve_default
# LH_CONSTR_RATIO_presolve_default
# NVAR_ALL_MEAN_presolve_default
# NVAR_ALL_MIN_presolve_default
# NVAR_ALL_STD_presolve_default
# CONSTR_COEFF_MEAN_MEAN_presolve_default
# CONSTR_COEFF_MEAN_STD_presolve_default
# CONSTR_COEFF_MIN_MEAN_presolve_default
# CONSTR_COEFF_MIN_STD_presolve_default
# CONSTR_COEFF_MAX_MEAN_presolve_default
# CONSTR_COEFF_MAX_STD_presolve_default
# CONSTR_COEFF_STD_MEAN_presolve_default
# CONSTR_COEFF_STD_STD_presolve_default
# CONSTR_COEFF_STD_MEDIAN_presolve_default
# CONSTR_MATRIX_DENSITY_presolve_default
# NONZEROES_presolve_default
# CLIQUE_MEAN_presolve_default
# CLIQUE_MIN_presolve_default
# CLIQUE_MAX_presolve_default
# CLIQUE_STD_presolve_default
# DYNAMISM_MEAN_presolve_default
# DYNAMISM_MAX_presolve_default
# DYNAMISM_STD_presolve_default
# DYNAMISM_MEDIAN_presolve_default
# VARS_presolve_off
# BIN_VARS_presolve_off
# CONT_VARS_presolve_off
# PER_FINITE_UB_presolve_off
# UPPERBOUNDS_MEAN_presolve_off
# UPPERBOUNDS_MIN_presolve_off
# UPPERBOUNDS_STD_presolve_off
# LOWERBOUNDS_MEAN_presolve_off
# LOWERBOUNDS_MIN_presolve_off
# LOWERBOUNDS_MAX_presolve_off
# LOWERBOUNDS_STD_presolve_off
# LOWERBOUNDS_DENSITY_presolve_off
# BOUNDRANGE_MEAN_presolve_off
# BOUNDRANGE_MAX_presolve_off
# BOUNDRANGE_STD_presolve_off
# BOUNDRANGE_MEDIAN_presolve_off
# OBJCOEFF_ALL_MEAN_presolve_off
# OBJCOEFF_ALL_STD_presolve_off
# OBJCOEFF_CONT_MEAN_presolve_off
# CONSTR_presolve_off
# LINSING_CONSTR_presolve_off
# LINVARBD_CONSTR_presolve_off
# LINMIXBIN_CONSTR_presolve_off
# CONSTR_MEAN_presolve_off
# CONSTR_MAX_presolve_off
# CONSTR_STD_presolve_off
# RH_CONSTR_MEAN_presolve_off
# RH_CONSTR_MIN_presolve_off
# RH_CONSTR_MAX_presolve_off
# RH_CONSTR_STD_presolve_off
# RH_CONSTR_DENSITY_presolve_off
# LH_CONSTR_MEAN_presolve_off
# LH_CONSTR_MIN_presolve_off
# LH_CONSTR_STD_presolve_off
# LH_CONSTR_DENSITY_presolve_off
# RH_CONSTR_RATIO_presolve_off
# LH_CONSTR_RATIO_presolve_off
# NVAR_ALL_MEAN_presolve_off
# NVAR_ALL_MAX_presolve_off
# NVAR_ALL_STD_presolve_off
# CONSTR_COEFF_MEAN_MEAN_presolve_off
# CONSTR_COEFF_MEAN_MIN_presolve_off
# CONSTR_COEFF_MEAN_STD_presolve_off
# CONSTR_COEFF_MIN_MEAN_presolve_off
# CONSTR_COEFF_MIN_STD_presolve_off
# CONSTR_COEFF_MAX_MEAN_presolve_off
# CONSTR_COEFF_MAX_MIN_presolve_off
# CONSTR_COEFF_MAX_STD_presolve_off
# CONSTR_COEFF_STD_MEAN_presolve_off
# CONSTR_COEFF_STD_STD_presolve_off
# CONSTR_COEFF_STD_MEDIAN_presolve_off
# CONSTR_MATRIX_DENSITY_presolve_off
# NONZEROES_presolve_off
# CLIQUE_MEAN_presolve_off
# CLIQUE_MIN_presolve_off
# CLIQUE_MAX_presolve_off
# CLIQUE_STD_presolve_off
# DYNAMISM_MEAN_presolve_off
# DYNAMISM_STD_presolve_off
# solvingtime
# readingtime
# copyingtime
# PresolvedProblem_Variables
# feasibleleaves
# objectiveleaves
# nodesleft
# avgswitchlength
# FirstLPIters
# FirstLPTime
# FinalDualBound
# FinalRootIters
# RootLPEstimate
# Solutionsfound
# PrimalBound
# Gap
# FirstSolution
# GapFirstSol.
# GapLastSol.
# PresolvedProblem_Variables_Binary
# PresolvedProblem_Variables_Continuous
# PresolvedProblem_Constraints_initial
# PresolvedProblem_Constraints_maximal
# PresolvedProblem_Nonzeros_constraint
# PresolvedProblem_Nonzeros_clique
# Presolvers_domcol_ExecTime
# Presolvers_domcol_Calls
# Presolvers_dualcomp_ExecTime
# Presolvers_dualsparsify_ExecTime
# Presolvers_dualsparsify_DelCons
# Presolvers_implics_Calls
# Presolvers_milp_ExecTime
# Presolvers_milp_Calls
# Presolvers_milp_FixedVars
# Presolvers_milp_ChgBounds
# Presolvers_sparsify_ExecTime
# Presolvers_trivial_Calls
# Presolvers_probing_ExecTime
# Presolvers_probing_FixedVars
# Presolvers_symmetry_ExecTime
# Presolvers_vbounds_Calls
# Presolvers_varbound_Calls
# Presolvers_varbound_DelCons
# Presolvers_setppc_Calls
# Presolvers_linear_ExecTime
# Presolvers_linear_SetupTime
# Presolvers_linear_Calls
# Presolvers_linear_ChgBounds
# Presolvers_linear_DelCons
# Presolvers_linear_ChgSides
# Presolvers_components_ExecTime
# Presolvers_rootnode_FixedVars
# Presolvers_rootnode_ChgBounds
# Constraints_benderslp_#EnfoLP
# Constraints_benderslp_#Check
# Constraints_integral_DomReds
# Constraints_integral_Conss
# Constraints_varbound_1_Number
# Constraints_varbound_1_MaxNumber
# Constraints_varbound_1_#Separate
# Constraints_varbound_1_#Propagate
# Constraints_varbound_1_#Check
# Constraints_varbound_1_#ResProp
# Constraints_varbound_1_Cutoffs
# Constraints_varbound_1_DomReds
# Constraints_setppc_1_MaxNumber
# Constraints_setppc_1_#Separate
# Constraints_setppc_1_#Propagate
# Constraints_setppc_1_#Check
# Constraints_setppc_1_#ResProp
# Constraints_setppc_1_Cutoffs
# Constraints_setppc_1_DomReds
# Constraints_setppc_1_Cuts
# Constraints_setppc_1_Applied
# Constraints_linear_1_Number
# Constraints_linear_1_MaxNumber
# Constraints_linear_1_#Propagate
# Constraints_linear_1_#Check
# Constraints_linear_1_#ResProp
# Constraints_linear_1_Cutoffs
# Constraints_linear_1_DomReds
# Constraints_logicor_1_MaxNumber
# Constraints_logicor_1_#Separate
# Constraints_logicor_1_#Propagate
# Constraints_logicor_1_#ResProp
# Constraints_logicor_1_Cutoffs
# Constraints_logicor_1_Cuts
# Constraints_logicor_1_Applied
# Constraints_benders_1_#Check
# ConstraintTimings_integral_1_TotalTime
# ConstraintTimings_integral_1_EnfoLP
# ConstraintTimings_varbound_2_TotalTime
# ConstraintTimings_varbound_2_Separate
# ConstraintTimings_varbound_2_Propagate
# ConstraintTimings_varbound_2_ResProp
# ConstraintTimings_setppc_2_TotalTime
# ConstraintTimings_setppc_2_Propagate
# ConstraintTimings_linear_2_TotalTime
# ConstraintTimings_linear_2_Separate
# ConstraintTimings_linear_2_Propagate
# ConstraintTimings_linear_2_Check
# ConstraintTimings_linear_2_ResProp
# ConstraintTimings_linear_2_SB-Prop
# Propagators_dualfix_1_#Propagate
# Propagators_pseudoobj_1_#Propagate
# Propagators_pseudoobj_1_DomReds
# Propagators_redcost_#Propagate
# Propagators_vbounds_1_#Propagate
# PropagatorTimings_probing_2_TotalTime
# PropagatorTimings_symmetry_2_TotalTime
# ConflictAnalysis_propagation_Time
# ConflictAnalysis_propagation_Calls
# ConflictAnalysis_propagation_Success
# ConflictAnalysis_propagation_Conflicts
# ConflictAnalysis_propagation_Literals
# ConflictAnalysis_propagation_Reconvs
# ConflictAnalysis_propagation_ReconvLits
# ConflictAnalysis_infeasibleLP_Time
# ConflictAnalysis_infeasibleLP_Calls
# ConflictAnalysis_infeasibleLP_Success
# ConflictAnalysis_infeasibleLP_Conflicts
# ConflictAnalysis_infeasibleLP_Literals
# ConflictAnalysis_infeasibleLP_Reconvs
# ConflictAnalysis_infeasibleLP_ReconvLits
# ConflictAnalysis_infeasibleLP_Dualrays
# ConflictAnalysis_infeasibleLP_Nonzeros
# ConflictAnalysis_boundexceed.LP_Time
# ConflictAnalysis_boundexceed.LP_Calls
# ConflictAnalysis_boundexceed.LP_Success
# ConflictAnalysis_boundexceed.LP_Conflicts
# ConflictAnalysis_boundexceed.LP_Literals
# ConflictAnalysis_boundexceed.LP_Reconvs
# ConflictAnalysis_boundexceed.LP_ReconvLits
# ConflictAnalysis_boundexceed.LP_Dualrays
# ConflictAnalysis_boundexceed.LP_LP
# ConflictAnalysis_pseudosolution_Calls
# ConflictAnalysis_appliedglobally_DomReds
# ConflictAnalysis_appliedglobally_Conflicts
# ConflictAnalysis_appliedglobally_Literals
# ConflictAnalysis_appliedglobally_Dualrays
# ConflictAnalysis_appliedlocally_Conflicts
# ConflictAnalysis_appliedlocally_Literals
# Separators_cutpool_ExecTime
# Separators_cutpool_Calls
# Separators_cutpool_FoundCuts
# Separators_cutpool_ViaPoolAdd
# Separators_aggregation_ExecTime
# Separators_aggregation_FoundCuts
# Separators_aggregation_ViaPoolAdd
# Separators_aggregation_Applied
# Separators_>cmir_ViaPoolAdd
# Separators_>cmir_Applied
# Separators_>flowcover_ViaPoolAdd
# Separators_>flowcover_Applied
# Separators_>knapsackcover_ViaPoolAdd
# Separators_>knapsackcover_Applied
# Separators_clique_FoundCuts
# Separators_clique_ViaPoolAdd
# Separators_clique_Applied
# Separators_gomory_ExecTime
# Separators_gomory_FoundCuts
# Separators_gomory_ViaPoolAdd
# Separators_gomory_Applied
# Separators_impliedbounds_FoundCuts
# Separators_impliedbounds_ViaPoolAdd
# Separators_impliedbounds_Applied
# Separators_mcf_ExecTime
# Separators_mixing_FoundCuts
# Separators_mixing_ViaPoolAdd
# Separators_mixing_Applied
# Separators_zerohalf_Calls
# Separators_zerohalf_FoundCuts
# Separators_zerohalf_ViaPoolAdd
# Cutselectors_hybrid_ExecTime
# Cutselectors_hybrid_Calls
# Cutselectors_hybrid_Selected
# Cutselectors_hybrid_Forced
# Cutselectors_hybrid_Filtered
# BranchingRules_relpscost_ExecTime
# BranchingRules_relpscost_BranchLP
# PrimalHeuristics_alns_ExecTime
# PrimalHeuristics_alns_Calls
# PrimalHeuristics_clique_1_ExecTime
# PrimalHeuristics_conflictdiving_ExecTime
# PrimalHeuristics_conflictdiving_Calls
# PrimalHeuristics_feaspump_ExecTime
# PrimalHeuristics_feaspump_Found
# PrimalHeuristics_intshifting_ExecTime
# PrimalHeuristics_intshifting_Calls
# PrimalHeuristics_locks_ExecTime
# PrimalHeuristics_oneopt_ExecTime
# PrimalHeuristics_oneopt_Calls
# PrimalHeuristics_randrounding_ExecTime
# PrimalHeuristics_randrounding_Calls
# PrimalHeuristics_rens_ExecTime
# PrimalHeuristics_rens_Calls
# PrimalHeuristics_rens_Found
# PrimalHeuristics_rounding_Calls
# PrimalHeuristics_shiftandpropagate_ExecTime
# PrimalHeuristics_shifting_ExecTime
# PrimalHeuristics_zirounding_Calls
# PrimalHeuristics_zirounding_Found
# LP_primalLP_Time
# LP_primalLP_Calls
# LP_primalLP_Iterations
# LP_primalLP_Iter/call
# LP_primalLP_Iter/sec
# LP_primalLP_Time-0-It
# LP_primalLP_Calls-0-It
# LP_dualLP_Time
# LP_dualLP_Calls
# LP_dualLP_Iterations
# LP_dualLP_Iter/call
# LP_dualLP_Iter/sec
# LP_dualLP_Time-0-It
# LP_dualLP_Calls-0-It
# LP_resolveinstable_Time
# LP_resolveinstable_Calls
# LP_resolveinstable_Iterations
# LP_resolveinstable_Iter/call
# LP_resolveinstable_Iter/sec
# LP_diving/probingLP_Time
# LP_diving/probingLP_Calls
# LP_diving/probingLP_Iterations
# LP_diving/probingLP_Iter/call
# LP_diving/probingLP_Iter/sec
# LP_strongbranching_2_Time
# LP_strongbranching_2_Calls
# LP_strongbranching_2_Iterations
# LP_strongbranching_2_Iter/call
# LP_strongbranching_2_Iter/sec
# LP_strongbranching_2_ItLimit
# LP_conflictanalysis_Time
# LP_conflictanalysis_Calls
# LP_conflictanalysis_Iter/call
# FirstLPIters_persecond
# Integrals_primal-dual_Total
# Integrals_primal-dual_Avg%

# %%
import re

_RE_ATTRIBUTE = re.compile(r'^(\".*\"|\'.*\'|[^\{\}%,\s]*)\s+(.+)$', re.UNICODE)

for col in features_df.columns:
    if col == 'instance_id':
        s = '@ATTRIBUTE ' + col + ' STRING'
    else:
        s = '@ATTRIBUTE ' + col + ' NUMERIC'
    _, v = s.split(' ', 1)
    v = v.strip()
    m = _RE_ATTRIBUTE.match(v)
    if not m:
        print('fail')
        print(v)
    else:
        print('pass')
        print(v)
# Out:
# pass
# instance_id STRING
# pass
# repetition NUMERIC
# pass
# VARS_presolve_default NUMERIC
# pass
# BIN_VARS_presolve_default NUMERIC
# pass
# CONT_VARS_presolve_default NUMERIC
# pass
# UPPERBOUNDS_MEAN_presolve_default NUMERIC
# pass
# UPPERBOUNDS_MIN_presolve_default NUMERIC
# pass
# UPPERBOUNDS_MAX_presolve_default NUMERIC
# pass
# UPPERBOUNDS_STD_presolve_default NUMERIC
# pass
# UPPERBOUNDS_MEDIAN_presolve_default NUMERIC
# pass
# UPPERBOUNDS_DENSITY_presolve_default NUMERIC
# pass
# LOWERBOUNDS_MEAN_presolve_default NUMERIC
# pass
# LOWERBOUNDS_MIN_presolve_default NUMERIC
# pass
# LOWERBOUNDS_MAX_presolve_default NUMERIC
# pass
# LOWERBOUNDS_STD_presolve_default NUMERIC
# pass
# LOWERBOUNDS_DENSITY_presolve_default NUMERIC
# pass
# BOUNDRANGE_MEAN_presolve_default NUMERIC
# pass
# BOUNDRANGE_MIN_presolve_default NUMERIC
# pass
# BOUNDRANGE_MAX_presolve_default NUMERIC
# pass
# BOUNDRANGE_STD_presolve_default NUMERIC
# pass
# BOUNDRANGE_MEDIAN_presolve_default NUMERIC
# pass
# OBJCOEFF_ALL_MEAN_presolve_default NUMERIC
# pass
# OBJCOEFF_ALL_STD_presolve_default NUMERIC
# pass
# OBJCOEFF_CONT_MEAN_presolve_default NUMERIC
# pass
# OBJCOEFF_CONT_STD_presolve_default NUMERIC
# pass
# CONSTR_presolve_default NUMERIC
# pass
# LINSING_CONSTR_presolve_default NUMERIC
# pass
# LINPREC_CONSTR_presolve_default NUMERIC
# pass
# LINVARBD_CONSTR_presolve_default NUMERIC
# pass
# LINMIXBIN_CONSTR_presolve_default NUMERIC
# pass
# CONSTR_MEAN_presolve_default NUMERIC
# pass
# CONSTR_MAX_presolve_default NUMERIC
# pass
# CONSTR_STD_presolve_default NUMERIC
# pass
# RH_CONSTR_MEAN_presolve_default NUMERIC
# pass
# RH_CONSTR_MAX_presolve_default NUMERIC
# pass
# RH_CONSTR_STD_presolve_default NUMERIC
# pass
# RH_CONSTR_DENSITY_presolve_default NUMERIC
# pass
# LH_CONSTR_MEAN_presolve_default NUMERIC
# pass
# LH_CONSTR_MIN_presolve_default NUMERIC
# pass
# LH_CONSTR_MAX_presolve_default NUMERIC
# pass
# LH_CONSTR_STD_presolve_default NUMERIC
# pass
# LH_CONSTR_MEDIAN_presolve_default NUMERIC
# pass
# RH_CONSTR_RATIO_presolve_default NUMERIC
# pass
# LH_CONSTR_RATIO_presolve_default NUMERIC
# pass
# NVAR_ALL_MEAN_presolve_default NUMERIC
# pass
# NVAR_ALL_MIN_presolve_default NUMERIC
# pass
# NVAR_ALL_STD_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MEAN_MEAN_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MEAN_STD_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MIN_MEAN_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MIN_STD_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MAX_MEAN_presolve_default NUMERIC
# pass
# CONSTR_COEFF_MAX_STD_presolve_default NUMERIC
# pass
# CONSTR_COEFF_STD_MEAN_presolve_default NUMERIC
# pass
# CONSTR_COEFF_STD_STD_presolve_default NUMERIC
# pass
# CONSTR_COEFF_STD_MEDIAN_presolve_default NUMERIC
# pass
# CONSTR_MATRIX_DENSITY_presolve_default NUMERIC
# pass
# NONZEROES_presolve_default NUMERIC
# pass
# CLIQUE_MEAN_presolve_default NUMERIC
# pass
# CLIQUE_MIN_presolve_default NUMERIC
# pass
# CLIQUE_MAX_presolve_default NUMERIC
# pass
# CLIQUE_STD_presolve_default NUMERIC
# pass
# DYNAMISM_MEAN_presolve_default NUMERIC
# pass
# DYNAMISM_MAX_presolve_default NUMERIC
# pass
# DYNAMISM_STD_presolve_default NUMERIC
# pass
# DYNAMISM_MEDIAN_presolve_default NUMERIC
# pass
# VARS_presolve_off NUMERIC
# pass
# BIN_VARS_presolve_off NUMERIC
# pass
# CONT_VARS_presolve_off NUMERIC
# pass
# PER_FINITE_UB_presolve_off NUMERIC
# pass
# UPPERBOUNDS_MEAN_presolve_off NUMERIC
# pass
# UPPERBOUNDS_MIN_presolve_off NUMERIC
# pass
# UPPERBOUNDS_STD_presolve_off NUMERIC
# pass
# LOWERBOUNDS_MEAN_presolve_off NUMERIC
# pass
# LOWERBOUNDS_MIN_presolve_off NUMERIC
# pass
# LOWERBOUNDS_MAX_presolve_off NUMERIC
# pass
# LOWERBOUNDS_STD_presolve_off NUMERIC
# pass
# LOWERBOUNDS_DENSITY_presolve_off NUMERIC
# pass
# BOUNDRANGE_MEAN_presolve_off NUMERIC
# pass
# BOUNDRANGE_MAX_presolve_off NUMERIC
# pass
# BOUNDRANGE_STD_presolve_off NUMERIC
# pass
# BOUNDRANGE_MEDIAN_presolve_off NUMERIC
# pass
# OBJCOEFF_ALL_MEAN_presolve_off NUMERIC
# pass
# OBJCOEFF_ALL_STD_presolve_off NUMERIC
# pass
# OBJCOEFF_CONT_MEAN_presolve_off NUMERIC
# pass
# CONSTR_presolve_off NUMERIC
# pass
# LINSING_CONSTR_presolve_off NUMERIC
# pass
# LINVARBD_CONSTR_presolve_off NUMERIC
# pass
# LINMIXBIN_CONSTR_presolve_off NUMERIC
# pass
# CONSTR_MEAN_presolve_off NUMERIC
# pass
# CONSTR_MAX_presolve_off NUMERIC
# pass
# CONSTR_STD_presolve_off NUMERIC
# pass
# RH_CONSTR_MEAN_presolve_off NUMERIC
# pass
# RH_CONSTR_MIN_presolve_off NUMERIC
# pass
# RH_CONSTR_MAX_presolve_off NUMERIC
# pass
# RH_CONSTR_STD_presolve_off NUMERIC
# pass
# RH_CONSTR_DENSITY_presolve_off NUMERIC
# pass
# LH_CONSTR_MEAN_presolve_off NUMERIC
# pass
# LH_CONSTR_MIN_presolve_off NUMERIC
# pass
# LH_CONSTR_STD_presolve_off NUMERIC
# pass
# LH_CONSTR_DENSITY_presolve_off NUMERIC
# pass
# RH_CONSTR_RATIO_presolve_off NUMERIC
# pass
# LH_CONSTR_RATIO_presolve_off NUMERIC
# pass
# NVAR_ALL_MEAN_presolve_off NUMERIC
# pass
# NVAR_ALL_MAX_presolve_off NUMERIC
# pass
# NVAR_ALL_STD_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MEAN_MEAN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MEAN_MIN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MEAN_STD_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MIN_MEAN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MIN_STD_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MAX_MEAN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MAX_MIN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_MAX_STD_presolve_off NUMERIC
# pass
# CONSTR_COEFF_STD_MEAN_presolve_off NUMERIC
# pass
# CONSTR_COEFF_STD_STD_presolve_off NUMERIC
# pass
# CONSTR_COEFF_STD_MEDIAN_presolve_off NUMERIC
# pass
# CONSTR_MATRIX_DENSITY_presolve_off NUMERIC
# pass
# NONZEROES_presolve_off NUMERIC
# pass
# CLIQUE_MEAN_presolve_off NUMERIC
# pass
# CLIQUE_MIN_presolve_off NUMERIC
# pass
# CLIQUE_MAX_presolve_off NUMERIC
# pass
# CLIQUE_STD_presolve_off NUMERIC
# pass
# DYNAMISM_MEAN_presolve_off NUMERIC
# pass
# DYNAMISM_STD_presolve_off NUMERIC
# pass
# solvingtime NUMERIC
# pass
# readingtime NUMERIC
# pass
# copyingtime NUMERIC
# pass
# PresolvedProblem_Variables NUMERIC
# pass
# feasibleleaves NUMERIC
# pass
# objectiveleaves NUMERIC
# pass
# nodesleft NUMERIC
# pass
# avgswitchlength NUMERIC
# pass
# FirstLPIters NUMERIC
# pass
# FirstLPTime NUMERIC
# pass
# FinalDualBound NUMERIC
# pass
# FinalRootIters NUMERIC
# pass
# RootLPEstimate NUMERIC
# pass
# Solutionsfound NUMERIC
# pass
# PrimalBound NUMERIC
# pass
# Gap NUMERIC
# pass
# FirstSolution NUMERIC
# pass
# GapFirstSol. NUMERIC
# pass
# GapLastSol. NUMERIC
# pass
# PresolvedProblem_Variables_Binary NUMERIC
# pass
# PresolvedProblem_Variables_Continuous NUMERIC
# pass
# PresolvedProblem_Constraints_initial NUMERIC
# pass
# PresolvedProblem_Constraints_maximal NUMERIC
# pass
# PresolvedProblem_Nonzeros_constraint NUMERIC
# pass
# PresolvedProblem_Nonzeros_clique NUMERIC
# pass
# Presolvers_domcol_ExecTime NUMERIC
# pass
# Presolvers_domcol_Calls NUMERIC
# pass
# Presolvers_dualcomp_ExecTime NUMERIC
# pass
# Presolvers_dualsparsify_ExecTime NUMERIC
# pass
# Presolvers_dualsparsify_DelCons NUMERIC
# pass
# Presolvers_implics_Calls NUMERIC
# pass
# Presolvers_milp_ExecTime NUMERIC
# pass
# Presolvers_milp_Calls NUMERIC
# pass
# Presolvers_milp_FixedVars NUMERIC
# pass
# Presolvers_milp_ChgBounds NUMERIC
# pass
# Presolvers_sparsify_ExecTime NUMERIC
# pass
# Presolvers_trivial_Calls NUMERIC
# pass
# Presolvers_probing_ExecTime NUMERIC
# pass
# Presolvers_probing_FixedVars NUMERIC
# pass
# Presolvers_symmetry_ExecTime NUMERIC
# pass
# Presolvers_vbounds_Calls NUMERIC
# pass
# Presolvers_varbound_Calls NUMERIC
# pass
# Presolvers_varbound_DelCons NUMERIC
# pass
# Presolvers_setppc_Calls NUMERIC
# pass
# Presolvers_linear_ExecTime NUMERIC
# pass
# Presolvers_linear_SetupTime NUMERIC
# pass
# Presolvers_linear_Calls NUMERIC
# pass
# Presolvers_linear_ChgBounds NUMERIC
# pass
# Presolvers_linear_DelCons NUMERIC
# pass
# Presolvers_linear_ChgSides NUMERIC
# pass
# Presolvers_components_ExecTime NUMERIC
# pass
# Presolvers_rootnode_FixedVars NUMERIC
# pass
# Presolvers_rootnode_ChgBounds NUMERIC
# pass
# Constraints_benderslp_#EnfoLP NUMERIC
# pass
# Constraints_benderslp_#Check NUMERIC
# pass
# Constraints_integral_DomReds NUMERIC
# pass
# Constraints_integral_Conss NUMERIC
# pass
# Constraints_varbound_1_Number NUMERIC
# pass
# Constraints_varbound_1_MaxNumber NUMERIC
# pass
# Constraints_varbound_1_#Separate NUMERIC
# pass
# Constraints_varbound_1_#Propagate NUMERIC
# pass
# Constraints_varbound_1_#Check NUMERIC
# pass
# Constraints_varbound_1_#ResProp NUMERIC
# pass
# Constraints_varbound_1_Cutoffs NUMERIC
# pass
# Constraints_varbound_1_DomReds NUMERIC
# pass
# Constraints_setppc_1_MaxNumber NUMERIC
# pass
# Constraints_setppc_1_#Separate NUMERIC
# pass
# Constraints_setppc_1_#Propagate NUMERIC
# pass
# Constraints_setppc_1_#Check NUMERIC
# pass
# Constraints_setppc_1_#ResProp NUMERIC
# pass
# Constraints_setppc_1_Cutoffs NUMERIC
# pass
# Constraints_setppc_1_DomReds NUMERIC
# pass
# Constraints_setppc_1_Cuts NUMERIC
# pass
# Constraints_setppc_1_Applied NUMERIC
# pass
# Constraints_linear_1_Number NUMERIC
# pass
# Constraints_linear_1_MaxNumber NUMERIC
# pass
# Constraints_linear_1_#Propagate NUMERIC
# pass
# Constraints_linear_1_#Check NUMERIC
# pass
# Constraints_linear_1_#ResProp NUMERIC
# pass
# Constraints_linear_1_Cutoffs NUMERIC
# pass
# Constraints_linear_1_DomReds NUMERIC
# pass
# Constraints_logicor_1_MaxNumber NUMERIC
# pass
# Constraints_logicor_1_#Separate NUMERIC
# pass
# Constraints_logicor_1_#Propagate NUMERIC
# pass
# Constraints_logicor_1_#ResProp NUMERIC
# pass
# Constraints_logicor_1_Cutoffs NUMERIC
# pass
# Constraints_logicor_1_Cuts NUMERIC
# pass
# Constraints_logicor_1_Applied NUMERIC
# pass
# Constraints_benders_1_#Check NUMERIC
# pass
# ConstraintTimings_integral_1_TotalTime NUMERIC
# pass
# ConstraintTimings_integral_1_EnfoLP NUMERIC
# pass
# ConstraintTimings_varbound_2_TotalTime NUMERIC
# pass
# ConstraintTimings_varbound_2_Separate NUMERIC
# pass
# ConstraintTimings_varbound_2_Propagate NUMERIC
# pass
# ConstraintTimings_varbound_2_ResProp NUMERIC
# pass
# ConstraintTimings_setppc_2_TotalTime NUMERIC
# pass
# ConstraintTimings_setppc_2_Propagate NUMERIC
# pass
# ConstraintTimings_linear_2_TotalTime NUMERIC
# pass
# ConstraintTimings_linear_2_Separate NUMERIC
# pass
# ConstraintTimings_linear_2_Propagate NUMERIC
# pass
# ConstraintTimings_linear_2_Check NUMERIC
# pass
# ConstraintTimings_linear_2_ResProp NUMERIC
# pass
# ConstraintTimings_linear_2_SB-Prop NUMERIC
# pass
# Propagators_dualfix_1_#Propagate NUMERIC
# pass
# Propagators_pseudoobj_1_#Propagate NUMERIC
# pass
# Propagators_pseudoobj_1_DomReds NUMERIC
# pass
# Propagators_redcost_#Propagate NUMERIC
# pass
# Propagators_vbounds_1_#Propagate NUMERIC
# pass
# PropagatorTimings_probing_2_TotalTime NUMERIC
# pass
# PropagatorTimings_symmetry_2_TotalTime NUMERIC
# pass
# ConflictAnalysis_propagation_Time NUMERIC
# pass
# ConflictAnalysis_propagation_Calls NUMERIC
# pass
# ConflictAnalysis_propagation_Success NUMERIC
# pass
# ConflictAnalysis_propagation_Conflicts NUMERIC
# pass
# ConflictAnalysis_propagation_Literals NUMERIC
# pass
# ConflictAnalysis_propagation_Reconvs NUMERIC
# pass
# ConflictAnalysis_propagation_ReconvLits NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Time NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Calls NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Success NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Conflicts NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Literals NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Reconvs NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_ReconvLits NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Dualrays NUMERIC
# pass
# ConflictAnalysis_infeasibleLP_Nonzeros NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Time NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Calls NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Success NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Conflicts NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Literals NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Reconvs NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_ReconvLits NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_Dualrays NUMERIC
# pass
# ConflictAnalysis_boundexceed.LP_LP NUMERIC
# pass
# ConflictAnalysis_pseudosolution_Calls NUMERIC
# pass
# ConflictAnalysis_appliedglobally_DomReds NUMERIC
# pass
# ConflictAnalysis_appliedglobally_Conflicts NUMERIC
# pass
# ConflictAnalysis_appliedglobally_Literals NUMERIC
# pass
# ConflictAnalysis_appliedglobally_Dualrays NUMERIC
# pass
# ConflictAnalysis_appliedlocally_Conflicts NUMERIC
# pass
# ConflictAnalysis_appliedlocally_Literals NUMERIC
# pass
# Separators_cutpool_ExecTime NUMERIC
# pass
# Separators_cutpool_Calls NUMERIC
# pass
# Separators_cutpool_FoundCuts NUMERIC
# pass
# Separators_cutpool_ViaPoolAdd NUMERIC
# pass
# Separators_aggregation_ExecTime NUMERIC
# pass
# Separators_aggregation_FoundCuts NUMERIC
# pass
# Separators_aggregation_ViaPoolAdd NUMERIC
# pass
# Separators_aggregation_Applied NUMERIC
# pass
# Separators_>cmir_ViaPoolAdd NUMERIC
# pass
# Separators_>cmir_Applied NUMERIC
# pass
# Separators_>flowcover_ViaPoolAdd NUMERIC
# pass
# Separators_>flowcover_Applied NUMERIC
# pass
# Separators_>knapsackcover_ViaPoolAdd NUMERIC
# pass
# Separators_>knapsackcover_Applied NUMERIC
# pass
# Separators_clique_FoundCuts NUMERIC
# pass
# Separators_clique_ViaPoolAdd NUMERIC
# pass
# Separators_clique_Applied NUMERIC
# pass
# Separators_gomory_ExecTime NUMERIC
# pass
# Separators_gomory_FoundCuts NUMERIC
# pass
# Separators_gomory_ViaPoolAdd NUMERIC
# pass
# Separators_gomory_Applied NUMERIC
# pass
# Separators_impliedbounds_FoundCuts NUMERIC
# pass
# Separators_impliedbounds_ViaPoolAdd NUMERIC
# pass
# Separators_impliedbounds_Applied NUMERIC
# pass
# Separators_mcf_ExecTime NUMERIC
# pass
# Separators_mixing_FoundCuts NUMERIC
# pass
# Separators_mixing_ViaPoolAdd NUMERIC
# pass
# Separators_mixing_Applied NUMERIC
# pass
# Separators_zerohalf_Calls NUMERIC
# pass
# Separators_zerohalf_FoundCuts NUMERIC
# pass
# Separators_zerohalf_ViaPoolAdd NUMERIC
# pass
# Cutselectors_hybrid_ExecTime NUMERIC
# pass
# Cutselectors_hybrid_Calls NUMERIC
# pass
# Cutselectors_hybrid_Selected NUMERIC
# pass
# Cutselectors_hybrid_Forced NUMERIC
# pass
# Cutselectors_hybrid_Filtered NUMERIC
# pass
# BranchingRules_relpscost_ExecTime NUMERIC
# pass
# BranchingRules_relpscost_BranchLP NUMERIC
# pass
# PrimalHeuristics_alns_ExecTime NUMERIC
# pass
# PrimalHeuristics_alns_Calls NUMERIC
# pass
# PrimalHeuristics_clique_1_ExecTime NUMERIC
# pass
# PrimalHeuristics_conflictdiving_ExecTime NUMERIC
# pass
# PrimalHeuristics_conflictdiving_Calls NUMERIC
# pass
# PrimalHeuristics_feaspump_ExecTime NUMERIC
# pass
# PrimalHeuristics_feaspump_Found NUMERIC
# pass
# PrimalHeuristics_intshifting_ExecTime NUMERIC
# pass
# PrimalHeuristics_intshifting_Calls NUMERIC
# pass
# PrimalHeuristics_locks_ExecTime NUMERIC
# pass
# PrimalHeuristics_oneopt_ExecTime NUMERIC
# pass
# PrimalHeuristics_oneopt_Calls NUMERIC
# pass
# PrimalHeuristics_randrounding_ExecTime NUMERIC
# pass
# PrimalHeuristics_randrounding_Calls NUMERIC
# pass
# PrimalHeuristics_rens_ExecTime NUMERIC
# pass
# PrimalHeuristics_rens_Calls NUMERIC
# pass
# PrimalHeuristics_rens_Found NUMERIC
# pass
# PrimalHeuristics_rounding_Calls NUMERIC
# pass
# PrimalHeuristics_shiftandpropagate_ExecTime NUMERIC
# pass
# PrimalHeuristics_shifting_ExecTime NUMERIC
# pass
# PrimalHeuristics_zirounding_Calls NUMERIC
# pass
# PrimalHeuristics_zirounding_Found NUMERIC
# pass
# LP_primalLP_Time NUMERIC
# pass
# LP_primalLP_Calls NUMERIC
# pass
# LP_primalLP_Iterations NUMERIC
# pass
# LP_primalLP_Iter/call NUMERIC
# pass
# LP_primalLP_Iter/sec NUMERIC
# pass
# LP_primalLP_Time-0-It NUMERIC
# pass
# LP_primalLP_Calls-0-It NUMERIC
# pass
# LP_dualLP_Time NUMERIC
# pass
# LP_dualLP_Calls NUMERIC
# pass
# LP_dualLP_Iterations NUMERIC
# pass
# LP_dualLP_Iter/call NUMERIC
# pass
# LP_dualLP_Iter/sec NUMERIC
# pass
# LP_dualLP_Time-0-It NUMERIC
# pass
# LP_dualLP_Calls-0-It NUMERIC
# pass
# LP_resolveinstable_Time NUMERIC
# pass
# LP_resolveinstable_Calls NUMERIC
# pass
# LP_resolveinstable_Iterations NUMERIC
# pass
# LP_resolveinstable_Iter/call NUMERIC
# pass
# LP_resolveinstable_Iter/sec NUMERIC
# pass
# LP_diving/probingLP_Time NUMERIC
# pass
# LP_diving/probingLP_Calls NUMERIC
# pass
# LP_diving/probingLP_Iterations NUMERIC
# pass
# LP_diving/probingLP_Iter/call NUMERIC
# pass
# LP_diving/probingLP_Iter/sec NUMERIC
# pass
# LP_strongbranching_2_Time NUMERIC
# pass
# LP_strongbranching_2_Calls NUMERIC
# pass
# LP_strongbranching_2_Iterations NUMERIC
# pass
# LP_strongbranching_2_Iter/call NUMERIC
# pass
# LP_strongbranching_2_Iter/sec NUMERIC
# pass
# LP_strongbranching_2_ItLimit NUMERIC
# pass
# LP_conflictanalysis_Time NUMERIC
# pass
# LP_conflictanalysis_Calls NUMERIC
# pass
# LP_conflictanalysis_Iter/call NUMERIC
# pass
# FirstLPIters_persecond NUMERIC
# pass
# Integrals_primal-dual_Total NUMERIC
# fail
# Integrals_primal-dual_Avg% NUMERIC

# %% [markdown]
# ### Create description.txt

# %%
for i in features_df.columns:
    if 'presolve_off' in i:
        print('- ' + i)

    else:
        pass
# Out:
# - VARS_presolve_off
# - BIN_VARS_presolve_off
# - CONT_VARS_presolve_off
# - PER_FINITE_UB_presolve_off
# - UPPERBOUNDS_MEAN_presolve_off
# - UPPERBOUNDS_MIN_presolve_off
# - UPPERBOUNDS_STD_presolve_off
# - LOWERBOUNDS_MEAN_presolve_off
# - LOWERBOUNDS_MIN_presolve_off
# - LOWERBOUNDS_MAX_presolve_off
# - LOWERBOUNDS_STD_presolve_off
# - LOWERBOUNDS_DENSITY_presolve_off
# - BOUNDRANGE_MEAN_presolve_off
# - BOUNDRANGE_MAX_presolve_off
# - BOUNDRANGE_STD_presolve_off
# - BOUNDRANGE_MEDIAN_presolve_off
# - OBJCOEFF_ALL_MEAN_presolve_off
# - OBJCOEFF_ALL_STD_presolve_off
# - OBJCOEFF_CONT_MEAN_presolve_off
# - CONSTR_presolve_off
# - LINSING_CONSTR_presolve_off
# - LINVARBD_CONSTR_presolve_off
# - LINMIXBIN_CONSTR_presolve_off
# - CONSTR_MEAN_presolve_off
# - CONSTR_MAX_presolve_off
# - CONSTR_STD_presolve_off
# - RH_CONSTR_MEAN_presolve_off
# - RH_CONSTR_MIN_presolve_off
# - RH_CONSTR_MAX_presolve_off
# - RH_CONSTR_STD_presolve_off
# - RH_CONSTR_DENSITY_presolve_off
# - LH_CONSTR_MEAN_presolve_off
# - LH_CONSTR_MIN_presolve_off
# - LH_CONSTR_STD_presolve_off
# - LH_CONSTR_DENSITY_presolve_off
# - RH_CONSTR_RATIO_presolve_off
# - LH_CONSTR_RATIO_presolve_off
# - NVAR_ALL_MEAN_presolve_off
# - NVAR_ALL_MAX_presolve_off
# - NVAR_ALL_STD_presolve_off
# - CONSTR_COEFF_MEAN_MEAN_presolve_off
# - CONSTR_COEFF_MEAN_MIN_presolve_off
# - CONSTR_COEFF_MEAN_STD_presolve_off
# - CONSTR_COEFF_MIN_MEAN_presolve_off
# - CONSTR_COEFF_MIN_STD_presolve_off
# - CONSTR_COEFF_MAX_MEAN_presolve_off
# - CONSTR_COEFF_MAX_MIN_presolve_off
# - CONSTR_COEFF_MAX_STD_presolve_off
# - CONSTR_COEFF_STD_MEAN_presolve_off
# - CONSTR_COEFF_STD_STD_presolve_off
# - CONSTR_COEFF_STD_MEDIAN_presolve_off
# - CONSTR_MATRIX_DENSITY_presolve_off
# - NONZEROES_presolve_off
# - CLIQUE_MEAN_presolve_off
# - CLIQUE_MIN_presolve_off
# - CLIQUE_MAX_presolve_off
# - CLIQUE_STD_presolve_off
# - DYNAMISM_MEAN_presolve_off
# - DYNAMISM_STD_presolve_off

# %%
for i in features_df.columns:
    if 'presolve_default' in i:
        print('- ' + i)

    else:
        pass
# Out:
# - VARS_presolve_default
# - BIN_VARS_presolve_default
# - CONT_VARS_presolve_default
# - UPPERBOUNDS_MEAN_presolve_default
# - UPPERBOUNDS_MIN_presolve_default
# - UPPERBOUNDS_MAX_presolve_default
# - UPPERBOUNDS_STD_presolve_default
# - UPPERBOUNDS_MEDIAN_presolve_default
# - UPPERBOUNDS_DENSITY_presolve_default
# - LOWERBOUNDS_MEAN_presolve_default
# - LOWERBOUNDS_MIN_presolve_default
# - LOWERBOUNDS_MAX_presolve_default
# - LOWERBOUNDS_STD_presolve_default
# - LOWERBOUNDS_DENSITY_presolve_default
# - BOUNDRANGE_MEAN_presolve_default
# - BOUNDRANGE_MIN_presolve_default
# - BOUNDRANGE_MAX_presolve_default
# - BOUNDRANGE_STD_presolve_default
# - BOUNDRANGE_MEDIAN_presolve_default
# - OBJCOEFF_ALL_MEAN_presolve_default
# - OBJCOEFF_ALL_STD_presolve_default
# - OBJCOEFF_CONT_MEAN_presolve_default
# - OBJCOEFF_CONT_STD_presolve_default
# - CONSTR_presolve_default
# - LINSING_CONSTR_presolve_default
# - LINPREC_CONSTR_presolve_default
# - LINVARBD_CONSTR_presolve_default
# - LINMIXBIN_CONSTR_presolve_default
# - CONSTR_MEAN_presolve_default
# - CONSTR_MAX_presolve_default
# - CONSTR_STD_presolve_default
# - RH_CONSTR_MEAN_presolve_default
# - RH_CONSTR_MAX_presolve_default
# - RH_CONSTR_STD_presolve_default
# - RH_CONSTR_DENSITY_presolve_default
# - LH_CONSTR_MEAN_presolve_default
# - LH_CONSTR_MIN_presolve_default
# - LH_CONSTR_MAX_presolve_default
# - LH_CONSTR_STD_presolve_default
# - LH_CONSTR_MEDIAN_presolve_default
# - RH_CONSTR_RATIO_presolve_default
# - LH_CONSTR_RATIO_presolve_default
# - NVAR_ALL_MEAN_presolve_default
# - NVAR_ALL_MIN_presolve_default
# - NVAR_ALL_STD_presolve_default
# - CONSTR_COEFF_MEAN_MEAN_presolve_default
# - CONSTR_COEFF_MEAN_STD_presolve_default
# - CONSTR_COEFF_MIN_MEAN_presolve_default
# - CONSTR_COEFF_MIN_STD_presolve_default
# - CONSTR_COEFF_MAX_MEAN_presolve_default
# - CONSTR_COEFF_MAX_STD_presolve_default
# - CONSTR_COEFF_STD_MEAN_presolve_default
# - CONSTR_COEFF_STD_STD_presolve_default
# - CONSTR_COEFF_STD_MEDIAN_presolve_default
# - CONSTR_MATRIX_DENSITY_presolve_default
# - NONZEROES_presolve_default
# - CLIQUE_MEAN_presolve_default
# - CLIQUE_MIN_presolve_default
# - CLIQUE_MAX_presolve_default
# - CLIQUE_STD_presolve_default
# - DYNAMISM_MEAN_presolve_default
# - DYNAMISM_MAX_presolve_default
# - DYNAMISM_STD_presolve_default
# - DYNAMISM_MEDIAN_presolve_default

# %%
for i in features_df.columns:
    print('- ' + i)
# Out:
# - repetition
# - instance_id
# - VARS_presolve_default
# - BIN_VARS_presolve_default
# - CONT_VARS_presolve_default
# - UPPERBOUNDS_MEAN_presolve_default
# - UPPERBOUNDS_MIN_presolve_default
# - UPPERBOUNDS_MAX_presolve_default
# - UPPERBOUNDS_STD_presolve_default
# - UPPERBOUNDS_MEDIAN_presolve_default
# - UPPERBOUNDS_DENSITY_presolve_default
# - LOWERBOUNDS_MEAN_presolve_default
# - LOWERBOUNDS_MIN_presolve_default
# - LOWERBOUNDS_MAX_presolve_default
# - LOWERBOUNDS_STD_presolve_default
# - LOWERBOUNDS_DENSITY_presolve_default
# - BOUNDRANGE_MEAN_presolve_default
# - BOUNDRANGE_MIN_presolve_default
# - BOUNDRANGE_MAX_presolve_default
# - BOUNDRANGE_STD_presolve_default
# - BOUNDRANGE_MEDIAN_presolve_default
# - OBJCOEFF_ALL_MEAN_presolve_default
# - OBJCOEFF_ALL_STD_presolve_default
# - OBJCOEFF_CONT_MEAN_presolve_default
# - OBJCOEFF_CONT_STD_presolve_default
# - CONSTR_presolve_default
# - LINSING_CONSTR_presolve_default
# - LINPREC_CONSTR_presolve_default
# - LINVARBD_CONSTR_presolve_default
# - LINMIXBIN_CONSTR_presolve_default
# - CONSTR_MEAN_presolve_default
# - CONSTR_MAX_presolve_default
# - CONSTR_STD_presolve_default
# - RH_CONSTR_MEAN_presolve_default
# - RH_CONSTR_MAX_presolve_default
# - RH_CONSTR_STD_presolve_default
# - RH_CONSTR_DENSITY_presolve_default
# - LH_CONSTR_MEAN_presolve_default
# - LH_CONSTR_MIN_presolve_default
# - LH_CONSTR_MAX_presolve_default
# - LH_CONSTR_STD_presolve_default
# - LH_CONSTR_MEDIAN_presolve_default
# - RH_CONSTR_RATIO_presolve_default
# - LH_CONSTR_RATIO_presolve_default
# - NVAR_ALL_MEAN_presolve_default
# - NVAR_ALL_MIN_presolve_default
# - NVAR_ALL_STD_presolve_default
# - CONSTR_COEFF_MEAN_MEAN_presolve_default
# - CONSTR_COEFF_MEAN_STD_presolve_default
# - CONSTR_COEFF_MIN_MEAN_presolve_default
# - CONSTR_COEFF_MIN_STD_presolve_default
# - CONSTR_COEFF_MAX_MEAN_presolve_default
# - CONSTR_COEFF_MAX_STD_presolve_default
# - CONSTR_COEFF_STD_MEAN_presolve_default
# - CONSTR_COEFF_STD_STD_presolve_default
# - CONSTR_COEFF_STD_MEDIAN_presolve_default
# - CONSTR_MATRIX_DENSITY_presolve_default
# - NONZEROES_presolve_default
# - CLIQUE_MEAN_presolve_default
# - CLIQUE_MIN_presolve_default
# - CLIQUE_MAX_presolve_default
# - CLIQUE_STD_presolve_default
# - DYNAMISM_MEAN_presolve_default
# - DYNAMISM_MAX_presolve_default
# - DYNAMISM_STD_presolve_default
# - DYNAMISM_MEDIAN_presolve_default
# - VARS_presolve_off
# - BIN_VARS_presolve_off
# - CONT_VARS_presolve_off
# - PER_FINITE_UB_presolve_off
# - UPPERBOUNDS_MEAN_presolve_off
# - UPPERBOUNDS_MIN_presolve_off
# - UPPERBOUNDS_STD_presolve_off
# - LOWERBOUNDS_MEAN_presolve_off
# - LOWERBOUNDS_MIN_presolve_off
# - LOWERBOUNDS_MAX_presolve_off
# - LOWERBOUNDS_STD_presolve_off
# - LOWERBOUNDS_DENSITY_presolve_off
# - BOUNDRANGE_MEAN_presolve_off
# - BOUNDRANGE_MAX_presolve_off
# - BOUNDRANGE_STD_presolve_off
# - BOUNDRANGE_MEDIAN_presolve_off
# - OBJCOEFF_ALL_MEAN_presolve_off
# - OBJCOEFF_ALL_STD_presolve_off
# - OBJCOEFF_CONT_MEAN_presolve_off
# - CONSTR_presolve_off
# - LINSING_CONSTR_presolve_off
# - LINVARBD_CONSTR_presolve_off
# - LINMIXBIN_CONSTR_presolve_off
# - CONSTR_MEAN_presolve_off
# - CONSTR_MAX_presolve_off
# - CONSTR_STD_presolve_off
# - RH_CONSTR_MEAN_presolve_off
# - RH_CONSTR_MIN_presolve_off
# - RH_CONSTR_MAX_presolve_off
# - RH_CONSTR_STD_presolve_off
# - RH_CONSTR_DENSITY_presolve_off
# - LH_CONSTR_MEAN_presolve_off
# - LH_CONSTR_MIN_presolve_off
# - LH_CONSTR_STD_presolve_off
# - LH_CONSTR_DENSITY_presolve_off
# - RH_CONSTR_RATIO_presolve_off
# - LH_CONSTR_RATIO_presolve_off
# - NVAR_ALL_MEAN_presolve_off
# - NVAR_ALL_MAX_presolve_off
# - NVAR_ALL_STD_presolve_off
# - CONSTR_COEFF_MEAN_MEAN_presolve_off
# - CONSTR_COEFF_MEAN_MIN_presolve_off
# - CONSTR_COEFF_MEAN_STD_presolve_off
# - CONSTR_COEFF_MIN_MEAN_presolve_off
# - CONSTR_COEFF_MIN_STD_presolve_off
# - CONSTR_COEFF_MAX_MEAN_presolve_off
# - CONSTR_COEFF_MAX_MIN_presolve_off
# - CONSTR_COEFF_MAX_STD_presolve_off
# - CONSTR_COEFF_STD_MEAN_presolve_off
# - CONSTR_COEFF_STD_STD_presolve_off
# - CONSTR_COEFF_STD_MEDIAN_presolve_off
# - CONSTR_MATRIX_DENSITY_presolve_off
# - NONZEROES_presolve_off
# - CLIQUE_MEAN_presolve_off
# - CLIQUE_MIN_presolve_off
# - CLIQUE_MAX_presolve_off
# - CLIQUE_STD_presolve_off
# - DYNAMISM_MEAN_presolve_off
# - DYNAMISM_STD_presolve_off
# - solvingtime
# - readingtime
# - copyingtime
# - PresolvedProblem_Variables
# - feasibleleaves
# - objectiveleaves
# - nodesleft
# - avgswitchlength
# - FirstLPIters
# - FirstLPTime
# - FinalDualBound
# - FinalRootIters
# - RootLPEstimate
# - Solutionsfound
# - PrimalBound
# - Gap
# - FirstSolution
# - GapFirstSol.
# - GapLastSol.
# - PresolvedProblem_Variables_Binary
# - PresolvedProblem_Variables_Continuous
# - PresolvedProblem_Constraints_initial
# - PresolvedProblem_Constraints_maximal
# - PresolvedProblem_Nonzeros_constraint
# - PresolvedProblem_Nonzeros_clique
# - Presolvers_domcol_ExecTime
# - Presolvers_domcol_Calls
# - Presolvers_dualcomp_ExecTime
# - Presolvers_dualsparsify_ExecTime
# - Presolvers_dualsparsify_DelCons
# - Presolvers_implics_Calls
# - Presolvers_milp_ExecTime
# - Presolvers_milp_Calls
# - Presolvers_milp_FixedVars
# - Presolvers_milp_ChgBounds
# - Presolvers_sparsify_ExecTime
# - Presolvers_trivial_Calls
# - Presolvers_probing_ExecTime
# - Presolvers_probing_FixedVars
# - Presolvers_symmetry_ExecTime
# - Presolvers_vbounds_Calls
# - Presolvers_varbound_Calls
# - Presolvers_varbound_DelCons
# - Presolvers_setppc_Calls
# - Presolvers_linear_ExecTime
# - Presolvers_linear_SetupTime
# - Presolvers_linear_Calls
# - Presolvers_linear_ChgBounds
# - Presolvers_linear_DelCons
# - Presolvers_linear_ChgSides
# - Presolvers_components_ExecTime
# - Presolvers_rootnode_FixedVars
# - Presolvers_rootnode_ChgBounds
# - Constraints_benderslp_#EnfoLP
# - Constraints_benderslp_#Check
# - Constraints_integral_DomReds
# - Constraints_integral_Conss
# - Constraints_varbound_1_Number
# - Constraints_varbound_1_MaxNumber
# - Constraints_varbound_1_#Separate
# - Constraints_varbound_1_#Propagate
# - Constraints_varbound_1_#Check
# - Constraints_varbound_1_#ResProp
# - Constraints_varbound_1_Cutoffs
# - Constraints_varbound_1_DomReds
# - Constraints_setppc_1_MaxNumber
# - Constraints_setppc_1_#Separate
# - Constraints_setppc_1_#Propagate
# - Constraints_setppc_1_#Check
# - Constraints_setppc_1_#ResProp
# - Constraints_setppc_1_Cutoffs
# - Constraints_setppc_1_DomReds
# - Constraints_setppc_1_Cuts
# - Constraints_setppc_1_Applied
# - Constraints_linear_1_Number
# - Constraints_linear_1_MaxNumber
# - Constraints_linear_1_#Propagate
# - Constraints_linear_1_#Check
# - Constraints_linear_1_#ResProp
# - Constraints_linear_1_Cutoffs
# - Constraints_linear_1_DomReds
# - Constraints_logicor_1_MaxNumber
# - Constraints_logicor_1_#Separate
# - Constraints_logicor_1_#Propagate
# - Constraints_logicor_1_#ResProp
# - Constraints_logicor_1_Cutoffs
# - Constraints_logicor_1_Cuts
# - Constraints_logicor_1_Applied
# - Constraints_benders_1_#Check
# - ConstraintTimings_integral_1_TotalTime
# - ConstraintTimings_integral_1_EnfoLP
# - ConstraintTimings_varbound_2_TotalTime
# - ConstraintTimings_varbound_2_Separate
# - ConstraintTimings_varbound_2_Propagate
# - ConstraintTimings_varbound_2_ResProp
# - ConstraintTimings_setppc_2_TotalTime
# - ConstraintTimings_setppc_2_Propagate
# - ConstraintTimings_linear_2_TotalTime
# - ConstraintTimings_linear_2_Separate
# - ConstraintTimings_linear_2_Propagate
# - ConstraintTimings_linear_2_Check
# - ConstraintTimings_linear_2_ResProp
# - ConstraintTimings_linear_2_SB-Prop
# - Propagators_dualfix_1_#Propagate
# - Propagators_pseudoobj_1_#Propagate
# - Propagators_pseudoobj_1_DomReds
# - Propagators_redcost_#Propagate
# - Propagators_vbounds_1_#Propagate
# - PropagatorTimings_probing_2_TotalTime
# - PropagatorTimings_symmetry_2_TotalTime
# - ConflictAnalysis_propagation_Time
# - ConflictAnalysis_propagation_Calls
# - ConflictAnalysis_propagation_Success
# - ConflictAnalysis_propagation_Conflicts
# - ConflictAnalysis_propagation_Literals
# - ConflictAnalysis_propagation_Reconvs
# - ConflictAnalysis_propagation_ReconvLits
# - ConflictAnalysis_infeasibleLP_Time
# - ConflictAnalysis_infeasibleLP_Calls
# - ConflictAnalysis_infeasibleLP_Success
# - ConflictAnalysis_infeasibleLP_Conflicts
# - ConflictAnalysis_infeasibleLP_Literals
# - ConflictAnalysis_infeasibleLP_Reconvs
# - ConflictAnalysis_infeasibleLP_ReconvLits
# - ConflictAnalysis_infeasibleLP_Dualrays
# - ConflictAnalysis_infeasibleLP_Nonzeros
# - ConflictAnalysis_boundexceed.LP_Time
# - ConflictAnalysis_boundexceed.LP_Calls
# - ConflictAnalysis_boundexceed.LP_Success
# - ConflictAnalysis_boundexceed.LP_Conflicts
# - ConflictAnalysis_boundexceed.LP_Literals
# - ConflictAnalysis_boundexceed.LP_Reconvs
# - ConflictAnalysis_boundexceed.LP_ReconvLits
# - ConflictAnalysis_boundexceed.LP_Dualrays
# - ConflictAnalysis_boundexceed.LP_LP
# - ConflictAnalysis_pseudosolution_Calls
# - ConflictAnalysis_appliedglobally_DomReds
# - ConflictAnalysis_appliedglobally_Conflicts
# - ConflictAnalysis_appliedglobally_Literals
# - ConflictAnalysis_appliedglobally_Dualrays
# - ConflictAnalysis_appliedlocally_Conflicts
# - ConflictAnalysis_appliedlocally_Literals
# - Separators_cutpool_ExecTime
# - Separators_cutpool_Calls
# - Separators_cutpool_FoundCuts
# - Separators_cutpool_ViaPoolAdd
# - Separators_aggregation_ExecTime
# - Separators_aggregation_FoundCuts
# - Separators_aggregation_ViaPoolAdd
# - Separators_aggregation_Applied
# - Separators_>cmir_ViaPoolAdd
# - Separators_>cmir_Applied
# - Separators_>flowcover_ViaPoolAdd
# - Separators_>flowcover_Applied
# - Separators_>knapsackcover_ViaPoolAdd
# - Separators_>knapsackcover_Applied
# - Separators_clique_FoundCuts
# - Separators_clique_ViaPoolAdd
# - Separators_clique_Applied
# - Separators_gomory_ExecTime
# - Separators_gomory_FoundCuts
# - Separators_gomory_ViaPoolAdd
# - Separators_gomory_Applied
# - Separators_impliedbounds_FoundCuts
# - Separators_impliedbounds_ViaPoolAdd
# - Separators_impliedbounds_Applied
# - Separators_mcf_ExecTime
# - Separators_mixing_FoundCuts
# - Separators_mixing_ViaPoolAdd
# - Separators_mixing_Applied
# - Separators_zerohalf_Calls
# - Separators_zerohalf_FoundCuts
# - Separators_zerohalf_ViaPoolAdd
# - Cutselectors_hybrid_ExecTime
# - Cutselectors_hybrid_Calls
# - Cutselectors_hybrid_Selected
# - Cutselectors_hybrid_Forced
# - Cutselectors_hybrid_Filtered
# - BranchingRules_relpscost_ExecTime
# - BranchingRules_relpscost_BranchLP
# - PrimalHeuristics_alns_ExecTime
# - PrimalHeuristics_alns_Calls
# - PrimalHeuristics_clique_1_ExecTime
# - PrimalHeuristics_conflictdiving_ExecTime
# - PrimalHeuristics_conflictdiving_Calls
# - PrimalHeuristics_feaspump_ExecTime
# - PrimalHeuristics_feaspump_Found
# - PrimalHeuristics_intshifting_ExecTime
# - PrimalHeuristics_intshifting_Calls
# - PrimalHeuristics_locks_ExecTime
# - PrimalHeuristics_oneopt_ExecTime
# - PrimalHeuristics_oneopt_Calls
# - PrimalHeuristics_randrounding_ExecTime
# - PrimalHeuristics_randrounding_Calls
# - PrimalHeuristics_rens_ExecTime
# - PrimalHeuristics_rens_Calls
# - PrimalHeuristics_rens_Found
# - PrimalHeuristics_rounding_Calls
# - PrimalHeuristics_shiftandpropagate_ExecTime
# - PrimalHeuristics_shifting_ExecTime
# - PrimalHeuristics_zirounding_Calls
# - PrimalHeuristics_zirounding_Found
# - LP_primalLP_Time
# - LP_primalLP_Calls
# - LP_primalLP_Iterations
# - LP_primalLP_Iter/call
# - LP_primalLP_Iter/sec
# - LP_primalLP_Time-0-It
# - LP_primalLP_Calls-0-It
# - LP_dualLP_Time
# - LP_dualLP_Calls
# - LP_dualLP_Iterations
# - LP_dualLP_Iter/call
# - LP_dualLP_Iter/sec
# - LP_dualLP_Time-0-It
# - LP_dualLP_Calls-0-It
# - LP_resolveinstable_Time
# - LP_resolveinstable_Calls
# - LP_resolveinstable_Iterations
# - LP_resolveinstable_Iter/call
# - LP_resolveinstable_Iter/sec
# - LP_diving/probingLP_Time
# - LP_diving/probingLP_Calls
# - LP_diving/probingLP_Iterations
# - LP_diving/probingLP_Iter/call
# - LP_diving/probingLP_Iter/sec
# - LP_strongbranching_2_Time
# - LP_strongbranching_2_Calls
# - LP_strongbranching_2_Iterations
# - LP_strongbranching_2_Iter/call
# - LP_strongbranching_2_Iter/sec
# - LP_strongbranching_2_ItLimit
# - LP_conflictanalysis_Time
# - LP_conflictanalysis_Calls
# - LP_conflictanalysis_Iter/call
# - FirstLPIters_persecond
# - Integrals_primal-dual_Total
# - Integrals_primal-dual_Avg%

# %% [markdown]
# ### Make the feature_runstatus.arff file

# %%
runstatus_df = pd.DataFrame({'instance_id': id_order,'repetition':[1]*10000, 'StaticOn':['ok']*10000, 
                             'StaticOff':['ok']*10000,'Dynamic':['ok']*10000})

runstatus_df
# Out:
#      instance_id  repetition StaticOn StaticOff Dynamic
# 0           mip1           1       ok        ok      ok
# 1          mip10           1       ok        ok      ok
# 2         mip100           1       ok        ok      ok
# 3        mip1000           1       ok        ok      ok
# 4       mip10000           1       ok        ok      ok
# ...          ...         ...      ...       ...     ...
# 9995     mip9995           1       ok        ok      ok
# 9996     mip9996           1       ok        ok      ok
# 9997     mip9997           1       ok        ok      ok
# 9998     mip9998           1       ok        ok      ok
# 9999     mip9999           1       ok        ok      ok
#
# [10000 rows x 5 columns]

# %%
with open("MIPVerifySDP_SCIPfeatureset/feature_runstatus.arff","a") as file:
    for index,row in runstatus_df.iterrows():
        file.write("\n")
        newrow = str(list(row)).strip("[]").replace("'", "")
        file.write(newrow)

    file.close()

# %% [markdown]
# ### Now make feature_costs.arff file

# %%
costs_df = pd.DataFrame({'instance_id': id_order, 'repetition':[1]*10000})

costs_df
# Out:
#      instance_id  repetition
# 0           mip1           1
# 1          mip10           1
# 2         mip100           1
# 3        mip1000           1
# 4       mip10000           1
# ...          ...         ...
# 9995     mip9995           1
# 9996     mip9996           1
# 9997     mip9997           1
# 9998     mip9998           1
# 9999     mip9999           1
#
# [10000 rows x 2 columns]

# %%
costs_df = pd.concat([costs_df,timing_df['presolvingtime']],axis=1)
costs_df['time_StaticOff'] = 0
costs_df
# Out:
#      instance_id  repetition  presolvingtime  time_StaticOff
# 0           mip1           1            1.47               0
# 1          mip10           1            1.31               0
# 2         mip100           1            1.40               0
# 3        mip1000           1            2.53               0
# 4       mip10000           1            1.94               0
# ...          ...         ...             ...             ...
# 9995     mip9995           1            1.18               0
# 9996     mip9996           1            1.08               0
# 9997     mip9997           1            1.27               0
# 9998     mip9998           1            1.44               0
# 9999     mip9999           1            1.19               0
#
# [10000 rows x 4 columns]

# %%
costs_df['time_dynamic'] = timing_df['TotalTime'] - timing_df['presolvingtime']
costs_df
# Out:
#      instance_id  repetition  presolvingtime  time_StaticOff  time_dynamic
# 0           mip1           1            1.47               0         21.27
# 1          mip10           1            1.31               0         18.36
# 2         mip100           1            1.40               0         30.25
# 3        mip1000           1            2.53               0         36.11
# 4       mip10000           1            1.94               0         14.92
# ...          ...         ...             ...             ...           ...
# 9995     mip9995           1            1.18               0         10.49
# 9996     mip9996           1            1.08               0          9.76
# 9997     mip9997           1            1.27               0         11.44
# 9998     mip9998           1            1.44               0         18.30
# 9999     mip9999           1            1.19               0         16.67
#
# [10000 rows x 5 columns]

# %%
with open("MIPVerifySDP_SCIPfeatureset/feature_costs.arff","a") as file:
    for index,row in costs_df.iterrows():
        file.write("\n")
        newrow = str(list(row)).strip("[]").replace("'", "")
        file.write(newrow)

    file.close()

# %% [markdown]
# ### Next step is creating algorithm_runs.arff

# %%
runtimes = pd.read_excel('C:/Users/Jasmin/Documents/MSc-Thesis/Data/Runtime/Results-MIPVerify_SDPdMLPa.xlsx')
runtimes
# Out:
#       SampleNumber  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0                1         104.393417  InfeasibleOrUnbounded       152.683291
# 1                2        9600.323414              UserLimit      9600.080699
# 2                3        9600.157577              UserLimit      1258.149140
# 3                4          83.344657  InfeasibleOrUnbounded       170.613330
# 4                5        5567.992290  InfeasibleOrUnbounded       220.795008
# ...            ...                ...                    ...              ...
# 9995          9996          12.674720  InfeasibleOrUnbounded     18608.097787
# 9996          9997          18.379950  InfeasibleOrUnbounded       110.131027
# 9997          9998          75.684641  InfeasibleOrUnbounded       105.670172
# 9998          9999        1669.967257  InfeasibleOrUnbounded       826.113838
# 9999         10000          22.112561  InfeasibleOrUnbounded       378.362607
#
#           SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  \
# 0     InfeasibleOrUnbounded        44.068493        Infeasible
# 1                 UserLimit      9600.184597         UserLimit
# 2     InfeasibleOrUnbounded      3025.400426        Infeasible
# 3     InfeasibleOrUnbounded        54.733004        Infeasible
# 4     InfeasibleOrUnbounded       538.053177        Infeasible
# ...                     ...              ...               ...
# 9995              UserLimit        25.863838        Infeasible
# 9996  InfeasibleOrUnbounded        50.209194        Infeasible
# 9997  InfeasibleOrUnbounded       106.346014        Infeasible
# 9998  InfeasibleOrUnbounded      1401.266455        Infeasible
# 9999  InfeasibleOrUnbounded        78.919991        Infeasible
#
#       SolveTime_conf3 SolveStatus_conf3  SolveTime_best        Config_best
# 0           78.731996        Infeasible       44.068493    SolveTime_conf2
# 1         9600.010288         UserLimit     9600.010288            TIMEOUT
# 2         2938.074613        Infeasible     1258.149140    SolveTime_conf1
# 3           41.134581        Infeasible       41.134581    SolveTime_conf3
# 4          300.046997        Infeasible      220.795008    SolveTime_conf1
# ...               ...               ...             ...                ...
# 9995       172.116870        Infeasible       12.674720  SolveTime_default
# 9996       110.876559        Infeasible       18.379950  SolveTime_default
# 9997       102.811690        Infeasible       75.684641  SolveTime_default
# 9998      1643.462584        Infeasible      826.113838    SolveTime_conf1
# 9999        18.838446        Infeasible       18.838446    SolveTime_conf3
#
# [10000 rows x 11 columns]

# %%
runtimes.rename(columns={'SampleNumber':'instance_id'},inplace=True)

# %%
runtimes['instance_id'] = 'mip' + runtimes['instance_id'].astype('str')
runtimes.head()
# Out:
#   instance_id  SolveTime_default    SolveStatus_default  SolveTime_conf1  \
# 0        mip1         104.393417  InfeasibleOrUnbounded       152.683291
# 1        mip2        9600.323414              UserLimit      9600.080699
# 2        mip3        9600.157577              UserLimit      1258.149140
# 3        mip4          83.344657  InfeasibleOrUnbounded       170.613330
# 4        mip5        5567.992290  InfeasibleOrUnbounded       220.795008
#
#        SolveStatus_conf1  SolveTime_conf2 SolveStatus_conf2  SolveTime_conf3  \
# 0  InfeasibleOrUnbounded        44.068493        Infeasible        78.731996
# 1              UserLimit      9600.184597         UserLimit      9600.010288
# 2  InfeasibleOrUnbounded      3025.400426        Infeasible      2938.074613
# 3  InfeasibleOrUnbounded        54.733004        Infeasible        41.134581
# 4  InfeasibleOrUnbounded       538.053177        Infeasible       300.046997
#
#   SolveStatus_conf3  SolveTime_best      Config_best
# 0        Infeasible       44.068493  SolveTime_conf2
# 1         UserLimit     9600.010288          TIMEOUT
# 2        Infeasible     1258.149140  SolveTime_conf1
# 3        Infeasible       41.134581  SolveTime_conf3
# 4        Infeasible      220.795008  SolveTime_conf1

# %%
runtimes = runtimes.drop(columns=['Config_best','SolveTime_best','SolveStatus_default','SolveStatus_conf1','SolveStatus_conf2','SolveStatus_conf3'])
runtimes.head()
# Out:
#   instance_id  SolveTime_default  SolveTime_conf1  SolveTime_conf2  \
# 0        mip1         104.393417       152.683291        44.068493
# 1        mip2        9600.323414      9600.080699      9600.184597
# 2        mip3        9600.157577      1258.149140      3025.400426
# 3        mip4          83.344657       170.613330        54.733004
# 4        mip5        5567.992290       220.795008       538.053177
#
#    SolveTime_conf3
# 0        78.731996
# 1      9600.010288
# 2      2938.074613
# 3        41.134581
# 4       300.046997

# %%
runtimes['SolveTime_default'][runtimes['SolveTime_default'] >= 9600] = 9600
runtimes['SolveTime_conf1'][runtimes['SolveTime_conf1'] >= 9600] = 9600
runtimes['SolveTime_conf2'][runtimes['SolveTime_conf2'] >= 9600] = 9600
runtimes['SolveTime_conf3'][runtimes['SolveTime_conf3'] >= 9600] = 9600
runtimes.head()
# Out:
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_1580\3673047457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runtimes['SolveTime_default'][runtimes['SolveTime_default'] >= 9600] = 9600
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_1580\3673047457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runtimes['SolveTime_conf1'][runtimes['SolveTime_conf1'] >= 9600] = 9600
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_1580\3673047457.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runtimes['SolveTime_conf2'][runtimes['SolveTime_conf2'] >= 9600] = 9600
# C:\Users\Jasmin\AppData\Local\Temp\ipykernel_1580\3673047457.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runtimes['SolveTime_conf3'][runtimes['SolveTime_conf3'] >= 9600] = 9600
#   instance_id  SolveTime_default  SolveTime_conf1  SolveTime_conf2  \
# 0        mip1         104.393417       152.683291        44.068493
# 1        mip2        9600.000000      9600.000000      9600.000000
# 2        mip3        9600.000000      1258.149140      3025.400426
# 3        mip4          83.344657       170.613330        54.733004
# 4        mip5        5567.992290       220.795008       538.053177
#
#    SolveTime_conf3
# 0        78.731996
# 1      9600.000000
# 2      2938.074613
# 3        41.134581
# 4       300.046997

# %%
runtimes.sort_values(by='instance_id', inplace=True)
runtimes.head()
# Out:
#      instance_id  SolveTime_default  SolveTime_conf1  SolveTime_conf2  \
# 0           mip1         104.393417       152.683291        44.068493
# 9          mip10        9600.000000      9600.000000      9600.000000
# 99        mip100          89.865928       779.582903        80.580781
# 999      mip1000        9600.000000      9600.000000      9600.000000
# 9999    mip10000          22.112561       378.362607        78.919991
#
#       SolveTime_conf3
# 0           78.731996
# 9         9600.000000
# 99         215.399513
# 999       9600.000000
# 9999        18.838446

# %%
new_runtime = runtimes.stack().reset_index()
new_runtime
# Out:
#        level_0            level_1            0
# 0            0        instance_id         mip1
# 1            0  SolveTime_default   104.393417
# 2            0    SolveTime_conf1   152.683291
# 3            0    SolveTime_conf2    44.068493
# 4            0    SolveTime_conf3    78.731996
# ...        ...                ...          ...
# 49995     9998        instance_id      mip9999
# 49996     9998  SolveTime_default  1669.967257
# 49997     9998    SolveTime_conf1   826.113838
# 49998     9998    SolveTime_conf2  1401.266455
# 49999     9998    SolveTime_conf3  1643.462584
#
# [50000 rows x 3 columns]

# %%
temp = {'instance_id':[], 'repetition':[1]*10000*4, 'algorithm':[],'par10':[],'runstatus':[]}
for index,row in new_runtime.iterrows():
    if row['level_1'] == 'instance_id':
        temp['instance_id'].append(row[0])
        temp['instance_id'].append(row[0])
        temp['instance_id'].append(row[0])
        temp['instance_id'].append(row[0])

    else:
        temp['algorithm'].append(row['level_1'])
        temp['par10'].append(row[0])
        if row[0] == 9600:
            temp['runstatus'].append('timeout')
        else:
            temp['runstatus'].append('ok')

# %%
algo_runs_df = pd.DataFrame(temp)
algo_runs_df
# Out:
#       instance_id  repetition          algorithm        par10 runstatus
# 0            mip1           1  SolveTime_default   104.393417        ok
# 1            mip1           1    SolveTime_conf1   152.683291        ok
# 2            mip1           1    SolveTime_conf2    44.068493        ok
# 3            mip1           1    SolveTime_conf3    78.731996        ok
# 4           mip10           1  SolveTime_default  9600.000000   timeout
# ...           ...         ...                ...          ...       ...
# 39995     mip9998           1    SolveTime_conf3   102.811690        ok
# 39996     mip9999           1  SolveTime_default  1669.967257        ok
# 39997     mip9999           1    SolveTime_conf1   826.113838        ok
# 39998     mip9999           1    SolveTime_conf2  1401.266455        ok
# 39999     mip9999           1    SolveTime_conf3  1643.462584        ok
#
# [40000 rows x 5 columns]

# %%
algo_runs_df.loc[algo_runs_df["algorithm"] == "SolveTime_default", "algorithm"] = 'ConfigDefault'

# %%
algo_runs_df.loc[algo_runs_df["algorithm"] == "SolveTime_conf1", "algorithm"] = 'Config1'
algo_runs_df.loc[algo_runs_df["algorithm"] == "SolveTime_conf2", "algorithm"] = 'Config2'
algo_runs_df.loc[algo_runs_df["algorithm"] == "SolveTime_conf3", "algorithm"] = 'Config3'
algo_runs_df.head()
# Out:
#   instance_id  repetition      algorithm        par10 runstatus
# 0        mip1           1  ConfigDefault   104.393417        ok
# 1        mip1           1        Config1   152.683291        ok
# 2        mip1           1        Config2    44.068493        ok
# 3        mip1           1        Config3    78.731996        ok
# 4       mip10           1  ConfigDefault  9600.000000   timeout

# %%
with open("MIPVerifySDP_SCIPfeatureset/algorithm_runs.arff","a") as file:
    for index,row in algo_runs_df.iterrows():
        file.write("\n")
        newrow = str(list(row)).strip("[]").replace("'", "")
        file.write(newrow)

    file.close()

# %% [markdown]
# ### Last one.... make cv.arff

# %%
import random

# %%
# This script specifies which instances are in which of the 10 folds for 10-fold cross validation
folds_df = pd.DataFrame({'instance_id': id_order, 'repetition':[1]*10000})
folds_df
# Out:
#      instance_id  repetition
# 0           mip1           1
# 1          mip10           1
# 2         mip100           1
# 3        mip1000           1
# 4       mip10000           1
# ...          ...         ...
# 9995     mip9995           1
# 9996     mip9996           1
# 9997     mip9997           1
# 9998     mip9998           1
# 9999     mip9999           1
#
# [10000 rows x 2 columns]

# %%
# Make a list of length 10000 and randomly replace 0's with numbers from 1 to 10 (each number uses up 10% of the list)
fold_list = []
fold_num = 10

for x in range(1,fold_num+1):
    for _ in range(1000):
        fold_list.append(x)


random.seed(1234)
random.shuffle(fold_list)
print(fold_list)
# Check that the lengths are correct
for i in range(1,fold_num+1):
    print(fold_list.count(i))


folds_df['fold'] = fold_list
folds_df.head()
# Out:
# [2, 3, 9, 4, 5, 6, 10, 3, 8, 8, 7, 4, 3, 3, 2, 2, 2, 9, 6, 6, 5, 9, 9, 6, 8, 4, 6, 1, 1, 5, 9, 7, 9, 9, 10, 6, 3, 8, 6, 6, 1, 7, 7, 9, 4, 2, 7, 3, 3, 8, 7, 6, 6, 5, 10, 7, 1, 5, 8, 5, 8, 6, 8, 9, 7, 8, 1, 10, 1, 9, 3, 1, 3, 5, 8, 10, 6, 4, 10, 2, 1, 10, 9, 8, 1, 1, 2, 9, 5, 6, 10, 3, 6, 9, 8, 10, 8, 1, 6, 2, 2, 7, 2, 6, 6, 10, 3, 5, 5, 6, 10, 3, 8, 5, 3, 2, 10, 4, 8, 2, 8, 5, 2, 3, 2, 5, 10, 10, 6, 5, 4, 4, 4, 3, 7, 10, 3, 5, 8, 8, 7, 7, 5, 3, 6, 4, 3, 1, 2, 7, 2, 8, 8, 6, 2, 8, 9, 4, 9, 6, 9, 6, 2, 10, 6, 2, 9, 3, 6, 2, 1, 8, 9, 4, 9, 3, 4, 2, 6, 10, 10, 3, 3, 8, 9, 8, 5, 10, 9, 7, 4, 8, 10, 10, 10, 6, 10, 8, 6, 10, 8, 7, 4, 3, 7, 10, 1, 2, 3, 8, 8, 2, 10, 4, 8, 3, 10, 2, 3, 2, 2, 8, 10, 9, 4, 7, 8, 4, 3, 10, 4, 1, 4, 7, 9, 8, 10, 7, 8, 8, 9, 10, 9, 4, 4, 7, 1, 1, 3, 7, 9, 2, 9, 6, 6, 1, 3, 2, 2, 4, 4, 7, 1, 1, 6, 6, 2, 3, 9, 4, 1, 1, 7, 4, 6, 9, 8, 6, 7, 2, 9, 4, 6, 4, 3, 1, 2, 8, 5, 3, 6, 8, 8, 5, 7, 1, 4, 9, 1, 7, 7, 5, 1, 8, 5, 5, 7, 8, 9, 5, 3, 8, 8, 5, 7, 4, 6, 1, 8, 1, 3, 9, 2, 2, 4, 7, 9, 7, 9, 9, 6, 8, 8, 4, 7, 5, 7, 1, 1, 9, 10, 3, 9, 2, 9, 10, 3, 10, 7, 6, 6, 1, 7, 6, 1, 7, 5, 7, 8, 3, 8, 9, 2, 2, 3, 10, 2, 1, 5, 1, 9, 1, 10, 8, 4, 7, 10, 7, 7, 6, 4, 4, 10, 4, 4, 6, 3, 3, 6, 1, 3, 1, 5, 4, 2, 6, 7, 9, 10, 3, 5, 7, 6, 8, 1, 4, 1, 7, 4, 4, 1, 5, 10, 5, 6, 6, 9, 5, 4, 2, 5, 1, 4, 5, 8, 7, 9, 5, 10, 6, 2, 6, 1, 9, 5, 2, 7, 8, 1, 8, 10, 8, 4, 7, 8, 5, 3, 2, 6, 4, 4, 10, 10, 6, 8, 9, 9, 7, 10, 4, 3, 9, 9, 8, 2, 2, 2, 9, 1, 10, 2, 8, 1, 9, 8, 6, 1, 2, 9, 1, 2, 10, 7, 7, 7, 10, 4, 5, 6, 2, 6, 8, 6, 4, 2, 5, 4, 4, 2, 1, 8, 10, 6, 4, 6, 9, 3, 8, 1, 9, 3, 2, 9, 3, 5, 10, 9, 5, 6, 1, 6, 1, 8, 8, 2, 10, 5, 9, 10, 8, 3, 7, 4, 9, 6, 5, 7, 4, 3, 9, 1, 3, 9, 6, 6, 8, 3, 3, 8, 7, 3, 4, 2, 5, 6, 10, 7, 2, 6, 4, 9, 2, 10, 10, 2, 4, 6, 10, 3, 10, 4, 9, 8, 1, 1, 4, 9, 10, 3, 4, 2, 8, 3, 8, 8, 4, 1, 5, 2, 3, 1, 5, 1, 3, 2, 3, 4, 8, 2, 3, 3, 10, 1, 7, 6, 8, 3, 5, 4, 2, 4, 5, 3, 1, 6, 8, 8, 5, 7, 9, 3, 3, 8, 5, 1, 6, 4, 3, 1, 1, 10, 9, 4, 6, 9, 10, 10, 5, 8, 2, 3, 5, 4, 8, 9, 10, 6, 1, 1, 8, 9, 9, 1, 8, 2, 2, 2, 3, 1, 8, 5, 5, 7, 8, 8, 6, 6, 4, 3, 8, 6, 8, 6, 10, 10, 8, 2, 9, 7, 6, 1, 1, 8, 9, 7, 7, 3, 4, 6, 2, 10, 4, 4, 1, 6, 7, 1, 6, 3, 7, 4, 8, 6, 10, 9, 5, 7, 3, 4, 4, 6, 4, 2, 6, 1, 8, 6, 5, 3, 10, 9, 10, 8, 2, 1, 8, 7, 8, 1, 1, 8, 8, 9, 4, 1, 8, 3, 7, 6, 4, 2, 3, 10, 5, 9, 8, 6, 3, 5, 10, 8, 3, 4, 8, 3, 1, 2, 1, 9, 1, 7, 6, 1, 3, 9, 1, 5, 7, 4, 1, 6, 6, 9, 8, 5, 10, 4, 3, 8, 10, 1, 6, 3, 1, 6, 3, 9, 9, 5, 8, 2, 4, 9, 5, 6, 2, 4, 10, 3, 5, 2, 9, 4, 3, 8, 3, 3, 1, 1, 10, 2, 1, 9, 3, 6, 2, 1, 5, 10, 10, 9, 3, 4, 4, 10, 8, 4, 2, 3, 2, 7, 6, 2, 5, 5, 3, 6, 7, 4, 10, 5, 10, 8, 2, 9, 1, 4, 2, 8, 2, 1, 3, 9, 3, 10, 6, 10, 1, 10, 5, 7, 6, 2, 10, 2, 9, 3, 6, 5, 5, 2, 1, 2, 3, 10, 2, 5, 8, 10, 9, 5, 4, 1, 10, 7, 1, 9, 3, 4, 3, 8, 7, 1, 8, 3, 9, 9, 5, 4, 2, 7, 7, 4, 1, 8, 10, 5, 6, 2, 1, 8, 2, 9, 3, 7, 8, 7, 4, 3, 5, 3, 10, 5, 7, 8, 8, 10, 10, 7, 2, 3, 6, 6, 10, 3, 10, 8, 10, 10, 5, 2, 10, 3, 8, 8, 6, 9, 2, 3, 9, 5, 2, 8, 9, 8, 6, 10, 3, 9, 5, 1, 4, 6, 1, 4, 1, 9, 10, 10, 2, 10, 6, 8, 6, 10, 5, 10, 8, 5, 6, 4, 1, 5, 5, 4, 3, 10, 6, 8, 7, 3, 5, 9, 10, 6, 2, 5, 3, 4, 8, 6, 9, 7, 8, 8, 3, 4, 7, 1, 9, 6, 5, 5, 3, 9, 3, 7, 7, 4, 8, 7, 9, 8, 6, 3, 6, 2, 4, 2, 1, 10, 3, 1, 8, 6, 5, 2, 10, 8, 10, 6, 9, 3, 2, 8, 9, 4, 4, 10, 6, 6, 5, 4, 10, 1, 3, 10, 7, 3, 6, 2, 4, 2, 5, 8, 7, 10, 8, 9, 1, 6, 1, 10, 4, 10, 4, 2, 3, 8, 3, 10, 1, 6, 6, 7, 7, 9, 4, 8, 3, 6, 1, 7, 6, 9, 9, 8, 1, 9, 9, 6, 5, 7, 6, 1, 8, 2, 10, 7, 9, 3, 10, 10, 3, 1, 8, 10, 8, 1, 1, 4, 2, 4, 3, 7, 9, 8, 9, 1, 8, 1, 3, 7, 9, 6, 4, 4, 8, 1, 10, 10, 7, 2, 3, 8, 4, 4, 2, 10, 1, 9, 3, 3, 1, 5, 10, 6, 10, 4, 6, 9, 8, 2, 8, 9, 7, 3, 3, 1, 3, 10, 3, 3, 3, 1, 5, 3, 8, 3, 4, 8, 6, 1, 2, 10, 5, 6, 8, 10, 9, 4, 1, 8, 6, 4, 7, 10, 6, 2, 2, 8, 6, 5, 2, 7, 4, 1, 7, 5, 5, 8, 5, 2, 7, 10, 9, 6, 2, 3, 4, 7, 7, 8, 9, 9, 10, 10, 2, 3, 7, 9, 8, 1, 10, 3, 7, 3, 7, 6, 5, 4, 7, 3, 3, 4, 3, 3, 10, 10, 5, 7, 5, 9, 4, 3, 7, 7, 1, 8, 9, 4, 10, 7, 3, 10, 7, 7, 7, 4, 10, 9, 7, 4, 2, 5, 4, 10, 9, 5, 7, 5, 5, 2, 4, 6, 1, 2, 3 ...
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
#   instance_id  repetition  fold
# 0        mip1           1     2
# 1       mip10           1     3
# 2      mip100           1     9
# 3     mip1000           1     4
# 4    mip10000           1     5

# %%
with open("MIPVerifySDP_SCIPfeatureset/cv.arff","a") as file:
    for index,row in folds_df.iterrows():
        file.write("\n")
        newrow = str(list(row)).strip("[]").replace("'", "")
        file.write(newrow)

    file.close()

# %% [markdown]
# ## Check RE

# %%
import re

features_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Jasmin\Documents\MSc-Thesis\autofolio_prep\aslib_step1_scip_features.ipynb Cell 49 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/aslib_step1_scip_features.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> import re
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jasmin/Documents/MSc-Thesis/autofolio_prep/aslib_step1_scip_features.ipynb#X65sZmlsZQ%3D%3D?line=2'>3</a> features_df.columns
#
# NameError: name 'features_df' is not defined
